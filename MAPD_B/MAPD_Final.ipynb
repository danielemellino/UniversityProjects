# %% [markdown]
# # MAPD (module B) Final Project
# # Dask Distributed Analysis of Covid-19 Papers
#
# * Alessandro Casalino
# * Michele M. Crudele
# * Daniele Mellino

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %% [markdown]
# # Table of Contents

# %% [markdown]
# # *Creation of a Distributed Cluster in Dask*
# In order to create the distributed cluster for this project, we exploit the convenience script **dask-ssh**, that opens several SSH connections to our target computers (the CloudVeneto VMs) and initializes the network accordingly.
# In our case, the IP addresses of the two VMs we have are: 10.67.22.160 and 10.67.22.190. So, if for example we want to create a distributed cluster with 4 workers using these machines, we simply type in the terminal window:
#
# $ dask-ssh 10.67.22.190 10.67.22.190 10.67.22.160 10.67.22.160 --nthreads <#cores/#workers>,
#
# where in our case #cores = 8, since we have 4 cores per VM.
#
# By typing this commmand, a ‘dask-scheduler’ process will run on the first of the specified IP addresses and one ‘dask-worker’ process will be run for each of them, so we will have 2 workers per VM.
#
# In order to be able to run this command, some operations are needed to make the two VMs "visible" between each other. To perform those operations, we followed the instructions in this website: https://towardsdatascience.com/set-up-a-dask-cluster-for-distributed-machine-learning-31f587b1b553.
#
# Finally, the version of every useful library has to be the same in every machine of the cluster and all the data need to be downloaded in the same path.
#
# As far as the cluster used in the project, we decided to use a cluster made up of two VMs, with 1 worker per core we have (i.e. 8 workers, 4 per VM). We made this choice a priori and a posteriori we can state that it was the best choice, since the analysis of the timings as a function of the number of workers shows that using 8 workers leads to the best performance.
#
# Then, in order to connect to the cluster, we simply use the Python command:
#
# >> client = Client( '10.67.22.190:8786' ),
#
# where 10.67.22.190 is the IP address of our scheduler and 8786 is its communication port with the workers.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

import os
import json
import time
import timeit

from dask.distributed import Client
import dask.bag as db
import dask.dataframe as ddf

from nltk.tokenize import RegexpTokenizer
from nltk import word_tokenize

from collections import Counter

from wordcloud import WordCloud, STOPWORDS

TIMING = False

# %% [markdown]
# # Dataset:
# The dataset consists of 1000 papers in json format randomly chosen from the ones in https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge. The json downloaded are in a multi-lines format. We decide to load the data into a dask.bag therefore we transform the json files into a single-line format through this script : <br>
# <div>
# <code>
# for filename in *.json; do
# <pre>    echo $filename
#     jq -c . $filename > ../json_singleline/$filename
# </pre>
# done
# </code>
# </div>

# %% [markdown]
# # 1. Most Used Words in COVID-19 Papers

# %%
# Make a client
client = Client('10.67.22.190:8786')
client
# Out:
# /usr/lib/python3.6/site-packages/distributed/client.py:1134: VersionMismatchWarning: Mismatched versions found
#
# +---------+---------------+---------------+------------------------------------+
# | Package | client        | scheduler     | workers                            |
# +---------+---------------+---------------+------------------------------------+
# | python  | 3.6.8.final.0 | 3.6.8.final.0 | {'3.6.8.final.0', '3.6.5.final.0'} |
# +---------+---------------+---------------+------------------------------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tcp://10.67.22.190:8786' processes=8 threads=32, memory=65.61 GB>

# %% [markdown]
# The first request, ask us to count the the most frequent words inside the documents. To do that we load our data into a dask.bag using the function read_text. This function interprets every line of our file as a separate element. That is why, in order to not get problem, we converted the data into a json-line delimeted format. The resulting items in the bag are strings. We convert each string (that encodes a json) in a dictionary thanks to the function json.loads.

# %%
# Load data and repartition
# 1000 papers is in the directory data/json_single line
# One single paper is a json file with a single line.
filename = os.path.join('data', 'json_singleline', '*.json')

# Load the Dask.bag directly from the text files
lines = db.read_text(filename)

# the resulting item in the bag are strings, the default number of partitions is
# equal to the number of files. So now we have a file for partition

# We convert each string (that encodes a json) in a dictionary thanks to the function json.loads
js = lines.map(json.loads)

# %% [markdown]
# Notice that the default number of partitions created by the read_text function is one per file. Therefore after the reading procedure we get 1000 partitions. This is the most sensible choice: in this way indeed, we avoid to group all the files together and then split them in small partitions. This operation would require a lot of time and resources, so it is better to read each file as a single partition and to repartition them later.
#
# The text we want to use for accomplish the first task is inside "body_text" under the key "text". As we can see below. Additionally we can notice that there are more than one "text".

# %%
# The pluck function select item from all tuples/dicts in collection.
js.pluck("body_text").take(1)
# Out:
# ([{'text': "Severe acute respiratory syndrome (SARS) is a recently emerged infectious disease characterized by persistent fever, respiratory symptoms with lung consolidation, lymphopenia and respiratory failure in life-threatening cases [1] [2] [3] [4] . Watery diarrhoea has also been manifested in some cases [5] . We found that lymphopenia and depletion of CD4 and CD8 T lymphocytes could be associated with disease activity and adverse outcomes in SARS [4] . The SARS-related deaths have resulted mainly from pulmonary complications, including progressive respiratory failure due to alveolar damage and acute respiratory distress syndrome (ARDS). The causative agent of SARS has been identified as a new coronavirus (SARS-CoV) [6] [7] [8] with a genome sequence that is only moderately related to other known coronaviruses [9, 10] . Rapid diagnostic tests using molecular techniques for the detection of SARS-CoV RNA have been developed recently [11, 12] . Administration of the antiviral drug ribarivin together with systemic corticosteroid resulted in alleviation of inflammation, reduction of organ dysfunction and improvement on survival in the majority of SARS patients [1, 5, 13] , although controlled clinical trials are required to confirm this regimen's genuine efficacy.",
#    'cite_spans': [{'start': 225,
#      'end': 228,
#      'text': '[1]',
#      'ref_id': 'BIBREF0'},
#     {'start': 229, 'end': 232, 'text': '[2]', 'ref_id': 'BIBREF1'},
#     {'start': 233, 'end': 236, 'text': '[3]', 'ref_id': 'BIBREF2'},
#     {'start': 237, 'end': 240, 'text': '[4]', 'ref_id': 'BIBREF3'},
#     {'start': 299, 'end': 302, 'text': '[5]', 'ref_id': 'BIBREF4'},
#     {'start': 445, 'end': 448, 'text': '[4]', 'ref_id': 'BIBREF3'},
#     {'start': 719, 'end': 722, 'text': '[6]', 'ref_id': 'BIBREF5'},
#     {'start': 723, 'end': 726, 'text': '[7]', 'ref_id': 'BIBREF6'},
#     {'start': 727, 'end': 730, 'text': '[8]', 'ref_id': 'BIBREF7'},
#     {'start': 815, 'end': 818, 'text': '[9,', 'ref_id': 'BIBREF8'},
#     {'start': 819, 'end': 822, 'text': '10]', 'ref_id': 'BIBREF9'},
#     {'start': 938, 'end': 942, 'text': '[11,', 'ref_id': 'BIBREF10'},
#     {'start': 943, 'end': 946, 'text': '12]', 'ref_id': 'BIBREF11'},
#     {'start': 1167, 'end': 1170, 'text': '[1,', 'ref_id': 'BIBREF0'},
#     {'start': 1171, 'end': 1173, 'text': '5,', 'ref_id': 'BIBREF4'},
#     {'start': 1174, 'end': 1177, 'text': '13]', 'ref_id': 'BIBREF12'}],
#    'ref_spans': [],
#    'section': 'INTRODUCTION'},
#   {'text': "It has been shown that the over-production of specific inflammatory cytokines [tumour necrosis factor (TNF)-a , interleukin (IL)-1 b , IL-6, IL-10] and polymorphonuclear neutrophil (PMN) CC chemokine IL-8 is the hallmark of viral infection, probably through the activation of transcription factor nuclear factor (NF)-k B, activator protein (AP)-1 and activating factor-2 (ATF-2) [14] . For example, the H5N1 'avian flu' influenza viruses are potent inducers of proinflammatory cytokines such as TNF-a in macrophages [15] . In swine pneumonia, the production of TNF-a and IL-6 was found to correlate positively with disease severity [16] . Therefore, SARS sequalae such as transendothelial migration of PMN into lung tissue, multiple organ dysfunction and ARDS have been postulated to associate with cytokine and chemokine dysregulation [17, 18] . In an attempt to study possible SARS-CoV-induced cytokine and chemokine dysregulation, to identify markers for disease severity, and to explore the feasibility of designing effective treatment strategy such as anti-cytokine therapy, we have prospectively investigated a panel of circulating T helper (Th) cell cytokines, inflammatory cytokines and chemokines in patients with SARS.",
#    'cite_spans': [{'start': 379,
#      'end': 383,
#      'text': '[14]',
#      'ref_id': 'BIBREF13'},
#     {'start': 516, 'end': 520, 'text': '[15]', 'ref_id': 'BIBREF14'},
#     {'start': 632, 'end': 636, 'text': '[16]', 'ref_id': 'BIBREF15'},
#     {'start': 836, 'end': 840, 'text': '[17,', 'ref_id': 'BIBREF16'},
#     {'start': 841, 'end': 844, 'text': '18]', 'ref_id': 'BIBREF17'}],
#    'ref_spans': [],
#    'section': 'INTRODUCTION'},
#   {'text': 'Our study included 20 consecutive adult patients who were diagnosed to have SARS and admitted to the Prince of Wales Hospi-tal, Hong Kong for treatment from 20 March to 11 April 2003. In accordance with the World Health Organization (WHO), our case definition was a fever (temperature > 38 ∞ C), a chest radiograph or computed tomographic image of the thorax showing evidence of new consolidation with or without respiratory symptoms (e.g. cough and shortness of breath) and a history of close contact with a person in whom SARS had been diagnosed [19] . The diagnosis of SARS was confirmed by an indirect immunofluorescence assay with fetal rhesus kidney cells that were infected with coronavirus and fixed in acetone to detect a serological response to the SARS-CoV [7] , or by a positive viral culture. Our protocol was approved by the Clinical Research Ethics Committee of the Chinese University of Hong Kong and informed consent was obtained from all participants.',
#    'cite_spans': [{'start': 548,
#      'end': 552,
#      'text': '[19]',
#      'ref_id': 'BIBREF18'},
#     {'start': 768, 'end': 771, 'text': '[7]', 'ref_id': 'BIBREF6'}],
#    'ref_spans': [],
#    'section': 'Patients'},
#   {'text': 'Box & whiskers plots of changes in plasma cytokine concentrations following day of disease onset in the 20 SARS patients. Normal ranges: (a) IL-1 b < 3·9 ng/l; (b) IL-6 < 3·1 ng/l; (c) IL-10 < 7·8 ng/l; (d) IL-12 < 7·8 ng/l; (e) TNF-a < 10·0 ng/l; and (f) IFN-g < 15·6 ng/l. *Significantly elevated compared to normal values (all P < 0·05). Measurement of plasma cytokines and chemokines EDTA blood samples were collected from SARS patients daily for a maximum of 19 consecutive days. They were immersed in ice and transported immediately to the laboratory for processing. Plasma were separated by centrifugation (2000 g for 10 min) at 4 ∞ C and stored in 300 m l aliquots at -70 ∞ C until analysis. Because the more commonly used procedure of enzymelinked immunosorbent assay (ELISA) may generate infectious droplets and aerosols, T helper (Th)1/Th2 cytokines, inflammatory cytokines and chemokines in plasma were measured serially by cytometric bead array (CBA) using a four-colour FACSCalibur flow cytometer (Becton Dickinson, CA, USA) located in a Biosafety Level II laboratory [20, 21] . In CBA, five or six bead populations with distinct fluorescence intensities had been coated with capturing antibodies specific for different cytokines or chemokines. These bead populations could be resolved in the fluorescence channels of the flow cytometer. After the beads had been incubated with 50 m l of plasma, different cytokines or chemokines in the sample were captured by their corresponding beads. The cytokine/chemokine captured beads were then mixed with phycoerythrin-conjugated detection antibodies to form sandwich complexes. Following incubation, washing and acquisition of fluorescence data, the results were generated in graphical format using the BD CBA software. The concentrations of Th1/Th2 cytokines IL-2, IL-4 and IFN-g ; inflammatory cytokines IL-1 b , IL-6, IL-10, TNF-a and IL-12p70; and chemokines IL-8, regulated upon activation normal T cell-expressed and secreted (RANTES), monocyte chemoattractant protein-1 (MCP-1), IFN-g -inducible protein-10 (IP-10) and monokine induced by IFN-g (MIG) were measured using the human Th1/Th2 cytokine, inflammatory cytokine and chemokine CBA kits (BD Pharmingen, CA, USA), respectively. The assay sensitivities of these eight cytokines and five chemokines were 2·6, 2·6, 7·1, 7·2, 2·5, 3·3, 3·7, 1·9, 0·2, 1·0, 2·7, 2·8 and 2·5 ng/l, respectively. The coefficients of variation for all cytokine and chemokine assays were less than 10%. Their respective normal ranges have been derived from measurement of ≥ 100 healthy subjects.',
#    'cite_spans': [{'start': 1082,
#      'end': 1086,
#      'text': '[20,',
#      'ref_id': 'BIBREF19'},
#     {'start': 1087, 'end': 1090, 'text': '21]', 'ref_id': 'BIBREF20'}],
#    'ref_spans': [],
#    'section': 'Fig. 1.'},
#   {'text': 'Because plasma cytokine and chemokine concentrations were not in a Gaussian distribution, the Mann-Whitney rank sum test was used for assessing their differences. Results were expressed as median (interquartile range). All analyses were performed using the Statistical Package for Social Sciences (SPSS) software for Windows, Version 9·0 (SPSS Inc., IL, USA). A probability ( P ) < 0·05 was considered as significantly different.',
#    'cite_spans': [],
#    'ref_spans': [],
#    'section': 'Statistical analysis'},
#   {'text': 'The characteristics of the 20 SARS patients are summarized in Table 1 . Coincidentally, all except one were female patients, although the female-to-male ratio of the 1755 SARS patients in this outbreak in Hong Kong, as well as that of the 290 patients None of the 20 SARS patients recruited in this study died or required admission to the intensive care unit (ICU). Initial treatment included antibiotics, cefotaxime and clarithromycin (or levofloxacin) to cover common pathogens causing community-acquired pneumonia. Oseltamivir (Tamiflu) was also given initially to treat possible influenza infection. After fever had persisted for more than 48 h and leukopenia, thrombocytopenia, or both, had developed, oral ribavirin (40-60 mg/kg/day) and oral prednisolone (1 mg/kg/day) were started as a combined regimen from 2 to 9 days after disease (fever) onset. Patients who did not respond clinically to standard empirical treatment including persistent fever, increasing shortness of breath, worsening lung opacities involving > 50% of lung field in chest radiograph and deteriorating oxygen saturation to < 90% by pulse oximetry, were given intravenous ribavirin (400 mg every 8 h) and an additional one to three pulses of 0·5 g of methylprednisolone sodium succinate (methylprednisolone) daily.',
#    'cite_spans': [],
#    'ref_spans': [{'start': 62,
#      'end': 69,
#      'text': 'Table 1',
#      'ref_id': 'TABREF0'}],
#    'section': 'SARS patients'},
#   {'text': 'The longitudinal trends of plasma Th1/Th2 cytokines and inflammatory cytokines of the 20 SARS patients are illustrated in Fig. 1 . Th1 cytokine IFN-g and inflammatory cytokines IL-1 b , IL-6 and IL-12 concentrations were significantly elevated above their normal range, respectively, within the first 12, 7 and 5 days after disease onset (all P < 0·05). In contrast, there was no significant increase in proinflammatory cytokine TNF-a in all SARS patients. Anti-inflammatory cytokine IL-10 was found to increase in some but not all patients (no overall significance). The plasma concentrations of Th1 cytokine IL-2 and Th2 cytokine IL-4 of all patients were low and within their respective normal range at all time points (data not shown). ',
#    'cite_spans': [],
#    'ref_spans': [{'start': 122, 'end': 128, 'text': 'Fig. 1', 'ref_id': None}],
#    'section': 'Plasma cytokines of SARS patients'},
#   {'text': 'As shown in Fig. 2 , plasma PMN CC chemokine IL-8, monocyte CC chemokine MCP-1 and Th1 CXC chemokine IP-10 concentrations were elevated, respectively, within the first 9, 3 and 14 days after disease onset (all P < 0·05). The overall plasma concentrations of T cell chemoattractants, namely CXC chemokine MIG and CC chemokine RANTES, were not significantly elevated.',
#    'cite_spans': [],
#    'ref_spans': [{'start': 12,
#      'end': 18,
#      'text': 'Fig. 2',
#      'ref_id': 'FIGREF2'}],
#    'section': 'Plasma chemokines of SARS patients'},
#   {'text': 'Among the 20 SARS patients in our cohort, 13 had more severe disease activity including persistent fever and worsening lung opacities; they were additionally given intravenous pulsed methylprednisolone. The other seven patients had milder disease severity and were not treated with pulsed steroid. Figure 3 shows that plasma IFN-g , IL-1 b , IL-6, IL-8, IP-10 and MCP-1 of the former group of patients had higher median concentrations than those of the latter, particularly from day 3-10 after disease onset. Following recovery, the cytokine and chemokine levels decreased progressively to normal values at about 1 week after disease onset for both groups of patients.',
#    'cite_spans': [],
#    'ref_spans': [{'start': 298,
#      'end': 306,
#      'text': 'Figure 3',
#      'ref_id': 'FIGREF6'}],
#    'section': 'Plasma cytokines and chemokines in SARS patients treated and not treated with pulsed methylprednisolone'},
#   {'text': 'As summarized in Table 2 , plasma chemokine IL-8, IP-10 and MCP-1 were significantly reduced to their respective normal ranges from 5 to 8 days after corticosteroid treatment compared to the elevated pretreatment levels (all P < 0·005). These 5-8-day post-treatment concentrations were also significantly lower than those of 1-2 days after treatment (all P < 0·05). All the other measured cytokines and chemokines (IL-1 b , IL-6, IL-10, IL-12p70, TNF-a , IFN-g , RANTES and MIG) did not show any significant difference before and after corticosteroid treatment.',
#    'cite_spans': [],
#    'ref_spans': [{'start': 17,
#      'end': 24,
#      'text': 'Table 2',
#      'ref_id': 'TABREF1'}],
#    'section': 'Effects of corticosteroid treatment on plasma cytokines and chemokines'},
#   {'text': 'This study was designed to investigate prospectively the longitudinal plasma cytokine and chemokine profile of adult patients with SARS. The progression of this potentially lethal disease may be represented by three phases: acute viral multiplication, hyperactive immune response, recovery or pulmonary destruction and death [1, 4, 5] . Accordingly, it is worthwhile to investigate cytokine and chemokine induction, which may be the cause or consequence of immune hyperactivity in SARS. We observed that for at least 2 weeks after disease onset, all SARS patients exhibited a significant increase in the typical antiviral Th1 cytokine IFN-g and an array of proinflammatory cytokines (IL-1 b , IL-6 and IL-12), together with a moderate increase in anti-inflammatory IL-10 that was manifested in some patients. IL-1 b can act as the early response cytokine to viral infection such as that caused by the human immunodeficiency virus, for mediation of inflammatory response, synthesis of acute phase proteins and release of IL-8 [14, 22] . IL-6 may play a proinflammatory role in pulmonary inflammation [23] . Th2 cytokine IL-10 is an antiinflammatory cytokine that suppresses the secretion of proinflammatory cytokines [24] , therefore it was elevated in some patients 1 week after disease onset and followed the elevation of other inflammatory cytokines. IL-12, also known as natural killer (NK) cell stimulatory factor or cytotoxic lymphocyte maturation factor, is a pleiotropic proinflammatory cytokine which is produced primarily by antigen-presenting cells (monocytes, macrophages, dendritic cells and B cells) and PMN [25] . IL-12 can induce the production of IFN-g and other Th1 cytokines with suppression of the Th2 pathway [26, 27] . It has multiple effects on T lymphocytes and NK cells, including the ability to stimulate cytotoxicity, proliferation, cytokine production and the development of Th1 subsets [28, 29] . Therefore, the observed early elevation of inflammatory cytokines IL-1 b , IL-6, IL-12 and IFN-g could be causative of the SARS-CoV-induced activation of Th1 cells and NK cells, release of chemokines such as IL-8, and results in pulmonary inflammation [16] .',
#    'cite_spans': [{'start': 325,
#      'end': 328,
#      'text': '[1,',
#      'ref_id': 'BIBREF0'},
#     {'start': 329, 'end': 331, 'text': '4,', 'ref_id': 'BIBREF3'},
#     {'start': 332, 'end': 334, 'text': '5]', 'ref_id': 'BIBREF4'},
#     {'start': 1025, 'end': 1029, 'text': '[14,', 'ref_id': 'BIBREF13'},
#     {'start': 1030, 'end': 1033, 'text': '22]', 'ref_id': 'BIBREF21'},
#     {'start': 1099, 'end': 1103, 'text': '[23]', 'ref_id': 'BIBREF22'},
#     {'start': 1216, 'end': 1220, 'text': '[24]', 'ref_id': 'BIBREF23'},
#     {'start': 1621, 'end': 1625, 'text': '[25]', 'ref_id': 'BIBREF24'},
#     {'start': 1729, 'end': 1733, 'text': '[26,', 'ref_id': 'BIBREF25'},
#     {'start': 1734, 'end': 1737, 'text': '27]', 'ref_id': 'BIBREF26'},
#     {'start': 1914, 'end': 1918, 'text': '[28,', 'ref_id': 'BIBREF27'},
#     {'start': 1919, 'end': 1922, 'text': '29]', 'ref_id': 'BIBREF28'},
#     {'start': 2177, 'end': 2181, 'text': '[16]', 'ref_id': 'BIBREF15'}],
#    'ref_spans': [],
#    'section': 'DISCUSSION'},
#   {'text': 'A previous study has suggested that the infiltration of proinflammatory PMN is involved in the pathogenesis of acute lung injury [30] . PMN are abundant in the airspaces of most ARDS patients with infection, and their secretory products such as myeloperoxidase and elastase in bronchoalveolar lavage (BAL) fluid can cause acute lung injury [31] [32] [33] . IL-8, the PMN achemokine, has been shown to be elevated in blood and alveolar spaces [34] and exhibit a positive correlation with the number of PMN in BAL fluid of patients with pneumonia and ARDS [35] . Our SARS-CoV-infected patients also showed elevation of plasma IL-8 soon after disease onset, which declined from 5 to 8 days after corticosteroid treatment. In our former clinical study, 82% of 157 SARS patients developed neutrophilia and the high neutrophil counts were associated with ICU admission and mortality from pneumonia [4] . Therefore, PMN-induced acute pneumonitis should be crucial in the pathogenesis of ARDS and pulmonary destruction in SARS patients.',
#    'cite_spans': [{'start': 129,
#      'end': 133,
#      'text': '[30]',
#      'ref_id': 'BIBREF29'},
#     {'start': 340, 'end': 344, 'text': '[31]', 'ref_id': 'BIBREF30'},
#     {'start': 345, 'end': 349, 'text': '[32]', 'ref_id': 'BIBREF31'},
#     {'start': 350, 'end': 354, 'text': '[33]', 'ref_id': 'BIBREF32'},
#     {'start': 442, 'end': 446, 'text': '[34]', 'ref_id': 'BIBREF33'},
#     {'start': 554, 'end': 558, 'text': '[35]', 'ref_id': 'BIBREF34'},
#     {'start': 892, 'end': 895, 'text': '[4]', 'ref_id': 'BIBREF3'}],
#    'ref_spans': [],
#    'section': 'DISCUSSION'},
#   {'text': 'Apart from the a -chemokine IL-8, we have also observed elevation of the monocyte/macrophages b -chemokine MCP-1 soon after the onset of SARS, followed by decline after corticosteroid treatment. MCP-1 concentration has been shown to increase in BAL fluid of patients with persistent ARDS [36] , correlating positively with the predominance of alveolar macrophages [37] that has also been found in the postmortem examination of SARS patients [2, 38] . IP-10 is a specific chemoattractant for Th1 cells for the activation of cell-mediated immune response; its expression can be up-regulated by the Th1 cytokine IFN-g in acute lung inflammation [39] . Consistently, our results showed that both circulating IFN-g and IP-10 were increased in SARS patients. Our observation of low or normal Th2 cytokine IL-4 in SARS patients is also similar to the finding of a previous study of viral pneumonia [40] . These suggest that SARS-CoV does not enhance the Th2 pathway and the subsequent humoral immue response. Such imbalance of Th1/Th2 cytokine profile confirms the SARS-CoVinduced Th1 predominance. In contrast to H5N1 infection [15] , plasma TNF-a was not elevated in our patients. This finding, therefore, does not support the therapeutic use of TNF-a monoclonal antibody for SARS. However, it must be cautioned that the concentration of TNF-a at the pulmonary inflammatory sites has not been investigated. Previous studies have implicated that inflammatory IL-b and the acute-phase cytokine IL-6 are endogenous pyrogens or inducers of fever [41] . Therefore, elevations of IL-b and IL-6 might account for the fever onset, as both of them were found to have high plasma concentrations during the first week of disease. Moreover, the T cell chemokines MIG and RANTES also did not show any significantly elevation. Therefore, the recruitment of activated T cells in pulmonary tissue should be studied by performing chemokine assay and differential cell count in BAL fluids, although this should be difficult because of the high risk of infection.',
#    'cite_spans': [{'start': 288,
#      'end': 292,
#      'text': '[36]',
#      'ref_id': 'BIBREF35'},
#     {'start': 364, 'end': 368, 'text': '[37]', 'ref_id': 'BIBREF36'},
#     {'start': 441, 'end': 444, 'text': '[2,', 'ref_id': 'BIBREF1'},
#     {'start': 445, 'end': 448, 'text': '38]', 'ref_id': 'BIBREF37'},
#     {'start': 642, 'end': 646, 'text': '[39]', 'ref_id': 'BIBREF38'},
#     {'start': 891, 'end': 895, 'text': '[40]', 'ref_id': 'BIBREF39'},
#     {'start': 1122, 'end': 1126, 'text': '[15]', 'ref_id': 'BIBREF14'},
#     {'start': 1537, 'end': 1541, 'text': '[41]', 'ref_id': 'BIBREF40'}],
#    'ref_spans': [],
#    'section': 'DISCUSSION'},
#   {'text': 'In summary, we postulate that the elevation of the plasma chemokines IL-8, MCP-1 and IP-10, Th1-related cytokine IFN-g and IL-12, and inflammatory cytokines IL-1b and IL-6 can induce the hyperinnate inflammatory response due to the SARS-CoV invasion of the respiratory tract. This leads to the recruitment and accumulation of alveolar macrophages and PMN [42] , as well as the activation of Th1 cell-mediated immunity by the stimulation of NK and cytotoxic T lymphocytes (CTL). Treatment with immunosuppressive corticosteroid can significantly suppress the elevated chemokines IL-8, IP-10 and MCP-1, and subsequently alleviate the chemokine-associated pulmonary inflammation in SARS. Indeed, the reduction in IL-8, IP-10 and MCP-1 correlated with the improvement in general clinical condition, pulmonary function and radiological appearance in SARS patients of our present study. In addition, we also observed that higher disease severity was associated with more elevated plasma IFN-g, IL-1b, IL-6, IL-8, IP-10 and MCP-1 concentrations (Fig. 3) . It can be postulated that the addition of pulsed steroid in the severe-disease group not only controlled the rapidly deteriorating clinical condition, but basically attenuated the otherwise over-exaggerated immunological response with potentially much high median concentrations of plasma cytokines and chemokines. This further supports that the above cytokines and chemokines played impor-tant roles in the immunopathological mechanisms of SARS. We have initiated a study comparing plasma cytokines and chemokines in SARS patients with and without corticosteroid treatment. The elevated plasma cytokines and chemokines should also shed light on the possibility of using them as prognostic indicators for disease severity in SARS. For example, the presence of high anti-IL-8 : IL-8 complexes in BAL fluid has been shown to be an important prognostic indicator for ARDS [43] .',
#    'cite_spans': [{'start': 355,
#      'end': 359,
#      'text': '[42]',
#      'ref_id': 'BIBREF41'},
#     {'start': 1917, 'end': 1921, 'text': '[43]', 'ref_id': 'BIBREF42'}],
#    'ref_spans': [{'start': 1037,
#      'end': 1045,
#      'text': '(Fig. 3)',
#      'ref_id': 'FIGREF6'}],
#    'section': 'DISCUSSION'},
#   {'text': 'Although our study has provided some understanding of the immunological mechanisms of inflammation in SARS and the therapeutic effects of corticosteroid, many further investigations are required to explore the detailed pathophysiology of this novel emerging disease with global impact. In order to correlate cytokine release with disease severity, in vitro mechanistic study of cytokine induction using SARS-CoV and immune cell culture, and eventually the measurement of cytokine and chemokine concentrations at local inflammatory sites should be contemplated. Other chemokines such as epithelial neutrophil-activating peptide (ENA)-78, a neutrophil chemoattractant [30] , and macrophage inflammatory peptide-1 alpha (MIP-1a), a monocyte chemoattractant [30] , should be measured. Recently, transforming growth factor (TGF)-b has been shown to be active early in acute lung injury, and potentially contribute to the development of pulmonary oedema [44] . Therefore, the role of TGF-b in SARS also requires investigation. Given the prominent roles of cytokines and chemokines in the pathogenesis of SARS, anticytokine/ chemokine immunotherapy using anticytokine/chemokine antibodies (e.g. anti-IL-8, anti-MCP-1) or cytokine/chemokine antagonists may represent a novel approach for the treatment of hyperactive inflammation in SARS [45, 46] .',
#    'cite_spans': [{'start': 666,
#      'end': 670,
#      'text': '[30]',
#      'ref_id': 'BIBREF29'},
#     {'start': 754, 'end': 758, 'text': '[30]', 'ref_id': 'BIBREF29'},
#     {'start': 948, 'end': 952, 'text': '[44]', 'ref_id': 'BIBREF43'},
#     {'start': 1330, 'end': 1334, 'text': '[45,', 'ref_id': 'BIBREF44'},
#     {'start': 1335, 'end': 1338, 'text': '46]', 'ref_id': 'BIBREF45'}],
#    'ref_spans': [],
#    'section': 'DISCUSSION'}],)

# %% [markdown]
# Once we select the body_text we decrease the number of partition in order to save computation time. In fact there is no more need of 1000 partitions since, now, the dimension of the files is reduced. Therefore we repartition the bag to 100 partitions. We will see later wich is an optimal partitions number.

# %%
# Merge all the body texts in one for each file
def merge_text(record):
    merge = ""
    for rec in record:
        merge += rec["text"]
    return merge


#Extract the body_text,repartition it, then merge the "text" into one string
texts = js.pluck("body_text").repartition(100).map(merge_text) 

#Show result
texts.take(1)
# Out:
# ("Severe acute respiratory syndrome (SARS) is a recently emerged infectious disease characterized by persistent fever, respiratory symptoms with lung consolidation, lymphopenia and respiratory failure in life-threatening cases [1] [2] [3] [4] . Watery diarrhoea has also been manifested in some cases [5] . We found that lymphopenia and depletion of CD4 and CD8 T lymphocytes could be associated with disease activity and adverse outcomes in SARS [4] . The SARS-related deaths have resulted mainly from pulmonary complications, including progressive respiratory failure due to alveolar damage and acute respiratory distress syndrome (ARDS). The causative agent of SARS has been identified as a new coronavirus (SARS-CoV) [6] [7] [8] with a genome sequence that is only moderately related to other known coronaviruses [9, 10] . Rapid diagnostic tests using molecular techniques for the detection of SARS-CoV RNA have been developed recently [11, 12] . Administration of the antiviral drug ribarivin together with systemic corticosteroid resulted in alleviation of inflammation, reduction of organ dysfunction and improvement on survival in the majority of SARS patients [1, 5, 13] , although controlled clinical trials are required to confirm this regimen's genuine efficacy.It has been shown that the over-production of specific inflammatory cytokines [tumour necrosis factor (TNF)-a , interleukin (IL)-1 b , IL-6, IL-10] and polymorphonuclear neutrophil (PMN) CC chemokine IL-8 is the hallmark of viral infection, probably through the activation of transcription factor nuclear factor (NF)-k B, activator protein (AP)-1 and activating factor-2 (ATF-2) [14] . For example, the H5N1 'avian flu' influenza viruses are potent inducers of proinflammatory cytokines such as TNF-a in macrophages [15] . In swine pneumonia, the production of TNF-a and IL-6 was found to correlate positively with disease severity [16] . Therefore, SARS sequalae such as transendothelial migration of PMN into lung tissue, multiple organ dysfunction and ARDS have been postulated to associate with cytokine and chemokine dysregulation [17, 18] . In an attempt to study possible SARS-CoV-induced cytokine and chemokine dysregulation, to identify markers for disease severity, and to explore the feasibility of designing effective treatment strategy such as anti-cytokine therapy, we have prospectively investigated a panel of circulating T helper (Th) cell cytokines, inflammatory cytokines and chemokines in patients with SARS.Our study included 20 consecutive adult patients who were diagnosed to have SARS and admitted to the Prince of Wales Hospi-tal, Hong Kong for treatment from 20 March to 11 April 2003. In accordance with the World Health Organization (WHO), our case definition was a fever (temperature > 38 ∞ C), a chest radiograph or computed tomographic image of the thorax showing evidence of new consolidation with or without respiratory symptoms (e.g. cough and shortness of breath) and a history of close contact with a person in whom SARS had been diagnosed [19] . The diagnosis of SARS was confirmed by an indirect immunofluorescence assay with fetal rhesus kidney cells that were infected with coronavirus and fixed in acetone to detect a serological response to the SARS-CoV [7] , or by a positive viral culture. Our protocol was approved by the Clinical Research Ethics Committee of the Chinese University of Hong Kong and informed consent was obtained from all participants.Box & whiskers plots of changes in plasma cytokine concentrations following day of disease onset in the 20 SARS patients. Normal ranges: (a) IL-1 b < 3·9 ng/l; (b) IL-6 < 3·1 ng/l; (c) IL-10 < 7·8 ng/l; (d) IL-12 < 7·8 ng/l; (e) TNF-a < 10·0 ng/l; and (f) IFN-g < 15·6 ng/l. *Significantly elevated compared to normal values (all P < 0·05). Measurement of plasma cytokines and chemokines EDTA blood samples were collected from SARS patients daily for a maximum of 19 consecutive days. They were immersed in ice and transported im ...

# %% [markdown]
# ## Text Cleaning

# %% [markdown]
# As we can see from the output above, the produced text has some issues.
# It presents the reference numbers, punctuations, single numbers and stopwords(i.e. the most common words in a language). We use an pre-build set of stopwords from the wordcloud package to which we add a list of common words that are missing.

# %%
#set of words we' ll cancel out using stop_words:
stop_words = set(STOPWORDS)
#other words we remove a posteriori
no_words = {"i", "as", "or", "it", "et", "also", "may", "of", "at", "q", "al", "s", "fig", "figure"}
print(stop_words.union(no_words))
# Out:
# {"they've", 'about', 'http', 'am', 'in', "there's", "they're", "we've", 'or', 'just', 'they', 'ought', 'here', 'shall', 'else', 'below', 'his', 'q', 'also', "weren't", "wasn't", 'of', 'their', 'off', "you'll", "you're", 'no', "i'll", 'few', "i'm", 'have', 'our', 'should', 'was', 'www', 'she', 'for', 'against', 'further', 'itself', 'same', 'very', 'whom', 'each', "we'd", 'which', 'a', 'such', 'when', "shan't", 'than', "doesn't", 'com', 'hers', 'too', 'the', 'he', 'and', 'then', "wouldn't", 'had', 'there', "it's", "why's", 'did', 'both', 'own', 'being', 'because', 'i', 'is', 'that', 'by', 'through', 'you', 'cannot', 'do', "she's", "shouldn't", 'up', "he'd", "when's", 'at', 'et', 'as', 'al', 'only', "aren't", 'its', 'not', "we'll", 'themselves', "she'd", 'herself', 'nor', 'into', 'all', 'over', 'yourselves', 'like', "don't", 'this', 'those', 'himself', 'most', 'k', 'were', 'your', "mustn't", 'out', 'hence', 'until', 'what', 'during', 'where', 'r', 'with', 'yours', 'me', "won't", 'are', "let's", 'why', 'been', 'get', 'ourselves', "we're", 'ours', "didn't", 'could', 'once', 'before', 'does', 'however', 'having', 'ever', 'these', 'doing', 'again', "he'll", "that's", 'theirs', 'we', 'yourself', "they'll", "here's", 'can', 'but', 'figure', 'it', "hasn't", "she'll", 'from', "isn't", 'some', "can't", 'down', 'between', "how's", 'under', "you've", 'an', 'so', 'after', 'while', 'since', 'would', 'her', "you'd", 'be', 'has', "i've", 'other', 'if', 'him', 'may', "i'd", 'therefore', 'who', 'how', 'on', 'any', "where's", 's', 'fig', "they'd", 'otherwise', "what's", "he's", 'above', 'my', 'myself', 'to', "who's", "hadn't", 'more', "haven't", 'them', "couldn't"}

# %% [markdown]
# Below there is an example of usage of the function we develope to clean the data.

# %%
#example: 
string = "COVID-19, paper;"
result = word_tokenize(string, language='english')
print("word_tokenize:", result)
#word_tokenize scompose a string in "token"

#Here we delete the stop_words and recompose the tokens
new_sentence = ""
for w in result:
    if w.lower() not in stop_words.union(no_words): 
        new_sentence += w 
        new_sentence += " "
        
print("new_sentence:", new_sentence)
tokenizer = RegexpTokenizer(r"\w+") #\w+ matches any word character (equal to [a-zA-Z0-9_])
resultf = tokenizer.tokenize(new_sentence)
resultf = [item for item in resultf if item.isalpha()]

print("final result:", resultf)
# Out:
# word_tokenize: ['COVID-19', ',', 'paper', ';']
# new_sentence: COVID-19 , paper ;
# final result: ['COVID', 'paper']

# %%
# Now we clean all the files

tokenizer = RegexpTokenizer(r"\w+") #\w+ matches any word character (equal to [a-zA-Z0-9_])

def clean_func(text):
    def merge_text(text, stop_words):
        clean_text = " "
        for w in text:
            if w.lower() not in stop_words: #select the good words
                clean_text += w 
                clean_text += " "
        return clean_text   #this will be a string
    
    stop_words = set(STOPWORDS) #define the stopping words
    result = word_tokenize(text, language = 'english') #divide the string in words
    result = merge_text(result, stop_words.union(no_words)) # clean
    result = tokenizer.tokenize(result) #tokenize the output string
    result = [item for item in result if item.isalpha()] #remove numbers
    return result

text_clean = texts.map(clean_func)

text_clean.take(1)[0][:15]
# Out:
# ['Severe',
#  'acute',
#  'respiratory',
#  'syndrome',
#  'SARS',
#  'recently',
#  'emerged',
#  'infectious',
#  'disease',
#  'characterized',
#  'persistent',
#  'fever',
#  'respiratory',
#  'symptoms',
#  'lung']

# %% [markdown]
# ## Map Phase:
# In this section we produce the list of intermediate pairs (words and counts) in a dictionary format.

# %%
# We create a dictionary for each file with  
# the unique words and their frequencies

def count_words(text):
    counts = Counter(text)
    listt = [{"word": x , "counts": y} for x, y in counts.items()]
    return listt

words = text_clean.map(count_words)

#Example:
words.take(1)
# Out:
# ([{'word': 'Severe', 'counts': 1},
#   {'word': 'acute', 'counts': 10},
#   {'word': 'respiratory', 'counts': 7},
#   {'word': 'syndrome', 'counts': 2},
#   {'word': 'SARS', 'counts': 47},
#   {'word': 'recently', 'counts': 2},
#   {'word': 'emerged', 'counts': 1},
#   {'word': 'infectious', 'counts': 2},
#   {'word': 'disease', 'counts': 22},
#   {'word': 'characterized', 'counts': 1},
#   {'word': 'persistent', 'counts': 4},
#   {'word': 'fever', 'counts': 8},
#   {'word': 'symptoms', 'counts': 2},
#   {'word': 'lung', 'counts': 9},
#   {'word': 'consolidation', 'counts': 2},
#   {'word': 'lymphopenia', 'counts': 2},
#   {'word': 'failure', 'counts': 2},
#   {'word': 'life', 'counts': 1},
#   {'word': 'threatening', 'counts': 1},
#   {'word': 'cases', 'counts': 2},
#   {'word': 'Watery', 'counts': 1},
#   {'word': 'diarrhoea', 'counts': 1},
#   {'word': 'manifested', 'counts': 2},
#   {'word': 'found', 'counts': 5},
#   {'word': 'depletion', 'counts': 1},
#   {'word': 'T', 'counts': 9},
#   {'word': 'lymphocytes', 'counts': 3},
#   {'word': 'associated', 'counts': 4},
#   {'word': 'activity', 'counts': 2},
#   {'word': 'adverse', 'counts': 1},
#   {'word': 'outcomes', 'counts': 1},
#   {'word': 'related', 'counts': 3},
#   {'word': 'deaths', 'counts': 1},
#   {'word': 'resulted', 'counts': 2},
#   {'word': 'mainly', 'counts': 1},
#   {'word': 'pulmonary', 'counts': 10},
#   {'word': 'complications', 'counts': 1},
#   {'word': 'including', 'counts': 4},
#   {'word': 'progressive', 'counts': 1},
#   {'word': 'due', 'counts': 2},
#   {'word': 'alveolar', 'counts': 4},
#   {'word': 'damage', 'counts': 1},
#   {'word': 'distress', 'counts': 1},
#   {'word': 'ARDS', 'counts': 7},
#   {'word': 'causative', 'counts': 2},
#   {'word': 'agent', 'counts': 1},
#   {'word': 'identified', 'counts': 1},
#   {'word': 'new', 'counts': 2},
#   {'word': 'coronavirus', 'counts': 2},
#   {'word': 'CoV', 'counts': 9},
#   {'word': 'genome', 'counts': 1},
#   {'word': 'sequence', 'counts': 1},
#   {'word': 'moderately', 'counts': 1},
#   {'word': 'known', 'counts': 2},
#   {'word': 'coronaviruses', 'counts': 1},
#   {'word': 'Rapid', 'counts': 1},
#   {'word': 'diagnostic', 'counts': 1},
#   {'word': 'tests', 'counts': 1},
#   {'word': 'using', 'counts': 8},
#   {'word': 'molecular', 'counts': 1},
#   {'word': 'techniques', 'counts': 1},
#   {'word': 'detection', 'counts': 2},
#   {'word': 'RNA', 'counts': 1},
#   {'word': 'developed', 'counts': 3},
#   {'word': 'Administration', 'counts': 1},
#   {'word': 'antiviral', 'counts': 2},
#   {'word': 'drug', 'counts': 1},
#   {'word': 'ribarivin', 'counts': 1},
#   {'word': 'together', 'counts': 2},
#   {'word': 'systemic', 'counts': 1},
#   {'word': 'corticosteroid', 'counts': 8},
#   {'word': 'alleviation', 'counts': 1},
#   {'word': 'inflammation', 'counts': 7},
#   {'word': 'reduction', 'counts': 2},
#   {'word': 'organ', 'counts': 2},
#   {'word': 'dysfunction', 'counts': 2},
#   {'word': 'improvement', 'counts': 2},
#   {'word': 'survival', 'counts': 1},
#   {'word': 'majority', 'counts': 1},
#   {'word': 'patients', 'counts': 34},
#   {'word': 'although', 'counts': 3},
#   {'word': 'controlled', 'counts': 2},
#   {'word': 'clinical', 'counts': 4},
#   {'word': 'trials', 'counts': 1},
#   {'word': 'required', 'counts': 3},
#   {'word': 'confirm', 'counts': 1},
#   {'word': 'regimen', 'counts': 2},
#   {'word': 's', 'counts': 1},
#   {'word': 'genuine', 'counts': 1},
#   {'word': 'efficacy', 'counts': 1},
#   {'word': 'It', 'counts': 1},
#   {'word': 'shown', 'counts': 7},
#   {'word': 'over', 'counts': 2},
#   {'word': 'production', 'counts': 4},
#   {'word': 'specific', 'counts': 3},
#   {'word': 'inflammatory', 'counts': 18},
#   {'word': 'cytokines', 'counts': 27},
#   {'word': 'tumour', 'counts': 1},
#   {'word': 'necrosis', 'counts': 1},
#   {'word': 'factor', 'counts': 7},
#   {'word': 'TNF', 'counts': 10},
#   {'word': 'a', 'counts': 10},
#   {'word': 'interleukin', 'counts': 1},
#   {'word': 'IL', 'counts': 66},
#   {'word': 'b', 'counts': 15},
#   {'word': 'polymorphonuclear', 'counts': 1},
#   {'word': 'neutrophil', 'counts': 4},
#   {'word': 'PMN', 'counts': 10},
#   {'word': 'CC', 'counts': 4},
#   {'word': 'chemokine', 'counts': 24},
#   {'word': 'hallmark', 'counts': 1},
#   {'word': 'viral', 'counts': 5},
#   {'word': 'infection', 'counts': 6},
#   {'word': 'probably', 'counts': 1},
#   {'word': 'activation', 'counts': 5},
#   {'word': 'transcription', 'counts': 1},
#   {'word': 'nuclear', 'counts': 1},
#   {'word': 'NF', 'counts': 1},
#   {'word': 'k', 'counts': 1},
#   {'word': 'B', 'counts': 2},
#   {'word': 'activator', 'counts': 1},
#   {'word': 'protein', 'counts': 3},
#   {'word': 'AP', 'counts': 1},
#   {'word': 'activating', 'counts': 2},
#   {'word': 'ATF', 'counts': 1},
#   {'word': 'example', 'counts': 2},
#   {'word': 'avian', 'counts': 1},
#   {'word': 'flu', 'counts': 1},
#   {'word': 'influenza', 'counts': 2},
#   {'word': 'viruses', 'counts': 1},
#   {'word': 'potent', 'counts': 1},
#   {'word': 'inducers', 'counts': 2},
#   {'word': 'proinflammatory', 'counts': 7},
#   {'word': 'macrophages', 'counts': 5},
#   {'word': 'swine', 'counts': 1},
#   {'word': 'pneumonia', 'counts': 5},
#   {'word': 'correlate', 'counts': 2},
#   {'word': 'positively', 'counts': 2},
#   {'word': 'severity', 'counts': 6},
#   {'word': 'sequalae', 'counts': 1},
#   {'word': 'transendothelial', 'counts': 1},
#   {'word': 'migration', 'counts': 1},
#   {'word': 'tissue', 'counts': 2},
#   {'word': 'multiple', 'counts': 2},
#   {'word': 'postulated', 'counts': 2},
#   {'word': 'associate', 'counts': 1},
#   {'word': 'cytokine', 'counts': 32},
#   {'word': 'dysregulation', 'counts': 2},
#   {'word': 'attempt', 'counts': 1},
#   {'word': 'study', 'counts': 11},
#   {'word': 'possible', 'counts': 2},
#   {'word': 'induced', 'counts': 4},
#   {'word': 'identify', 'counts': 1},
#   {'word': 'markers', 'counts': 1},
#   {'word': 'explore', 'counts': 2},
#   {'word': 'feasibility', 'counts': 1},
#   {'word': 'designing', 'counts': 1},
#   {'word': 'effective', 'counts': 1},
#   {'word': 'treatment', 'counts': 12},
#   {'word': 'strategy', 'counts': 1},
#   {'word': 'anti', 'counts': 5},
#   {'word': 'therapy', 'counts': 1},
#   {'word': 'prospectively', 'counts': 2},
#   {'word': 'investigated', 'counts': 2},
#   {'word': 'panel', 'counts': 1},
#   {'word': 'circulating', 'counts': 2},
#   {'word': 'helper', 'counts': 2},
#   {'word': 'Th', 'counts': 2},
#   {'word': 'cell', 'counts': 9},
#   {'word': 'chemokines', 'counts': 18},
#   {'word': 'Our', 'counts': 1},
#   {'word': 'included', 'counts': 2},
#   {'word': 'consecutive', 'counts': 2},
#   {'word': 'adult', 'counts': 2},
#   {'word': 'diagnosed', 'counts': 2},
#   {'word': 'admitted', 'counts': 1},
#   {'word': 'Prince', 'counts': 1},
#   {'word': 'Wales', 'counts': 1},
#   {'word': 'Hospi', 'counts': 1},
#   {'word': 'tal', 'counts': 1},
#   {'word': 'Hong', 'counts': 3},
#   {'word': 'Kong', 'counts': 3},
#   {'word': 'March', 'counts': 1},
#   {'word': 'April', 'counts': 1},
#   {'word': 'accordance', 'counts': 1},
#   {'word': 'World', 'counts': 1},
#   {'word': 'Health', 'counts': 1},
#   {'word': 'Organization', 'counts': 1},
#   {'word': 'case', 'counts': 1},
#   {'word': 'definition', 'counts': 1},
#   {'word': 'temperature', 'counts': 1},
#   {'word': 'C', 'counts': 3},
#   {'word': 'chest', 'counts': 2},
#   {'word': 'radiograph', 'counts': 2},
#   {'word': 'computed', 'counts': 1},
#   {'word': 'tomographic', 'counts': 1},
#   {'word': 'image', 'counts': 1},
#   {'word': 'thorax', 'counts': 1},
#   {'word': 'showing', 'counts': 1},
#   {'word': 'evidence', 'counts': 1},
#   {'word': 'without', 'counts': 2},
#   {'word': 'e', 'counts': 3},
#   {'word': 'g', 'counts': 18},
#   {'word': 'cough', 'counts': 1},
#   {'word': 'shortness', 'counts': 2},
#   {'word': 'breath', 'counts': 2},
#   {'word': 'history', 'counts': 1},
#   {'word': 'close', 'counts': 1},
#   {'word': 'contact', 'counts': 1},
#   {'word': 'person', 'counts': 1},
#   {'word': 'diagnosis', 'counts': 1},
#   {'word': 'confirmed', 'counts': 1},
#   {'word': 'indirect', 'counts': 1},
#   {'word': 'immunofluorescence', 'counts': 1},
#   {'word': 'assay', 'counts': 4},
#   {'word': 'fetal', 'counts': 1},
#   {'word': 'rhesus', 'counts': 1},
#   {'word': 'kidney', 'counts': 1},
#   {'word': 'cells', 'counts': 9},
#   {'word': 'infected', 'counts': 2},
#   {'word': 'fixed', 'counts': 1},
#   {'word': 'acetone', 'counts': 1},
#   {'word': 'detect', 'counts': 1},
#   {'word': 'serological', 'counts': 1},
#   {'word': 'response', 'counts': 8},
#   {'word': 'positive', 'counts': 2},
#   {'word': 'culture', 'counts': 2},
#   {'word': 'protocol', 'counts': 1},
#   {'word': 'approved', 'counts': 1},
#   {'word': 'Clinical', 'counts': 1},
#   {'word': 'Research', 'counts': 1},
#   {'word': 'Ethics', 'counts': 1},
#   {'word': 'Committee', 'counts': 1},
#   {'word': 'Chinese', 'counts': 1},
#   {'word': 'University', 'counts': 1},
#   {'word': 'informed', 'counts': 1},
#   {'word': 'consent', 'counts': 1},
#   {'word': 'obtained', 'counts': 1},
#   {'word': 'participants', 'counts': 1},
#   {'word': 'Box', 'counts': 1},
#   {'word': 'whiskers', 'counts': 1},
#   {'word': 'plots', 'counts': 1},
#   {'word': 'changes', 'counts': 1},
#   {'word': 'plasma', 'counts': 20},
#   {'word': 'concentrations', 'counts': 13},
#   {'word': 'following', 'counts': 1},
#   {'word': 'day', 'counts': 5},
#   {'word': 'onset', 'counts': 11},
#   {'word': 'Normal', 'counts': 1},
#   {'word': 'ranges', 'counts': 3},
#   {'word': 'ng', 'counts': 7},
#   {'word': 'l', 'counts': 9},
#   {'word': 'c', 'counts': 1},
#   {'word': 'd', 'counts': 1},
#   {'word': 'f', 'counts': 1},
#   {'word': 'IFN', 'counts': 14},
#   {'word': 'Significantly', 'counts': 1},
#   {'word': 'elevated', 'counts': 11},
#   {'word': 'compared', 'counts': 2},
#   {'word': 'normal', 'counts': 8},
#   {'word': 'values', 'counts': 2},
#   {'word': 'P', 'counts': 6},
#   {'word': 'Measurement', 'counts': 1},
#   {'word': 'EDTA', 'counts': 1},
#   {'word': 'blood', 'counts': 2},
#   {'word': 'samples', 'counts': 1},
#   {'word': 'collected', 'counts': 1},
#   {'word': 'daily', 'counts': 2},
#   {'word': 'maximum', 'counts': 1},
#   {'word': 'days', 'counts': 7},
#   {'word': 'immersed', 'counts': 1},
#   {'word': 'ice', 'counts': 1},
#   {'word': 'transported', 'counts': 1},
#   {'word': 'immediately', 'counts': 1},
#   {'word': 'laboratory', 'counts': 2},
#   {'word': 'processing', 'counts': 1},
#   {'word': 'Plasma', 'counts': 1},
#   {'word': 'separated', 'counts': 1},
#   {'word': 'centrifugation', 'counts': 1},
#   {'word': 'min', 'counts': 1},
#   {'word': 'stored', 'counts': 1},
#   {'word': 'm', 'counts': 2},
#   {'word': 'aliquots', 'counts': 1},
#   {'word': 'analysis', 'counts': 1},
#   {'word': 'commonly', 'counts': 1},
#   {'word': 'used', 'counts': 2},
#   {'word': 'procedure', 'counts': 1},
#   {'word': 'enzymelinked', 'counts': 1},
#   {'word': 'immunosorbent', 'counts': 1},
#   {'word': 'ELISA', 'counts': 1},
#   {'word': 'generate', 'counts': 1},
#   {'word': 'droplets', 'counts': 1},
#   {'word': 'aerosols', 'counts': 1},
#   {'word': 'measured', 'counts': 4},
#   {'word': 'serially', 'counts': 1},
#   {'word': 'cytometric', 'counts': 1},
#   {'word': 'bead', 'counts': 3},
#   {'word': 'array', 'counts': 2},
#   {'word': 'CBA', 'counts': 4},
#   {'word': 'four', 'counts': 1},
#   {'word': 'colour', 'counts': 1},
#   {'word': 'FACSCalibur', 'counts': 1},
#   {'word': 'flow', 'counts': 2},
#   {'word': 'cytometer', 'counts': 2},
#   {'word': 'Becton', 'counts': 1},
#   {'word': 'Dickinson', 'counts': 1},
#   {'word': 'CA', 'counts': 2},
#   {'word': 'USA', 'counts': 3},
#   {'word': 'located', 'counts': 1},
#   {'word': 'Biosafety', 'counts': 1},
#   {'word': 'Level', 'counts': 1},
#   {'word': 'II', 'counts': 1},
#   {'word': 'five', 'counts': 2},
#   {'word': 'six', 'counts': 1},
#   {'word': 'populations', 'counts': 2},
#   {'word': 'distinct', 'counts': 1},
#   {'word': 'fluorescence', 'counts': 3},
#   {'word': 'intensities', 'counts': 1},
#   {'word': 'coated', 'counts': 1},
#   {'word': 'capturing', 'counts': 1},
#   {'word': 'antibodies', 'counts': 3},
#   {'word': 'different', 'counts': 3},
#   {'word': 'resolved', 'counts': 1},
#   {'word': 'channels', 'counts': 1},
#   {'word': 'beads', 'counts': 3},
#   {'word': 'incubated', 'counts': 1},
#   {'word': 'sample', 'counts': 1},
#   {'word': 'captured', 'counts': 2},
#   {'word': 'corresponding', 'counts': 1},
#   {'word': 'mixed', 'counts': 1},
#   {'word': 'phycoerythrin', 'counts': 1},
#   {'word': 'conjugated', 'counts': 1},
#   {'word': 'form', 'counts': 1},
#   {'word': 'sandwich', 'counts': 1},
#   {'word': 'complexes', 'counts': 2},
#   {'word': 'Following', 'counts': 2},
#   {'word': 'incubation', 'counts': 1},
#   {'word': 'washing', 'counts': 1},
#   {'word': 'acquisition', 'counts': 1},
#   {'word': 'data', 'counts': 2},
#   {'word': 'results', 'counts': 3},
#   {'word': 'generated', 'counts': 1},
#   {'word': 'graphical', 'counts': 1},
#   {'word': 'format', 'counts': 1},
#   {'word': 'BD', 'counts': 2},
#   {'word': 'software', 'counts': 2},
#   {'word': 'regulated', 'counts': 2},
#   {'word': 'upon', 'counts': 1},
#   {'word': 'expressed', 'counts': 2},
#   {'word': 'secreted', 'counts': 1},
#   {'word': 'RANTES', 'counts': 4},
#   {'word': 'monocyte', 'counts': 4},
#   {'word': 'chemoattractant', 'counts': 4},
#   {'word': 'MCP', 'counts': 11},
#   {'word': 'inducible', 'counts': 1},
#   {'word': 'IP', 'counts': 10},
#   {'word': 'monokine', 'counts': 1},
#   {'word': 'MIG', 'counts': 4},
#   {'word': 'human', 'counts': 2},
#   {'word': 'kits', 'counts': 1},
#   {'word': 'Pharmingen', 'counts': 1},
#   {'word': 'respectively', 'counts': 4},
#   {'word': 'sensitivities', 'counts': 1},
#   {'word': 'eight', 'counts': 1},
#   {'word': 'coefficients', 'counts': 1},
#   {'word': 'variation', 'counts': 1},
#   {'word': 'assays', 'counts': 1},
#   {'word': 'less', 'counts': 1},
#   {'word': 'respective', 'counts': 3},
#   {'word': 'derived', 'counts': 1},
#   {'word': 'measurement', 'counts': 2},
#   {'word': 'healthy', 'counts': 1},
#   {'word': 'subjects', 'counts': 1},
#   {'word': 'Because', 'counts': 1},
#   {'word': 'Gaussian', 'counts': 1},
#   {'word': 'distribution', 'counts': 1},
#   {'word': 'Mann', 'counts': 1},
#   {'word': 'Whitney', 'counts': 1},
#   {'word': 'rank', 'counts': 1},
#   {'word': 'sum', 'counts': 1},
#   {'word': 'test', 'counts': 1},
#   {'word': 'assessing', 'counts': 1},
#   {'word': 'differences', 'counts': 1},
#   {'word': 'Results', 'counts': 1},
#   {'word': 'median', 'counts': 3},
#   {'word': 'interquartile', 'counts': 1},
#   {'word': 'range', 'counts': 3},
#   {'word': 'analyses', 'counts': 1},
#   {'word': 'performed', 'counts': 1},
#   {'word': 'Statistical', 'counts': 1},
#   {'word': 'Package', 'counts': 1},
#   {'word': 'Social', 'counts': 1},
#   {'word': 'Sciences', 'counts': 1},
#   {'word': 'SPSS', 'counts': 2},
#   {'word': 'Windows', 'counts': 1},
#   {'word': 'Version', 'counts': 1},
#   {'word': 'Inc', 'counts': 1},
#   {'word': 'probability', 'counts': 1},
#   {'word': 'considered', 'counts': 1},
#   {'word': 'significantly', 'counts': 7},
#   {'word': 'The', 'counts': 2},
#   {'word': 'characteristics', 'counts': 1},
#   {'word': 'summarized', 'counts': 2},
#   {'word': 'Table', 'counts': 2},
#   {'word': 'Coincidentally', 'counts': 1},
#   {'word': 'except', 'counts': 1},
#   {'word': 'one', 'counts': 2},
#   {'word': 'female', 'counts': 2},
#   {'word': 'to', 'counts': 1},
#   {'word': 'male', 'counts': 1},
#   {'word': 'ratio', 'counts': 1},
#   {'word': 'outbreak', 'counts': 1},
#   {'word': 'well', 'counts': 2},
#   {'word': 'None', 'counts': 1},
#   {'word': 'recruited', 'counts': 1},
#   {'word': 'died', 'counts': 1},
#   {'word': 'admission', 'counts': 2},
#   {'word': 'intensive', 'counts': 1},
#   {'word': 'care', 'counts': 1},
#   {'word': 'unit', 'counts': 1},
#   {'word': 'ICU', 'counts': 2},
#   {'word': 'Initial', 'counts': 1},
#   {'word': 'antibiotics', 'counts': 1},
#   {'word': 'cefotaxime', 'counts': 1},
#   {'word': 'clarithromycin', 'counts': 1},
#   {'word': 'levofloxacin', 'counts': 1},
#   {'word': 'cover', 'counts': 1},
#   {'word': 'common', 'counts': 1},
#   {'word': 'pathogens', 'counts': 1},
#   {'word': 'causing', 'counts': 1},
#   {'word': 'community', 'counts': 1},
#   {'word': 'acquired', 'counts': 1},
#   {'word': 'Oseltamivir', 'counts': 1},
#   {'word': 'Tamiflu', 'counts': 1},
#   {'word': 'given', 'counts': 3},
#   {'word': 'initially', 'counts': 1},
#   {'word': 'treat', 'counts': 1},
#   {'word': 'persisted', 'counts': 1},
#   {'word': 'h', 'counts': 2},
#   {'word': 'leukopenia', 'counts': 1},
#   {'word': 'thrombocytopenia', 'counts': 1},
#   {'word': 'oral', 'counts': 2},
#   {'word': 'ribavirin', 'counts': 2},
#   {'word': 'mg', 'counts': 3},
#   {'word': 'kg', 'counts': 2},
#   {'word': 'prednisolone', 'counts': 1},
#   {'word': 'started', 'counts': 1},
#   {'word': 'combined', 'counts': 1},
#   {'word': 'Patients', 'counts': 1},
#   {'word': 'respond', 'counts': 1},
#   {'word': 'clinically', 'counts': 1},
#   {'word': 'standard', 'counts': 1},
#   {'word': 'empirical', 'counts': 1},
#   {'word': 'increasing', 'counts': 1},
#   {'word': 'worsening', 'counts': 2},
#   {'word': 'opacities', 'counts': 2},
#   {'word': 'involving', 'counts': 1},
#   {'word': 'field', 'counts': 1},
#   {'word': 'deteriorating', 'counts': 2},
#   {'word': 'oxygen', 'counts': 1},
#   {'word': 'saturation', 'counts': 1},
#   {'word': 'pulse', 'counts': 1},
#   {'word': 'oximetry', 'counts': 1},
#   {'word': 'intravenous', 'counts': 2},
#   {'word': 'every', 'counts': 1},
#   {'word': 'additional', 'counts': 1},
#   {'word': 'three', 'counts': 2},
#   {'word': 'pulses', 'counts': 1},
#   {'word': 'methylprednisolone', 'counts': 3},
#   {'word': 'sodium', 'counts': 1},
#   {'word': 'succinate', 'counts': 1},
#   {'word': 'longitudinal', 'counts': 2},
#   {'word': 'trends', 'counts': 1},
#   {'word': 'illustrated', 'counts': 1},
#   {'word': 'within', 'counts': 3},
#   {'word': 'first', 'counts': 3},
#   {'word': 'contrast', 'counts': 2},
#   {'word': 'significant', 'counts': 3},
#   {'word': 'increase', 'counts': 5},
#   {'word': 'Anti', 'counts': 1},
#   {'word': 'overall', 'counts': 2},
#   {'word': 'significance', 'counts': 1},
#   {'word': 'low', 'counts': 2},
#   {'word': 'time', 'counts': 1},
#   {'word': 'points', 'counts': 1},
#   {'word': 'CXC', 'counts': 2},
#   {'word': 'chemoattractants', 'counts': 1},
#   {'word': 'namely', 'counts': 1},
#   {'word': 'Among', 'counts': 1},
#   {'word': 'cohort', 'counts': 1},
#   {'word': 'severe', 'counts': 2},
#   {'word': 'additionally', 'counts': 1},
#   {'word': 'pulsed', 'counts': 3},
#   {'word': 'seven', 'counts': 1},
#   {'word': 'milder', 'counts': 1},
#   {'word': 'treated', 'counts': 1},
#   {'word': 'steroid', 'counts': 2},
#   {'word': 'shows', 'counts': 1},
#   {'word': 'former', 'counts': 2},
#   {'word': 'group', 'counts': 2},
#   {'word': 'higher', 'counts': 2},
#   {'word': 'latter', 'counts': 1},
#   {'word': 'particularly', 'counts': 1},
#   {'word': 'recovery', 'counts': 2},
#   {'word': 'levels', 'counts': 2},
#   {'word': 'decreased', 'counts': 1},
#   {'word': 'progressively', 'counts': 1},
#   {'word': 'week', 'counts': 3},
#   {'word': 'groups', 'counts': 1},
#   {'word': 'As', 'counts': 1},
#   {'word': 'reduced', 'counts': 1},
#   {'word': 'pretreatment', 'counts': 1},
#   {'word': 'post', 'counts': 1},
#   {'word': 'lower', 'counts': 1},
#   {'word': 'show', 'counts': 2},
#   {'word': 'difference', 'counts': 1},
#   {'word': 'This', 'counts': 1},
#   {'word': 'designed', 'counts': 1},
#   {'word': 'investigate', 'counts': 2},
#   {'word': 'profile', 'counts': 2},
#   {'word': 'progression', 'counts': 1},
#   {'word': 'potentially', 'counts': 3},
#   {'word': 'lethal', 'counts': 1},
#   {'word': 'represented', 'counts': 1},
#   {'word': 'phases', 'counts': 1},
#   {'word': 'multiplication', 'counts': 1},
#   {'word': 'hyperactive', 'counts': 2},
#   {'word': 'immune', 'counts': 4},
#   {'word': 'destruction', 'counts': 2},
#   {'word': 'death', 'counts': 1},
#   {'word': 'Accordingly', 'counts': 1},
#   {'word': 'worthwhile', 'counts': 1},
#   {'word': 'induction', 'counts': 2},
#   {'word': 'cause', 'counts': 2},
#   {'word': 'consequence', 'counts': 1},
#   {'word': 'hyperactivity', 'counts': 1},
#   {'word': 'observed', 'counts': 4},
#   {'word': 'least', 'counts': 1},
#   {'word': 'weeks', 'counts': 1},
#   {'word': 'exhibited', 'counts': 1},
#   {'word': 'typical', 'counts': 1},
#   {'word': 'moderate', 'counts': 1},
#   {'word': 'act', 'counts': 1},
#   {'word': 'early', 'counts': 3},
#   {'word': 'caused', 'counts': 1},
#   {'word': 'immunodeficiency', 'counts': 1},
#   {'word': 'virus', 'counts': 1},
#   {'word': 'mediation', 'counts': 1},
#   {'word': 'synthesis', 'counts': 1},
#   {'word': 'phase', 'counts': 2},
#   {'word': 'proteins', 'counts': 1},
#   {'word': 'release', 'counts': 3},
#   {'word': 'play', 'counts': 1},
#   {'word': 'role', 'counts': 2},
#   {'word': 'antiinflammatory', 'counts': 1},
#   {'word': 'suppresses', 'counts': 1},
#   {'word': 'secretion', 'counts': 1},
#   {'word': 'followed', 'counts': 2},
#   {'word': 'elevation', 'counts': 6},
#   {'word': 'natural', 'counts': 1},
#   {'word': 'killer', 'counts': 1},
#   {'word': 'NK', 'counts': 4},
#   {'word': 'stimulatory', 'counts': 1},
#   {'word': 'cytotoxic', 'counts': 2},
#   {'word': 'lymphocyte', 'counts': 1},
#   {'word': 'maturation', 'counts': 1},
#   {'word': 'pleiotropic', 'counts': 1},
#   {'word': 'produced', 'counts': 1},
#   {'word': 'primarily', 'counts': 1},
#   {'word': 'antigen', 'counts': 1},
#   {'word': 'presenting', 'counts': 1},
#   {'word': 'monocytes', 'counts': 1},
#   {'word': 'dendritic', 'counts': 1},
#   {'word': 'induce', 'counts': 2},
#   {'word': 'suppression', 'counts': 1},
#   {'word': 'pathway', 'counts': 2},
#   {'word': 'effects', 'counts': 2},
#   {'word': 'ability', 'counts': 1},
#   {'word': 'stimulate', 'counts': 1},
#   {'word': 'cytotoxicity', 'counts': 1},
#   {'word': 'proliferation', 'counts': 1},
#   {'word': 'development', 'counts': 2},
#   {'word': 'subsets', 'counts': 1},
#   {'word': 'A', 'counts': 1},
#   {'word': 'previous', 'counts': 2},
#   {'word': 'suggested', 'counts': 1},
#   {'word': 'infiltration', 'counts': 1},
#   {'word': 'involved', 'counts': 1},
#   {'word': 'pathogenesis', 'counts': 3},
#   {'word': 'injury', 'counts': 3},
#   {'word': 'abundant', 'counts': 1},
#   {'word': 'airspaces', 'counts': 1},
#   {'word': 'secretory', 'counts': 1},
#   {'word': 'products', 'counts': 1},
#   {'word': 'myeloperoxidase', 'counts': 1},
#   {'word': 'elastase', 'counts': 1},
#   {'word': 'bronchoalveolar', 'counts': 1},
#   {'word': 'lavage', 'counts': 1},
#   {'word': 'BAL', 'counts': 5},
#   {'word': 'fluid', 'counts': 4},
#   {'word': 'achemokine', 'counts': 1},
#   {'word': 'spaces', 'counts': 1},
#   {'word': 'exhibit', 'counts': 1},
#   {'word': 'correlation', 'counts': 1},
#   {'word': 'number', 'counts': 1},
#   {'word': 'showed', 'counts': 2},
#   {'word': 'soon', 'counts': 2},
#   {'word': 'declined', 'counts': 1},
#   {'word': 'neutrophilia', 'counts': 1},
#   {'word': 'high', 'counts': 5},
#   {'word': 'counts', 'counts': 1},
#   {'word': 'mortality', 'counts': 1},
#   {'word': 'pneumonitis', 'counts': 1},
#   {'word': 'crucial', 'counts': 1},
#   {'word': 'Apart', 'counts': 1},
#   {'word': 'decline', 'counts': 1},
#   {'word': 'concentration', 'counts': 2},
#   {'word': 'correlating', 'counts': 1},
#   {'word': 'predominance', 'counts': 2},
#   {'word': 'postmortem', 'counts': 1},
#   {'word': 'examination', 'counts': 1},
#   {'word': 'mediated', 'counts': 2},
#   {'word': 'expression', 'counts': 1},
#   {'word': 'up', 'counts': 1},
#   {'word': 'Consistently', 'counts': 1},
#   {'word': 'increased', 'counts': 1},
#   {'word': 'observation', 'counts': 1},
#   {'word': 'similar', 'counts': 1},
#   {'word': 'finding', 'counts': 2},
#   {'word': 'suggest', 'counts': 1},
#   {'word': 'enhance', 'counts': 1},
#   {'word': 'subsequent', 'counts': 1},
#   {'word': 'humoral', 'counts': 1},
#   {'word': 'immue', 'counts': 1},
#   {'word': 'imbalance', 'counts': 1},
#   {'word': 'confirms', 'counts': 1},
#   {'word': 'CoVinduced', 'counts': 1},
#   {'word': 'support', 'counts': 1},
#   {'word': 'therapeutic', 'counts': 2},
#   {'word': 'use', 'counts': 1},
#   {'word': 'monoclonal', 'counts': 1},
#   {'word': 'antibody', 'counts': 1},
#   {'word': 'must', 'counts': 1},
#   {'word': 'cautioned', 'counts': 1},
#   {'word': 'sites', 'counts': 2},
#   {'word': 'Previous', 'counts': 1},
#   {'word': 'studies', 'counts': 1},
#   {'word': 'implicated', 'counts': 1},
#   {'word': 'endogenous', 'counts': 1},
#   {'word': 'pyrogens', 'counts': 1},
#   {'word': 'elevations', 'counts': 1},
#   {'word': 'might', 'counts': 1},
#   {'word': 'account', 'counts': 1},
#   {'word': 'Moreover', 'counts': 1},
#   {'word': 'recruitment', 'counts': 2},
#   {'word': 'activated', 'counts': 1},
#   {'word': 'studied', 'counts': 1},
#   {'word': 'performing', 'counts': 1},
#   {'word': 'differential', 'counts': 1},
#   {'word': 'count', 'counts': 1},
#   {'word': 'fluids', 'counts': 1},
#   {'word': 'difficult', 'counts': 1},
#   {'word': 'risk', 'counts': 1},
#   {'word': 'In', 'counts': 1},
#   {'word': 'summary', 'counts': 1},
#   {'word': 'postulate', 'counts': 1},
#   {'word': 'hyperinnate', 'counts': 1},
#   {'word': 'invasion', 'counts': 1},
#   {'word': 'tract', 'counts': 1},
#   {'word': 'leads', 'counts': 1},
#   {'word': 'accumulation', 'counts': 1},
#   {'word': 'immunity', 'counts': 1},
#   {'word': 'stimulation', 'counts': 1},
#   {'word': 'CTL', 'counts': 1},
#   {'word': 'Treatment', 'counts': 1},
#   {'word': 'immunosuppressive', 'counts': 1},
#   {'word': 'suppress', 'counts': 1},
#   {'word': 'subsequently', 'counts': 1},
#   {'word': 'alleviate', 'counts': 1},
#   {'word': 'Indeed', 'counts': 1},
#   {'word': 'correlated', 'counts': 1},
#   {'word': 'general', 'counts': 1},
#   {'word': 'condition', 'counts': 2},
#   {'word': 'function', 'counts': 1},
#   {'word': 'radiological', 'counts': 1},
#   {'word': 'appearance', 'counts': 1},
#   {'word': 'present', 'counts': 1},
#   {'word': 'addition', 'counts': 2},
#   {'word': 'rapidly', 'counts': 1},
#   {'word': 'basically', 'counts': 1},
#   {'word': 'attenuated', 'counts': 1},
#   {'word': 'exaggerated', 'counts': 1},
#   {'word': 'immunological', 'counts': 2},
#   {'word': 'much', 'counts': 1},
#   {'word': 'supports', 'counts': 1},
#   {'word': 'played', 'counts': 1},
#   {'word': 'impor', 'counts': 1},
#   {'word': 'tant', 'counts': 1},
#   {'word': 'roles', 'counts': 2},
#   {'word': 'immunopathological', 'counts': 1},
#   {'word': 'mechanisms', 'counts': 2},
#   {'word': 'initiated', 'counts': 1},
#   {'word': 'comparing', 'counts': 1},
#   {'word': 'shed', 'counts': 1},
#   {'word': 'light', 'counts': 1},
#   {'word': 'possibility', 'counts': 1},
#   {'word': 'prognostic', 'counts': 2},
#   {'word': 'indicators', 'counts': 1},
#   {'word': 'presence', 'counts': 1},
#   {'word': 'important', 'counts': 1},
#   {'word': 'indicator', 'counts': 1},
#   {'word': 'Although', 'counts': 1},
#   {'word': 'provided', 'counts': 1},
#   {'word': 'understanding', 'counts': 1},
#   {'word': 'many', 'counts': 1},
#   {'word': 'investigations', 'counts': 1},
#   {'word': 'detailed', 'counts': 1},
#   {'word': 'pathophysiology', 'counts': 1},
#   {'word': 'novel', 'counts': 2},
#   {'word': 'emerging', 'counts': 1},
#   {'word': 'global', 'counts': 1},
#   {'word': 'impact', 'counts': 1},
#   {'word': 'order', 'counts': 1},
#   {'word': 'vitro', 'counts': 1},
#   {'word': 'mechanistic', 'counts': 1},
#   {'word': 'eventually', 'counts': 1},
#   {'word': 'local', 'counts': 1},
#   {'word': 'contemplated', 'counts': 1},
#   {'word': 'epithelial', 'counts': 1},
#   {'word': 'peptide', 'counts': 2},
#   {'word': 'ENA', 'counts': 1},
#   {'word': 'macrophage', 'counts': 1},
#   {'word': 'alpha', 'counts': 1},
#   {'word': 'MIP', 'counts': 1},
#   {'word': 'Recently', 'counts': 1},
#   {'word': 'transforming', 'counts': 1},
#   {'word': 'growth', 'counts': 1},
#   {'word': 'TGF', 'counts': 2},
#   {'word': 'active', 'counts': 1},
#   {'word': 'contribute', 'counts': 1},
#   {'word': 'oedema', 'counts': 1},
#   {'word': 'requires', 'counts': 1},
#   {'word': 'investigation', 'counts': 1},
#   {'word': 'Given', 'counts': 1},
#   {'word': 'prominent', 'counts': 1},
#   {'word': 'anticytokine', 'counts': 2},
#   {'word': 'immunotherapy', 'counts': 1},
#   {'word': 'antagonists', 'counts': 1},
#   {'word': 'represent', 'counts': 1},
#   {'word': 'approach', 'counts': 1}],)

# %% [markdown]
# ## Reduce Phase
# After that we flatten the resuls(we get rid of the lists), and we use the foldby method of dask.bag to group properly the intermediate pairs in each partitions.

# %%
# Finally, we sum over all file using the foldby method
# we pass the bag to the foldby after flattening it 
# the method accesses the dictiornaries grouping them with the value associated to the key word
# and the sum the counts of each word
def incr(tot, x):
    return tot + x['counts']

word_count = words.flatten().foldby('word', binop=incr, 
                                      initial=0, combine = lambda x,y: x+y, 
                                      combine_initial=0).compute()
word_count
# Out:
# [('Severe', 160),
#  ('acute', 1843),
#  ('respiratory', 2441),
#  ('syndrome', 1017),
#  ('SARS', 6264),
#  ('recently', 682),
#  ('emerged', 203),
#  ('infectious', 1091),
#  ('disease', 5658),
#  ('characterized', 528),
#  ('persistent', 283),
#  ('fever', 637),
#  ('symptoms', 2146),
#  ('lung', 1673),
#  ('consolidation', 183),
#  ('lymphopenia', 81),
#  ('failure', 828),
#  ('life', 1081),
#  ('threatening', 97),
#  ('cases', 4199),
#  ('Watery', 1),
#  ('diarrhoea', 83),
#  ('manifested', 39),
#  ('found', 3131),
#  ('depletion', 191),
#  ('T', 3416),
#  ('lymphocytes', 434),
#  ('associated', 3485),
#  ('activity', 2674),
#  ('adverse', 475),
#  ('outcomes', 1203),
#  ('related', 2657),
#  ('deaths', 904),
#  ('resulted', 549),
#  ('mainly', 610),
#  ('pulmonary', 749),
#  ('complications', 608),
#  ('including', 3098),
#  ('progressive', 228),
#  ('due', 2711),
#  ('alveolar', 302),
#  ('damage', 624),
#  ('distress', 429),
#  ('ARDS', 399),
#  ('causative', 78),
#  ('agent', 393),
#  ('identified', 1573),
#  ('new', 2219),
#  ('coronavirus', 1311),
#  ('CoV', 5712),
#  ('genome', 673),
#  ('sequence', 1204),
#  ('moderately', 71),
#  ('known', 1363),
#  ('coronaviruses', 334),
#  ('Rapid', 79),
#  ('diagnostic', 575),
#  ('tests', 1017),
#  ('using', 5559),
#  ('molecular', 886),
#  ('techniques', 532),
#  ('detection', 1438),
#  ('RNA', 2212),
#  ('developed', 1356),
#  ('Administration', 83),
#  ('antiviral', 924),
#  ('drug', 1212),
#  ('ribarivin', 1),
#  ('together', 593),
#  ('systemic', 487),
#  ('corticosteroid', 57),
#  ('alleviation', 10),
#  ('inflammation', 757),
#  ('reduction', 1126),
#  ('organ', 395),
#  ('dysfunction', 429),
#  ('improvement', 435),
#  ('survival', 849),
#  ('majority', 591),
#  ('patients', 14536),
#  ('although', 818),
#  ('controlled', 419),
#  ('clinical', 3854),
#  ('trials', 700),
#  ('required', 1250),
#  ('confirm', 251),
#  ('regimen', 300),
#  ('s', 5056),
#  ('genuine', 20),
#  ('efficacy', 709),
#  ('It', 319),
#  ('shown', 2838),
#  ('over', 129),
#  ('production', 1404),
#  ('specific', 2941),
#  ('inflammatory', 1349),
#  ('cytokines', 553),
#  ('tumour', 112),
#  ('necrosis', 171),
#  ('factor', 1204),
#  ('TNF', 271),
#  ('a', 357),
#  ('interleukin', 115),
#  ('IL', 1417),
#  ('b', 1051),
#  ('polymorphonuclear', 20),
#  ('neutrophil', 265),
#  ('PMN', 93),
#  ('CC', 487),
#  ('chemokine', 89),
#  ('hallmark', 38),
#  ('viral', 4275),
#  ('infection', 6062),
#  ('probably', 303),
#  ('activation', 1167),
#  ('transcription', 453),
#  ('nuclear', 411),
#  ('NF', 222),
#  ('k', 134),
#  ('B', 2558),
#  ('activator', 54),
#  ('protein', 3762),
#  ('AP', 181),
#  ('activating', 91),
#  ('ATF', 1),
#  ('example', 1495),
#  ('avian', 218),
#  ('flu', 137),
#  ('influenza', 1461),
#  ('viruses', 2041),
#  ('potent', 252),
#  ('inducers', 19),
#  ('proinflammatory', 166),
#  ('macrophages', 528),
#  ('swine', 104),
#  ('pneumonia', 851),
#  ('correlate', 146),
#  ('positively', 197),
#  ('severity', 916),
#  ('sequalae', 2),
#  ('transendothelial', 2),
#  ('migration', 197),
#  ('tissue', 1014),
#  ('multiple', 1232),
#  ('postulated', 58),
#  ('associate', 47),
#  ('cytokine', 703),
#  ('dysregulation', 67),
#  ('attempt', 152),
#  ('study', 8362),
#  ('possible', 1764),
#  ('induced', 1589),
#  ('identify', 890),
#  ('markers', 389),
#  ('explore', 289),
#  ('feasibility', 131),
#  ('designing', 69),
#  ('effective', 1305),
#  ('treatment', 4064),
#  ('strategy', 646),
#  ('anti', 1678),
#  ('therapy', 1466),
#  ('prospectively', 104),
#  ('investigated', 563),
#  ('panel', 220),
#  ('circulating', 268),
#  ('helper', 83),
#  ('Th', 40),
#  ('cell', 5521),
#  ('chemokines', 107),
#  ('Our', 262),
#  ('included', 1657),
#  ('consecutive', 215),
#  ('adult', 553),
#  ('diagnosed', 369),
#  ('admitted', 377),
#  ('Prince', 5),
#  ('Wales', 28),
#  ('Hospi', 1),
#  ('tal', 4),
#  ('Hong', 143),
#  ('Kong', 142),
#  ('March', 666),
#  ('April', 580),
#  ('accordance', 175),
#  ('World', 305),
#  ('Health', 870),
#  ('Organization', 225),
#  ('case', 2515),
#  ('definition', 257),
#  ('temperature', 805),
#  ('C', 4160),
#  ('chest', 370),
#  ('radiograph', 25),
#  ('computed', 295),
#  ('tomographic', 11),
#  ('image', 363),
#  ('thorax', 34),
#  ('showing', 315),
#  ('evidence', 1583),
#  ('without', 2046),
#  ('e', 4216),
#  ('g', 2659),
#  ('cough', 406),
#  ('shortness', 75),
#  ('breath', 117),
#  ('history', 626),
#  ('close', 547),
#  ('contact', 1127),
#  ('person', 641),
#  ('diagnosis', 1153),
#  ('confirmed', 1296),
#  ('indirect', 314),
#  ('immunofluorescence', 92),
#  ('assay', 1043),
#  ('fetal', 390),
#  ('rhesus', 42),
#  ('kidney', 419),
#  ('cells', 9166),
#  ('infected', 2775),
#  ('fixed', 414),
#  ('acetone', 23),
#  ('detect', 557),
#  ('serological', 116),
#  ('response', 3070),
#  ('positive', 2869),
#  ('culture', 968),
#  ('protocol', 625),
#  ('approved', 477),
#  ('Clinical', 267),
#  ('Research', 350),
#  ('Ethics', 126),
#  ('Committee', 215),
#  ('Chinese', 386),
#  ('University', 502),
#  ('informed', 346),
#  ('consent', 385),
#  ('obtained', 1611),
#  ('participants', 1876),
#  ('Box', 30),
#  ('whiskers', 4),
#  ('plots', 161),
#  ('changes', 1678),
#  ('plasma', 1077),
#  ('concentrations', 718),
#  ('following', 2156),
#  ('day', 2324),
#  ('onset', 750),
#  ('Normal', 62),
#  ('ranges', 164),
#  ('ng', 325),
#  ('l', 1476),
#  ('c', 1484),
#  ('d', 1201),
#  ('f', 791),
#  ('IFN', 1425),
#  ('Significantly', 18),
#  ('elevated', 503),
#  ('compared', 2746),
#  ('normal', 1472),
#  ('values', 1657),
#  ('P', 2750),
#  ('Measurement', 18),
#  ('EDTA', 79),
#  ('blood', 2338),
#  ('samples', 2547),
#  ('collected', 1199),
#  ('daily', 750),
#  ('maximum', 413),
#  ('days', 3045),
#  ('immersed', 18),
#  ('ice', 81),
#  ('transported', 58),
#  ('immediately', 296),
#  ('laboratory', 845),
#  ('processing', 340),
#  ('Plasma', 81),
#  ('separated', 183),
#  ('centrifugation', 145),
#  ('min', 1335),
#  ('stored', 219),
#  ('m', 1116),
#  ('aliquots', 45),
#  ('analysis', 3810),
#  ('commonly', 401),
#  ('used', 5932),
#  ('procedure', 628),
#  ('enzymelinked', 5),
#  ('immunosorbent', 23),
#  ('ELISA', 377),
#  ('generate', 424),
#  ('droplets', 509),
#  ('aerosols', 117),
#  ('measured', 1051),
#  ('serially', 56),
#  ('cytometric', 25),
#  ('bead', 24),
#  ('array', 133),
#  ('CBA', 16),
#  ('four', 1105),
#  ('colour', 47),
#  ('FACSCalibur', 5),
#  ('flow', 673),
#  ('cytometer', 18),
#  ('Becton', 17),
#  ('Dickinson', 19),
#  ('CA', 215),
#  ('USA', 600),
#  ('located', 371),
#  ('Biosafety', 10),
#  ('Level', 59),
#  ('II', 1034),
#  ('five', 761),
#  ('six', 559),
#  ('populations', 658),
#  ('distinct', 446),
#  ('fluorescence', 227),
#  ('intensities', 41),
#  ('coated', 159),
#  ('capturing', 29),
#  ('antibodies', 1440),
#  ('different', 3862),
#  ('resolved', 164),
#  ('channels', 146),
#  ('beads', 72),
#  ('incubated', 522),
#  ('sample', 1652),
#  ('captured', 90),
#  ('corresponding', 659),
#  ('mixed', 385),
#  ('phycoerythrin', 7),
#  ('conjugated', 168),
#  ('form', 1116),
#  ('sandwich', 24),
#  ('complexes', 255),
#  ('Following', 297),
#  ('incubation', 414),
#  ('washing', 129),
#  ('acquisition', 123),
#  ('data', 7044),
#  ('results', 4281),
#  ('generated', 687),
#  ('graphical', 115),
#  ('format', 145),
#  ('BD', 78),
#  ('software', 382),
#  ('regulated', 244),
#  ('upon', 649),
#  ('expressed', 868),
#  ('secreted', 145),
#  ('RANTES', 19),
#  ('monocyte', 66),
#  ('chemoattractant', 25),
#  ('MCP', 72),
#  ('inducible', 63),
#  ('IP', 52),
#  ('monokine', 3),
#  ('MIG', 9),
#  ('human', 3176),
#  ('kits', 65),
#  ('Pharmingen', 3),
#  ('respectively', 1835),
#  ('sensitivities', 19),
#  ('eight', 284),
#  ('coefficients', 135),
#  ('variation', 507),
#  ('assays', 571),
#  ('less', 1875),
#  ('respective', 212),
#  ('derived', 912),
#  ('measurement', 339),
#  ('healthy', 730),
#  ('subjects', 1087),
#  ('Because', 53),
#  ('Gaussian', 133),
#  ('distribution', 1110),
#  ('Mann', 93),
#  ('Whitney', 75),
#  ('rank', 189),
#  ('sum', 159),
#  ('test', 2262),
#  ('assessing', 202),
#  ('differences', 1274),
#  ('Results', 947),
#  ('median', 1260),
#  ('interquartile', 59),
#  ('range', 1750),
#  ('analyses', 816),
#  ('performed', 2366),
#  ('Statistical', 154),
#  ('Package', 7),
#  ('Social', 139),
#  ('Sciences', 99),
#  ('SPSS', 114),
#  ('Windows', 15),
#  ('Version', 40),
#  ('Inc', 121),
#  ('probability', 495),
#  ('considered', 1560),
#  ('significantly', 1923),
#  ('The', 4676),
#  ('characteristics', 822),
#  ('summarized', 233),
#  ('Table', 3085),
#  ('Coincidentally', 3),
#  ('except', 287),
#  ('one', 4854),
#  ('female', 402),
#  ('to', 656),
#  ('male', 480),
#  ('ratio', 970),
#  ('outbreak', 930),
#  ('well', 3673),
#  ('None', 438),
#  ('recruited', 152),
#  ('died', 447),
#  ('admission', 662),
#  ('intensive', 383),
#  ('care', 2908),
#  ('unit', 453),
#  ('ICU', 626),
#  ('Initial', 71),
#  ('antibiotics', 285),
#  ('cefotaxime', 2),
#  ('clarithromycin', 8),
#  ('levofloxacin', 9),
#  ('cover', 147),
#  ('common', 1396),
#  ('pathogens', 556),
#  ('causing', 258),
#  ('community', 918),
#  ('acquired', 304),
#  ('Oseltamivir', 17),
#  ('Tamiflu', 10),
#  ('given', 1576),
#  ('initially', 299),
#  ('treat', 335),
#  ('persisted', 64),
#  ('h', 1510),
#  ('leukopenia', 16),
#  ('thrombocytopenia', 76),
#  ('oral', 721),
#  ('ribavirin', 165),
#  ('mg', 1463),
#  ('kg', 951),
#  ('prednisolone', 18),
#  ('started', 337),
#  ('combined', 507),
#  ('Patients', 602),
#  ('respond', 246),
#  ('clinically', 335),
#  ('standard', 1105),
#  ('empirical', 158),
#  ('increasing', 850),
#  ('worsening', 105),
#  ('opacities', 150),
#  ('involving', 321),
#  ('field', 690),
#  ('deteriorating', 22),
#  ('oxygen', 472),
#  ('saturation', 152),
#  ('pulse', 88),
#  ('oximetry', 18),
#  ('intravenous', 166),
#  ('every', 597),
#  ('additional', 1031),
#  ('three', 2545),
#  ('pulses', 26),
#  ('methylprednisolone', 26),
#  ('sodium', 161),
#  ('succinate', 6),
#  ('longitudinal', 119),
#  ('trends', 191),
#  ('illustrated', 116),
#  ('within', 2424),
#  ('first', 3443),
#  ('contrast', 821),
#  ('significant', 2847),
#  ('increase', 2259),
#  ('Anti', 80),
#  ('overall', 865),
#  ('significance', 351),
#  ('low', 2296),
#  ('time', 6044),
#  ('points', 628),
#  ('CXC', 7),
#  ('chemoattractants', 12),
#  ('namely', 206),
#  ('Among', 419),
#  ('cohort', 695),
#  ('severe', 2385),
#  ('additionally', 67),
#  ('pulsed', 29),
#  ('seven', 359),
#  ('milder', 42),
#  ('treated', 1437),
#  ('steroid', 98),
#  ('shows', 975),
#  ('former', 140),
#  ('group', 3554),
#  ('higher', 2982),
#  ('latter', 354),
#  ('particularly', 804),
#  ('recovery', 518),
#  ('levels', 3063),
#  ('decreased', 815),
#  ('progressively', 72),
#  ('week', 683),
#  ('groups', 2052),
#  ('As', 394),
#  ('reduced', 1341),
#  ('pretreatment', 75),
#  ('post', 1258),
#  ('lower', 2092),
#  ('show', 1095),
#  ('difference', 1029),
#  ('This', 475),
#  ('designed', 531),
#  ('investigate', 393),
#  ('profile', 316),
#  ('progression', 470),
#  ('potentially', 603),
#  ('lethal', 113),
#  ('represented', 293),
#  ('phases', 168),
#  ('multiplication', 34),
#  ('hyperactive', 15),
#  ('immune', 1952),
#  ('destruction', 74),
#  ('death', 1167),
#  ('Accordingly', 94),
#  ('worthwhile', 16),
#  ('induction', 394),
#  ('cause', 1097),
#  ('consequence', 232),
#  ('hyperactivity', 7),
#  ('observed', 2686),
#  ('least', 1197),
#  ('weeks', 1063),
#  ('exhibited', 192),
#  ('typical', 294),
#  ('moderate', 455),
#  ('act', 253),
#  ('early', 1709),
#  ('caused', 857),
#  ('immunodeficiency', 88),
#  ('virus', 5580),
#  ('mediation', 54),
#  ('synthesis', 568),
#  ('phase', 1119),
#  ('proteins', 1976),
#  ('release', 505),
#  ('play', 555),
#  ('role', 1948),
#  ('antiinflammatory', 14),
#  ('suppresses', 31),
#  ('secretion', 235),
#  ('followed', 1014),
#  ('elevation', 102),
#  ('natural', 707),
#  ('killer', 54),
#  ('NK', 327),
#  ('stimulatory', 37),
#  ('cytotoxic', 155),
#  ('lymphocyte', 299),
#  ('maturation', 128),
#  ('pleiotropic', 20),
#  ('produced', 643),
#  ('primarily', 289),
#  ('antigen', 886),
#  ('presenting', 232),
#  ('monocytes', 126),
#  ('dendritic', 89),
#  ('induce', 455),
#  ('suppression', 148),
#  ('pathway', 614),
#  ('effects', 2116),
#  ('ability', 882),
#  ('stimulate', 107),
#  ('cytotoxicity', 191),
#  ('proliferation', 355),
#  ('development', 1735),
#  ('subsets', 108),
#  ('A', 1564),
#  ('previous', 1149),
#  ('suggested', 757),
#  ('infiltration', 128),
#  ('involved', 1028),
#  ('pathogenesis', 367),
#  ('injury', 854),
#  ('abundant', 142),
#  ('airspaces', 6),
#  ('secretory', 58),
#  ('products', 739),
#  ('myeloperoxidase', 8),
#  ('elastase', 24),
#  ('bronchoalveolar', 54),
#  ('lavage', 107),
#  ('BAL', 127),
#  ('fluid', 439),
#  ('achemokine', 1),
#  ('spaces', 181),
#  ('exhibit', 223),
#  ('correlation', 772),
#  ('number', 4086),
#  ('showed', 2273),
#  ('soon', 141),
#  ('declined', 86),
#  ('neutrophilia', 11),
#  ('high', 4446),
#  ('counts', 286),
#  ('mortality', 1760),
#  ('pneumonitis', 31),
#  ('crucial', 331),
#  ('Apart', 74),
#  ('decline', 251),
#  ('concentration', 990),
#  ('correlating', 14),
#  ('predominance', 38),
#  ('postmortem', 14),
#  ('examination', 361),
#  ('mediated', 825),
#  ('expression', 2531),
#  ('up', 985),
#  ('Consistently', 19),
#  ('increased', 2582),
#  ('observation', 366),
#  ('similar', 1983),
#  ('finding', 448),
#  ('suggest', 1017),
#  ('enhance', 315),
#  ('subsequent', 538),
#  ('humoral', 137),
#  ('immue', 1),
#  ('imbalance', 50),
#  ('confirms', 51),
#  ('CoVinduced', 1),
#  ('support', 1516),
#  ('therapeutic', 648),
#  ('use', 3547),
#  ('monoclonal', 230),
#  ('antibody', 1801),
#  ('must', 862),
#  ('cautioned', 7),
#  ('sites', 797),
#  ('Previous', 201),
#  ('studies', 4097),
#  ('implicated', 139),
#  ('endogenous', 171),
#  ('pyrogens', 2),
#  ('elevations', 58),
#  ('might', 1691),
#  ('account', 543),
#  ('Moreover', 834),
#  ('recruitment', 215),
#  ('activated', 435),
#  ('studied', 752),
#  ('performing', 171),
#  ('differential', 344),
#  ('count', 457),
#  ('fluids', 105),
#  ('difficult', 607),
#  ('risk', 4158),
#  ('In', 1964),
#  ('summary', 323),
#  ('postulate', 13),
#  ('hyperinnate', 1),
#  ('invasion', 133),
#  ('tract', 506),
#  ('leads', 438),
#  ('accumulation', 222),
#  ('immunity', 590),
#  ('stimulation', 335),
#  ('CTL', 72),
#  ('Treatment', 165),
#  ('immunosuppressive', 157),
#  ('suppress', 89),
#  ('subsequently', 325),
#  ('alleviate', 48),
#  ('Indeed', 294),
#  ('correlated', 492),
#  ('general', 1172),
#  ('condition', 670),
#  ('function', 1836),
#  ('radiological', 137),
#  ('appearance', 190),
#  ('present', 2102),
#  ('addition', 1875),
#  ('rapidly', 516),
#  ('basically', 19),
#  ('attenuated', 199),
#  ('exaggerated', 39),
#  ('immunological', 153),
#  ('much', 894),
#  ('supports', 139),
#  ('played', 67),
#  ('impor', 3),
#  ('tant', 2),
#  ('roles', 268),
#  ('immunopathological', 6),
#  ('mechanisms', 840),
#  ('initiated', 157),
#  ('comparing', 238),
#  ('shed', 101),
#  ('light', 425),
#  ('possibility', 438),
#  ('prognostic', 226),
#  ('indicators', 182),
#  ('presence', 1406),
#  ('important', 2538),
#  ('indicator', 146),
#  ('Although', 1213),
#  ('provided', 1116),
#  ('understanding', 583),
#  ('many', 2096),
#  ('investigations', 192),
#  ('detailed', 358),
#  ('pathophysiology', 88),
#  ('novel', 813),
#  ('emerging', 298),
#  ('global', 963),
#  ('impact', 1611),
#  ('order', 1525),
#  ('vitro', 798),
#  ('mechanistic', 49),
#  ('eventually', 138),
#  ('local', 1057),
#  ('contemplated', 3),
#  ('epithelial', 330),
#  ('peptide', 445),
#  ('ENA', 1),
#  ('macrophage', 182),
#  ('alpha', 212),
#  ('MIP', 11),
#  ('Recently', 236),
#  ('transforming', 46),
#  ('growth', 1319),
#  ('TGF', 64),
#  ('active', 878),
#  ('contribute', 547),
#  ('oedema', 31),
#  ('requires', 485),
#  ('investigation', 346),
#  ('Given', 387),
#  ('prominent', 204),
#  ('anticytokine', 2),
#  ('immunotherapy', 83),
#  ('antagonists', 38),
#  ('represent', 572),
#  ('approach', 1472),
#  ('Porcine', 24),
#  ('epidemic', 960),
#  ('diarrhea', 226),
#  ('PED', 20),
#  ('highly', 1147),
#  ('contagious', 90),
#  ('enteric', 131),
#  ('enteritis', 25),
#  ('vomiting', 108),
#  ('watery', 23),
#  ('piglets', 163),
#  ('Ducatelle', 1),
#  ('al', 5005),
#  ('causes', 493),
#  ('economic', 778),
#  ('loss', 824),
#  ('raising', 59),
#  ('countries', 1502),
#  ('prevalence', 648),
#  ('rare', 258),
#  ('incidence', 928),
#  ('transmissible', 66),
#  ('gastroenteritis', 61),
#  ('TGE', 42),
#  ('asymptomatic', 517),
#  ('rotavirus', 113),
#  ('RV', 131),
#  ('infections', 2014),
#  ('Carvajal', 1),
#  ('porcine', 178),
#  ('PEDV', 335),
#  ('belongs', 59),
#  ('family', 1084),
#  ('Coronaviridae', 32),
#  ('reported', 3554),
#  ('Pensaert', 6),
#  ('de', 3805),
#  ('Bouck', 1),
#  ('enveloped', 98),
#  ('possessing', 25),
#  ('single', 1360),
#  ('stranded', 121),
#  ('sense', 357),
#  ('approximately', 627),
#  ('kb', 83),
#  ('size', 1501),
#  ('cap', 80),
#  ('polyadenylated', 8),
#  ('tail', 73),
#  ('comprises', 66),
#  ('untranslated', 17),
#  ('region', 1002),
#  ('UTR', 79),
#  ('open', 531),
#  ('reading', 156),
#  ('frames', 96),
#  ('ORFs', 47),
#  ('encode', 51),
#  ('structural', 511),
#  ('intestinal', 293),
#  ('target', 1131),
#  ('established', 608),
#  ('IEC', 28),
#  ('line', 857),
#  ('stably', 24),
#  ('express', 199),
#  ('N', 2070),
#  ('subcellular', 37),
#  ('localization', 158),
#  ('examining', 95),
#  ('cycle', 429),
#  ('localizes', 14),
#  ('endoplasmic', 47),
#  ('reticulum', 51),
#  ('ER', 281),
#  ('inhibits', 226),
#  ('prolongs', 8),
#  ('S', 1390),
#  ('prolonged', 231),
#  ('decrease', 807),
#  ('cyclin', 33),
#  ('level', 2548),
#  ('degradation', 221),
#  ('expressing', 359),
#  ('control', 2728),
#  ('induces', 226),
#  ('stress', 1118),
#  ('activates', 99),
#  ('kB', 51),
#  ('responsible', 518),
#  ('upregulation', 115),
#  ('Bcl', 22),
#  ('report', 950),
#  ('demonstrate', 366),
#  ('prolongation', 92),
#  ('regulation', 469),
#  ('findings', 1415),
#  ('provide', 1550),
#  ('information', 2358),
#  ('likely', 1570),
#  ('useful', 564),
#  ('ß', 12),
#  ('Elsevier', 11),
#  ('V', 723),
#  ('rights', 352),
#  ('reserved', 223),
#  ('spike', 470),
#  ('envelope', 137),
#  ('E', 1132),
#  ('kDa', 147),
#  ('membrane', 753),
#  ('M', 1468),
#  ('nucleocapsid', 96),
#  ('non', 2670),
#  ('replicases', 1),
#  ('arranged', 151),
#  ('replicase', 49),
#  ('Song', 33),
#  ('Park', 66),
#  ('Kocherhans', 1),
#  ('Yeo', 2),
#  ('binds', 238),
#  ('virion', 70),
#  ('provides', 608),
#  ('basis', 495),
#  ('helical', 15),
#  ('accurate', 309),
#  ('epitopes', 352),
#  ('Curtis', 4),
#  ('Saif', 14),
#  ('date', 541),
#  ('exists', 202),
#  ('IECs', 9),
#  ('targeted', 358),
#  ('gut', 352),
#  ('serve', 261),
#  ('physical', 990),
#  ('barrier', 193),
#  ('restricts', 18),
#  ('movement', 232),
#  ('components', 482),
#  ('passage', 84),
#  ('harmful', 80),
#  ('microorganisms', 131),
#  ('lumen', 62),
#  ('underlying', 508),
#  ('mucosa', 113),
#  ('Schierack', 1),
#  ('regulates', 101),
#  ('uncovered', 21),
#  ('stage', 749),
#  ('implications', 253),
#  ('economically', 31),
#  ('pEGFP', 14),
#  ('eukaryotic', 62),
#  ('vector', 482),
#  ('purchased', 118),
#  ('Clontech', 6),
#  ('Escherichia', 66),
#  ('coli', 227),
#  ('cloning', 52),
#  ('Tiangen', 1),
#  ('Biotech', 31),
#  ('China', 1250),
#  ('Shaanxi', 3),
#  ('strain', 723),
#  ('isolated', 686),
#  ('contents', 76),
#  ('Province', 100),
#  ('gene', 1478),
#  ('amplified', 138),
#  ('described', 1620),
#  ('previously', 1194),
#  ('Honglei', 2),
#  ('lines', 492),
#  ('kindly', 26),
#  ('Prof', 16),
#  ('Yan', 20),
#  ('Ming', 4),
#  ('Zhang', 148),
#  ('College', 92),
#  ('Veterinary', 25),
#  ('Medicine', 170),
#  ('Northwest', 5),
#  ('F', 683),
#  ('cultured', 335),
#  ('Jing', 4),
#  ('Briefly', 139),
#  ('grown', 147),
#  ('Dulbecco', 38),
#  ('modified', 350),
#  ('eagle', 4),
#  ('medium', 593),
#  ('DMEM', 115),
#  ('Gibco', 39),
#  ('BRL', 9),
#  ('Gaithersburg', 7),
#  ('MD', 114),
#  ('supplemented', 158),
#  ('heat', 135),
#  ('inactivated', 185),
#  ('born', 158),
#  ('calf', 122),
#  ('serum', 1312),
#  ('IU', 72),
#  ('penicillin', 71),
#  ('streptomycin', 47),
#  ('per', 1697),
#  ('mL', 784),
#  ('CO', 246),
#  ('atmosphere', 42),
#  ('incubator', 40),
#  ('Mouse', 28),
#  ('actin', 97),
#  ('Santa', 24),
#  ('Cruz', 31),
#  ('Biotechnology', 29),
#  ('GFP', 166),
#  ('Millipore', 38),
#  ('Temecula', 1),
#  ('Horseradish', 4),
#  ('peroxidase', 71),
#  ('HRP', 117),
#  ('secondary', 758),
#  ('Pierce', 27),
#  ('Rockford', 10),
#  ('proteasome', 23),
#  ('inhibitor', 513),
#  ('Calbiochem', 8),
#  ('San', 85),
#  ('Diego', 28),
#  ('staining', 276),
#  ('dye', 52),
#  ('Tracker', 14),
#  ('TM', 59),
#  ('Red', 59),
#  ('probe', 246),
#  ('Invitrogen', 114),
#  ('Carlsbad', 26),
#  ('primers', 215),
#  ('amplify', 43),
#  ('follows', 451),
#  ('forward', 205),
#  ('primer', 218),
#  ('XhoI', 10),
#  ('CCGCTCGA', 1),
#  ('GATGGCTTCTGTCAGCTTTCA', 1),
#  ('reverse', 321),
#  ('Hind', 3),
#  ('III', 429),
#  ...]

# %% [markdown]
# Finally we sort the resulting list and we plot the results.

# %%
# Sort by the counts in descendent order
word_count_ordered = sorted(word_count, key = lambda x: x[1], reverse=True)

word_count_ordered
# Out:
# [('patients', 14536),
#  ('COVID', 9729),
#  ('cells', 9166),
#  ('study', 8362),
#  ('data', 7044),
#  ('SARS', 6264),
#  ('infection', 6062),
#  ('time', 6044),
#  ('used', 5932),
#  ('CoV', 5712),
#  ('disease', 5658),
#  ('virus', 5580),
#  ('using', 5559),
#  ('cell', 5521),
#  ('s', 5056),
#  ('al', 5005),
#  ('will', 5004),
#  ('one', 4854),
#  ('The', 4676),
#  ('two', 4646),
#  ('high', 4446),
#  ('results', 4281),
#  ('viral', 4275),
#  ('model', 4246),
#  ('e', 4216),
#  ('cases', 4199),
#  ('C', 4160),
#  ('risk', 4158),
#  ('studies', 4097),
#  ('number', 4086),
#  ('treatment', 4064),
#  ('health', 4022),
#  ('based', 3987),
#  ('p', 3943),
#  ('different', 3862),
#  ('clinical', 3854),
#  ('analysis', 3810),
#  ('de', 3805),
#  ('protein', 3762),
#  ('well', 3673),
#  ('group', 3554),
#  ('reported', 3554),
#  ('use', 3547),
#  ('associated', 3485),
#  ('first', 3443),
#  ('T', 3416),
#  ('n', 3367),
#  ('patient', 3294),
#  ('human', 3176),
#  ('found', 3131),
#  ('including', 3098),
#  ('Table', 3085),
#  ('response', 3070),
#  ('levels', 3063),
#  ('days', 3045),
#  ('higher', 2982),
#  ('specific', 2941),
#  ('system', 2934),
#  ('care', 2908),
#  ('positive', 2869),
#  ('pandemic', 2865),
#  ('significant', 2847),
#  ('shown', 2838),
#  ('age', 2835),
#  ('infected', 2775),
#  ('P', 2750),
#  ('compared', 2746),
#  ('control', 2728),
#  ('rate', 2714),
#  ('due', 2711),
#  ('observed', 2686),
#  ('activity', 2674),
#  ('non', 2670),
#  ('g', 2659),
#  ('related', 2657),
#  ('increased', 2582),
#  ('years', 2568),
#  ('B', 2558),
#  ('level', 2548),
#  ('samples', 2547),
#  ('three', 2545),
#  ('important', 2538),
#  ('expression', 2531),
#  ('case', 2515),
#  ('respiratory', 2441),
#  ('available', 2425),
#  ('within', 2424),
#  ('research', 2392),
#  ('severe', 2385),
#  ('performed', 2366),
#  ('information', 2358),
#  ('blood', 2338),
#  ('day', 2324),
#  ('effect', 2307),
#  ('low', 2296),
#  ('showed', 2273),
#  ('test', 2262),
#  ('increase', 2259),
#  ('t', 2247),
#  ('potential', 2236),
#  ('population', 2229),
#  ('new', 2219),
#  ('RNA', 2212),
#  ('people', 2201),
#  ('social', 2189),
#  ('total', 2184),
#  ('following', 2156),
#  ('symptoms', 2146),
#  ('effects', 2116),
#  ('children', 2110),
#  ('present', 2102),
#  ('many', 2096),
#  ('lower', 2092),
#  ('factors', 2078),
#  ('N', 2070),
#  ('groups', 2052),
#  ('without', 2046),
#  ('viruses', 2041),
#  ('among', 2017),
#  ('infections', 2014),
#  ('work', 1990),
#  ('similar', 1983),
#  ('type', 1982),
#  ('proteins', 1976),
#  ('In', 1964),
#  ('immune', 1952),
#  ('role', 1948),
#  ('significantly', 1923),
#  ('participants', 1876),
#  ('less', 1875),
#  ('addition', 1875),
#  ('negative', 1859),
#  ('period', 1852),
#  ('acute', 1843),
#  ('function', 1836),
#  ('respectively', 1835),
#  ('antibody', 1801),
#  ('and', 1793),
#  ('large', 1785),
#  ('la', 1777),
#  ('possible', 1764),
#  ('mortality', 1760),
#  ('host', 1752),
#  ('range', 1750),
#  ('mean', 1750),
#  ('development', 1735),
#  ('i', 1733),
#  ('binding', 1723),
#  ('value', 1713),
#  ('early', 1709),
#  ('per', 1697),
#  ('might', 1691),
#  ('method', 1690),
#  ('vaccine', 1690),
#  ('anti', 1678),
#  ('changes', 1678),
#  ('lung', 1673),
#  ('included', 1657),
#  ('values', 1657),
#  ('sample', 1652),
#  ('need', 1651),
#  ('models', 1651),
#  ('individuals', 1646),
#  ('small', 1637),
#  ('described', 1620),
#  ('obtained', 1611),
#  ('impact', 1611),
#  ('several', 1596),
#  ('induced', 1589),
#  ('evidence', 1583),
#  ('public', 1581),
#  ('transmission', 1579),
#  ('given', 1576),
#  ('set', 1576),
#  ('process', 1576),
#  ('identified', 1573),
#  ('likely', 1570),
#  ('A', 1564),
#  ('considered', 1560),
#  ('result', 1553),
#  ('conditions', 1551),
#  ('provide', 1550),
#  ('made', 1535),
#  ('o', 1529),
#  ('order', 1525),
#  ('months', 1523),
#  ('preprint', 1520),
#  ('support', 1516),
#  ('h', 1510),
#  ('hospital', 1508),
#  ('countries', 1502),
#  ('size', 1501),
#  ('PCR', 1499),
#  ('example', 1495),
#  ('even', 1485),
#  ('c', 1484),
#  ('medical', 1480),
#  ('gene', 1478),
#  ('l', 1476),
#  ('normal', 1472),
#  ('approach', 1472),
#  ('M', 1468),
#  ('therapy', 1466),
#  ('mg', 1463),
#  ('influenza', 1461),
#  ('y', 1458),
#  ('antibodies', 1440),
#  ('detection', 1438),
#  ('treated', 1437),
#  ('IFN', 1425),
#  ('IL', 1417),
#  ('findings', 1415),
#  ('D', 1415),
#  ('mice', 1411),
#  ('presence', 1406),
#  ('production', 1404),
#  ('long', 1400),
#  ('common', 1396),
#  ('S', 1390),
#  ('diseases', 1388),
#  ('vs', 1383),
#  ('en', 1373),
#  ('DNA', 1371),
#  ('known', 1363),
#  ('single', 1360),
#  ('developed', 1356),
#  ('inflammatory', 1349),
#  ('reduced', 1341),
#  ('cancer', 1340),
#  ('genes', 1338),
#  ('min', 1335),
#  ('state', 1331),
#  ('whether', 1321),
#  ('growth', 1319),
#  ('acid', 1317),
#  ('responses', 1315),
#  ('serum', 1312),
#  ('coronavirus', 1311),
#  ('individual', 1309),
#  ('change', 1307),
#  ('effective', 1305),
#  ('measures', 1304),
#  ('methods', 1297),
#  ('confirmed', 1296),
#  ('testing', 1296),
#  ('der', 1293),
#  ('current', 1287),
#  ('second', 1287),
#  ('include', 1284),
#  ('review', 1276),
#  ('differences', 1274),
#  ('dose', 1274),
#  ('L', 1272),
#  ('year', 1264),
#  ('detected', 1263),
#  ('median', 1260),
#  ('post', 1258),
#  ('training', 1251),
#  ('required', 1250),
#  ('China', 1250),
#  ('see', 1248),
#  ('either', 1247),
#  ('primary', 1247),
#  ('animals', 1234),
#  ('multiple', 1232),
#  ('Although', 1213),
#  ('drug', 1212),
#  ('complex', 1211),
#  ('sequence', 1204),
#  ('factor', 1204),
#  ('outcomes', 1203),
#  ('d', 1201),
#  ('collected', 1199),
#  ('least', 1197),
#  ('limited', 1197),
#  ('previously', 1194),
#  ('water', 1184),
#  ('term', 1183),
#  ('general', 1172),
#  ('surface', 1171),
#  ('exposure', 1170),
#  ('ml', 1170),
#  ('via', 1169),
#  ('activation', 1167),
#  ('death', 1167),
#  ('outcome', 1154),
#  ('diagnosis', 1153),
#  ('systems', 1153),
#  ('previous', 1149),
#  ('various', 1149),
#  ('highly', 1147),
#  ('major', 1145),
#  ('future', 1143),
#  ('often', 1140),
#  ('structure', 1135),
#  ('E', 1132),
#  ('target', 1131),
#  ('management', 1131),
#  ('across', 1131),
#  ('contact', 1127),
#  ('reduction', 1126),
#  ('die', 1123),
#  ('areas', 1121),
#  ('license', 1120),
#  ('rates', 1120),
#  ('phase', 1119),
#  ('part', 1119),
#  ('stress', 1118),
#  ('m', 1116),
#  ('form', 1116),
#  ('provided', 1116),
#  ('chronic', 1112),
#  ('distribution', 1110),
#  ('area', 1110),
#  ('species', 1109),
#  ('received', 1107),
#  ('four', 1105),
#  ('standard', 1105),
#  ('liver', 1105),
#  ('times', 1101),
#  ('point', 1099),
#  ('spread', 1099),
#  ('cause', 1097),
#  ('or', 1097),
#  ('show', 1095),
#  ('better', 1095),
#  ('und', 1095),
#  ('infectious', 1091),
#  ('X', 1091),
#  ('subjects', 1087),
#  ('receptor', 1086),
#  ('family', 1084),
#  ('life', 1081),
#  ('plasma', 1077),
#  ('average', 1077),
#  ('initial', 1075),
#  ('demonstrated', 1070),
#  ('critical', 1067),
#  ('tested', 1065),
#  ('recent', 1064),
#  ('weeks', 1063),
#  ('variables', 1059),
#  ('site', 1059),
#  ('local', 1057),
#  ('features', 1054),
#  ('b', 1051),
#  ('measured', 1051),
#  ('defined', 1050),
#  ('score', 1047),
#  ('assay', 1043),
#  ('presented', 1038),
#  ('II', 1034),
#  ('greater', 1034),
#  ('Thus', 1033),
#  ('additional', 1031),
#  ('difference', 1029),
#  ('involved', 1028),
#  ('pre', 1025),
#  ('seen', 1025),
#  ('follow', 1018),
#  ('syndrome', 1017),
#  ('tests', 1017),
#  ('suggest', 1017),
#  ('determined', 1016),
#  ('learning', 1016),
#  ('tissue', 1014),
#  ('followed', 1014),
#  ('prior', 1013),
#  ('H', 1012),
#  ('still', 1006),
#  ('region', 1002),
#  ('reduce', 1002),
#  ('version', 1002),
#  ('medRxiv', 1000),
#  ('according', 999),
#  ('main', 995),
#  ('concentration', 990),
#  ('physical', 990),
#  ('up', 985),
#  ('experience', 983),
#  ('particular', 982),
#  ('healthcare', 979),
#  ('infants', 979),
#  ('interaction', 978),
#  ('quality', 976),
#  ('shows', 975),
#  ('proposed', 975),
#  ('free', 971),
#  ('ratio', 970),
#  ('culture', 968),
#  ('direct', 967),
#  ('global', 963),
#  ('epidemic', 960),
#  ('especially', 958),
#  ('x', 955),
#  ('One', 952),
#  ('sequences', 952),
#  ('kg', 951),
#  ('report', 950),
#  ('activities', 949),
#  ('domain', 949),
#  ('Results', 947),
#  ('thus', 942),
#  ('performance', 942),
#  ('knowledge', 934),
#  ('analyzed', 933),
#  ('replication', 931),
#  ('outbreak', 930),
#  ('dependent', 929),
#  ('incidence', 928),
#  ('antiviral', 924),
#  ('way', 923),
#  ('world', 922),
#  ('community', 918),
#  ('severity', 916),
#  ('end', 914),
#  ('We', 913),
#  ('derived', 912),
#  ('terms', 911),
#  ('deaths', 904),
#  ('author', 904),
#  ('determine', 899),
#  ('able', 897),
#  ('much', 894),
#  ('drugs', 892),
#  ('identify', 890),
#  ('conducted', 890),
#  ('molecular', 886),
#  ('antigen', 886),
#  ('ability', 882),
#  ('CI', 879),
#  ('active', 878),
#  ('weight', 878),
#  ('sensitivity', 871),
#  ('Health', 870),
#  ('evaluated', 870),
#  ('tumor', 870),
#  ('expressed', 868),
#  ('complete', 867),
#  ('air', 866),
#  ('overall', 865),
#  ('help', 863),
#  ('types', 863),
#  ('must', 862),
#  ('O', 860),
#  ('caused', 857),
#  ('line', 857),
#  ('cellular', 856),
#  ('containing', 855),
#  ('home', 855),
#  ('injury', 854),
#  ('doi', 853),
#  ('independent', 852),
#  ('parameters', 852),
#  ('pneumonia', 851),
#  ('events', 851),
#  ('increasing', 850),
#  ('survival', 849),
#  ('key', 846),
#  ('laboratory', 845),
#  ('safety', 843),
#  ('status', 842),
#  ('mechanisms', 840),
#  ('Furthermore', 838),
#  ('network', 837),
#  ('Moreover', 834),
#  ('relative', 834),
#  ('https', 834),
#  ('body', 833),
#  ('display', 829),
#  ('failure', 828),
#  ('self', 828),
#  ('el', 828),
#  ('mechanism', 826),
#  ('authors', 826),
#  ('mediated', 825),
#  ('loss', 824),
#  ('applied', 823),
#  ('characteristics', 822),
#  ('contrast', 821),
#  ('full', 819),
#  ('although', 818),
#  ('analyses', 816),
#  ('decreased', 815),
#  ('novel', 813),
#  ('selected', 812),
#  ('pressure', 811),
#  ('affected', 811),
#  ('decrease', 807),
#  ('another', 807),
#  ('staff', 806),
#  ('temperature', 805),
#  ('G', 805),
#  ('particularly', 804),
#  ('lack', 801),
#  ('essential', 799),
#  ('vitro', 798),
#  ('best', 798),
#  ('sites', 797),
#  ('u', 795),
#  ('f', 791),
#  ('design', 790),
#  ('interactions', 789),
#  ('indicated', 786),
#  ('lead', 786),
#  ('regions', 786),
#  ('particles', 785),
#  ('stem', 785),
#  ('mL', 784),
#  ('needed', 781),
#  ('economic', 778),
#  ('intervention', 776),
#  ('correlation', 772),
#  ('around', 772),
#  ('resulting', 771),
#  ('real', 771),
#  ('association', 770),
#  ('revealed', 765),
#  ('access', 764),
#  ('five', 761),
#  ('students', 759),
#  ('secondary', 758),
#  ('inflammation', 757),
#  ('suggested', 757),
#  ('los', 756),
#  ('membrane', 753),
#  ('studied', 752),
#  ('RT', 752),
#  ('services', 752),
#  ('workers', 751),
#  ('whereas', 751),
#  ('onset', 750),
#  ('daily', 750),
#  ('pulmonary', 749),
#  ('stage', 749),
#  ('fact', 748),
#  ('resources', 747),
#  ('food', 746),
#  ('necessary', 746),
#  ('rapid', 746),
#  ('co', 745),
#  ('others', 744),
#  ('relevant', 742),
#  ('trial', 740),
#  ('products', 739),
#  ('good', 738),
#  ('hours', 738),
#  ('animal', 738),
#  ('baseline', 737),
#  ('expected', 737),
#  ('controls', 735),
#  ('adults', 734),
#  ('I', 734),
#  ('vaccines', 733),
#  ('healthy', 730),
#  ('become', 729),
#  ('literature', 728),
#  ('estimated', 727),
#  ('org', 727),
#  ('strains', 727),
#  ('make', 725),
#  ('added', 724),
#  ('V', 723),
#  ('strain', 723),
#  ('mouse', 723),
#  ('oral', 721),
#  ('context', 721),
#  ('source', 721),
#  ('paper', 720),
#  ('criteria', 720),
#  ('resistance', 719),
#  ('concentrations', 718),
#  ('scale', 715),
#  ('assessed', 714),
#  ('environment', 713),
#  ('now', 713),
#  ('procedures', 711),
#  ('CT', 711),
#  ('reports', 711),
#  ('improve', 711),
#  ('efficacy', 709),
#  ('energy', 709),
#  ('solution', 708),
#  ('illness', 708),
#  ('country', 708),
#  ('natural', 707),
#  ('old', 706),
#  ('cross', 704),
#  ('Methods', 704),
#  ('cytokine', 703),
#  ('copyright', 703),
#  ('hand', 702),
#  ('assess', 702),
#  ('calculated', 701),
#  ('problem', 701),
#  ('trials', 700),
#  ('assessment', 697),
#  ('evaluation', 697),
#  ('amino', 697),
#  ('women', 697),
#  ('variable', 696),
#  ('directly', 696),
#  ('MERS', 696),
#  ('develop', 696),
#  ('cohort', 695),
#  ('media', 694),
#  ('leading', 694),
#  ('suggests', 694),
#  ('means', 693),
#  ('granted', 693),
#  ('volume', 692),
#  ('frequency', 692),
#  ('α', 692),
#  ('field', 690),
#  ('humans', 689),
#  ('needs', 689),
#  ('indicate', 688),
#  ('generated', 687),
#  ('isolated', 686),
#  ('heart', 686),
#  ('relationship', 685),
#  ('importance', 685),
#  ('appropriate', 684),
#  ('combination', 684),
#  ('week', 683),
#  ('F', 683),
#  ('recently', 682),
#  ('HIV', 682),
#  ('practice', 682),
#  ('mild', 680),
#  ('RBD', 678),
#  ('final', 677),
#  ('screening', 677),
#  ('funder', 677),
#  ('short', 676),
#  ('genome', 673),
#  ('flow', 673),
#  ('condition', 670),
#  ('mental', 668),
#  ('numbers', 668),
#  ('pattern', 667),
#  ('March', 666),
#  ('que', 666),
#  ('strategies', 665),
#  ('admission', 662),
#  ('interest', 661),
#  ('Finally', 661),
#  ('corresponding', 659),
#  ('already', 659),
#  ('populations', 658),
#  ('rather', 657),
#  ('to', 656),
#  ('approaches', 656),
#  ('series', 655),
#  ('consistent', 653),
#  ('upon', 649),
#  ('increases', 649),
#  ('therapeutic', 648),
#  ('prevalence', 648),
#  ('making', 648),
#  ('influence', 648),
#  ('signaling', 647),
#  ('collection', 647),
#  ('fold', 647),
#  ('strategy', 646),
#  ('us', 645),
#  ('produced', 643),
#  ('last', 643),
#  ('distance', 642),
#  ('J', 642),
#  ('person', 641),
#  ('comparison', 641),
#  ('online', 640),
#  ('measure', 639),
#  ('psychological', 639),
#  ('fever', 637),
#  ('reaction', 637),
#  ('course', 637),
#  ('members', 637),
#  ('in', 636),
#  ('experiments', 634),
#  ('taken', 634),
#  ('des', 634),
#  ('mass', 633),
#  ('bacterial', 633),
#  ('HSCT', 633),
#  ('affect', 632),
#  ('perpetuity', 632),
#  ('holder', 630),
#  ('evaluate', 630),
#  ('procedure', 628),
#  ('points', 628),
#  ('approximately', 627),
#  ('nature', 627),
#  ('history', 626),
#  ('ICU', 626),
#  ('To', 626),
#  ('protocol', 625),
#  ('damage', 624),
#  ('International', 623),
#  ('improved', 623),
#  ('experimental', 623),
#  ('pts', 621),
#  ('images', 619),
#  ('administration', 617),
#  ('proportion', 616),
#  ('education', 615),
#  ('pathway', 614),
#  ('cardiac', 614),
#  ('duration', 614),
#  ('IgG', 614),
#  ('remains', 613),
#  ('pro', 612),
#  ('suggesting', 612),
#  ('protective', 611),
#  ('posted', 611),
#  ('lockdown', 611),
#  ('mainly', 610),
#  ('larger', 610),
#  ('protection', 609),
#  ('complications', 608),
#  ('established', 608),
#  ('provides', 608),
#  ('difficult', 607),
#  ('patterns', 607),
#  ('working', 606),
#  ('U', 606),
#  ('vaccination', 606),
#  ('later', 604),
#  ('program', 604),
#  ('published', 604),
#  ('potentially', 603),
#  ('prevent', 603),
#  ('behavior', 603),
#  ('Patients', 602),
#  ('USA', 600),
#  ('relatively', 600),
#  ('like', 599),
#  ('β', 599),
#  ('cost', 599),
#  ('every', 597),
#  ('survey', 597),
#  ('brain', 597),
#  ('absence', 597),
#  ('transplantation', 596),
#  ('processes', 595),
#  ('functions', 595),
#  ('occur', 595),
#  ('together', 593),
#  ('medium', 593),
#  ('occurred', 592),
#  ('majority', 591),
#  ('currently', 591),
#  ('structures', 591),
#  ('dental', 591),
#  ('immunity', 590),
#  ('scores', 590),
#  ('trauma', 588),
#  ('step', 587),
#  ('families', 587),
#  ('mutations', 587),
#  ('side', 586),
#  ('Data', 585),
#  ('regarding', 584),
#  ('understanding', 583),
#  ('length', 583),
#  ('delivery', 583),
#  ('load', 582),
#  ('formation', 582),
#  ('fi', 581),
#  ('April', 580),
#  ('properties', 580),
#  ('young', 580),
#  ('along', 579),
#  ('diagnostic', 575),
#  ('selection', 574),
#  ('right', 573),
#  ('represent', 572),
#  ('challenge', 572),
#  ('surgery', 572),
#  ('assays', 571),
#  ('bone', 571),
#  ('capacity', 569),
#  ('clear', 569),
#  ('synthesis', 568),
#  ('strong', 568),
#  ('crisis', 567),
#  ('noted', 566),
#  ('biological', 566),
#  ('useful', 564),
#  ('investigated', 563),
#  ('peak', 563),
#  ('examined', 561),
#  ('predicted', 561),
#  ('require', 561),
#  ('take', 561),
#  ('government', 560),
#  ('six', 559),
#  ('degree', 559),
#  ('functional', 558),
#  ('subject', 558),
#  ('detect', 557),
#  ('third', 557),
#  ('pathogens', 556),
#  ('emergency', 556),
#  ('play', 555),
#  ('million', 555),
#  ('anxiety', 555),
#  ('amount', 555),
#  ('article', 555),
#  ('residues', 555),
#  ('face', 554),
#  ('consider', 554),
#  ('cytokines', 553),
#  ('adult', 553),
#  ('existing', 553),
#  ('se', 553),
#  ('HCV', 553),
#  ('index', 551),
#  ('re', 550),
#  ('genetic', 550),
#  ('resulted', 549),
#  ('agents', 549),
#  ('usually', 549),
#  ('close', 547),
#  ('contribute', 547),
#  ('exposed', 547),
#  ('estimate', 547),
#  ('limit', 546),
#  ('allow', 546),
#  ('position', 545),
#  ('problems', 545),
#  ('isolation', 545),
#  ('donor', 545),
#  ('pH', 545),
#  ('developing', 544),
#  ('interventions', 544),
#  ('account', 543),
#  ('regression', 543),
#  ('mM', 542),
#  ('pain', 542),
#  ('accuracy', 542),
#  ('United', 542),
#  ('date', 541),
#  ('inhibition', 541),
#  ('next', 541),
#  ('highest', 539),
#  ('subsequent', 538),
#  ('environmental', 536),
#  ('power', 535),
#  ('un', 535),
#  ('focus', 534),
#  ('prediction', 534),
#  ('issues', 533),
#  ('techniques', 532),
#  ('v', 532),
#  ('designed', 531),
#  ('open', 531),
#  ('allowed', 530),
#  ('pathways', 530),
#  ('decision', 529),
#  ('characterized', 528),
#  ('macrophages', 528),
#  ('material', 528),
#  ('whole', 527),
#  ('linked', 527),
#  ('feature', 526),
#  ('entry', 525),
#  ('attention', 523),
#  ('poor', 523),
#  ('action', 523),
#  ('peer', 523),
#  ('incubated', 522),
#  ('pathogen', 522),
#  ('inhibitors', 522),
#  ('surgical', 521),
#  ('setting', 520),
#  ('class', 520),
#  ('recovery', 518),
#  ('responsible', 518),
#  ('asymptomatic', 517),
#  ('density', 517),
#  ('items', 517),
#  ('rapidly', 516),
#  ('susceptible', 515),
#  ('represents', 514),
#  ('challenges', 514),
#  ('inhibitor', 513),
#  ('bacteria', 513),
#  ('situation', 513),
#  ('space', 513),
#  ('older', 513),
#  ('done', 513),
#  ('statistical', 512),
#  ('structural', 511),
#  ('mRNA', 511),
#  ('GVHD', 511),
#  ('generally', 510),
#  ('alternative', 510),
#  ('Introduction', 510),
#  ('droplets', 509),
#  ('personal', 509),
#  ('versus', 509),
#  ('underlying', 508),
#  ('section', 508),
#  ('variation', 507),
#  ('combined', 507),
#  ('left', 507),
#  ('tract', 506),
#  ('longer', 506),
#  ('release', 505),
#  ('guidelines', 505),
#  ('molecules', 505),
#  ('achieved', 504),
#  ('elevated', 503),
#  ('University', 502),
#  ('yet', 501),
#  ('application', 500),
#  ('carried', 499),
#  ('understand', 499),
#  ('tissues', 499),
#  ('vivo', 499),
#  ('exercise', 497),
#  ('forms', 497),
#  ('tool', 496),
#  ('generation', 496),
#  ('probability', 495),
#  ('basis', 495),
#  ('enzyme', 495),
#  ('specificity', 494),
#  ('causes', 493),
#  ('led', 493),
#  ('correlated', 492),
#  ('lines', 492),
#  ('alone', 492),
#  ('UK', 492),
#  ('room', 492),
#  ('signal', 489),
#  ('monitoring', 489),
#  ('antigens', 489),
#  ('remain', 488),
#  ('systemic', 487),
#  ('CC', 487),
#  ('requires', 485),
#  ('bias', 485),
#  ('external', 485),
#  ('Two', 485),
#  ('hospitals', 484),
#  ('discussed', 484),
#  ('con', 484),
#  ('components', 482),
#  ('vector', 482),
#  ('estimates', 482),
#  ('receptors', 482),
#  ('sources', 482),
#  ('male', 480),
#  ('questions', 479),
#  ('transplant', 479),
#  ('includes', 478),
#  ('traditional', 478),
#  ('approved', 477),
#  ('team', 477),
#  ('place', 477),
#  ('dataset', 477),
#  ('chain', 477),
#  ('certain', 476),
#  ('states', 476),
#  ('adverse', 475),
#  ('This', 475),
#  ('far', 475),
#  ('protease', 474),
#  ('w', 474),
#  ('stable', 473),
#  ('oxygen', 472),
#  ('called', 471),
#  ('providing', 471),
#  ('transport', 471),
#  ('dynamics', 471),
#  ('progression', 470),
#  ('spike', 470),
#  ('algorithm', 470),
#  ('cardiovascular', 470),
#  ('regulation', 469),
#  ('unique', 469),
#  ('signs', 469),
#  ('product', 468),
#  ('find', 467),
#  ('frequently', 467),
#  ('technology', 465),
#  ('basic', 465),
#  ('linear', 465),
#  ('ensure', 463),
#  ('diabetes', 462),
#  ('unknown', 462),
#  ('month', 461),
#  ('question', 460),
#  ('titers', 460),
#  ('cultures', 459),
#  ('national', 459),
#  ('US', 458),
#  ...]

# %% [markdown]
# ## Graphical Representation of the Results

# %%
from matplotlib.ticker import MultipleLocator

def top_words(sorted_list, n):
    
    bars = [sorted_list[i][0] for i in range(0, n)]
    values = [sorted_list[i][1] for i in range(0, n)]
    
    y = np.arange(n)
    
    fig, ax = plt.subplots(figsize=(16, int(n*0.45)))
    
    # Plot
    ax.grid(True, color = "lightsteelblue")
    ax.barh(bars, values, color = "mediumseagreen") # horizontal barplot (barh)
    ax.set_axisbelow(True)
    ax.xaxis.set_minor_locator(MultipleLocator(1000))
    ax.grid(True, "minor", linestyle="--", color = "lightsteelblue")

top_words(word_count_ordered, 10)

# %%
dd = {key: value for (key, value) in word_count}
wcloud = WordCloud(max_words = 80, width=1600, height=800).generate_from_frequencies(dd)
fig, ax = plt.subplots(figsize = (15, 15))
_ = ax.imshow(wcloud)

# %%
client.close()

# %% [markdown]
# ## Timing

# %%
def timing(partitions):
    # Make client
    client = Client('10.67.22.190:8786')
    # Register start time
    start = time.time()
    
    # Load data and repartition
    filename = os.path.join('data', 'json_singleline', '*.json')
    lines = db.read_text(filename)

    # Algorithm
    word_count = (lines.map(json.loads).pluck('body_text').repartition(partitions)
                       .map(merge_text).map(clean_func)
                       .map(count_words).flatten()
                       .foldby('word', binop = incr, 
                               initial = 0, combine = lambda x,y: x+y, 
                               combine_initial = 0).compute())
    
    word_count_ordered = sorted(word_count, key = lambda x: x[1], reverse = True)
    
    # Register end time
    end = time.time()
    
    # Close client
    client.close()
    
    return end-start

# %% [markdown]
# ### Algorithm used to compute the timings
# The following algorithm has been used to compute the computation time as a function of the number of workers and partitions. For each fixed number of workers, we create a cluster from the terminal and iterate on the different number of partitions. Then, we save the results in order to visualize them.
#
# Notice that there exists a way to create a distributed cluster with a chosen number of workers directly from Python, but a bug makes that cluster impossible to be closed from Python itself. This is why we couldn't iterate on the number of workers in a loop, but we had to create the cluster manually for every iteration.

# %%
if TIMING:
    # Number of workers
    workers = [8]
    # Partitions factor
    partitions = [1, 2, 4, 16, 32, 128, 400]
    # Partitions
    timings = np.zeros((len(workers),len(partitions)))
    # Printing timings
    for w_i, w in enumerate(workers):
        for p_i, p in enumerate(partitions):
            timings[w_i][p_i] = timing(p * w)
            print("nw: ", w, " partitions: ", p * w, " time [s]: ", timings[w_i][p_i])

    # Saving timings
    with open("times_words/words_08.npy", "wb") as f:
        np.save(f, timings)

# %% [markdown]
# Heatmap of execution times when varying the number of partitions per workers and number of workers.

# %%
directory_path = './times_words/'

file_type = 'npy'
files=sorted([file for file in os.listdir(directory_path) if file.split('.')[-1]== file_type])

np_tot=np.zeros((len(files), 7) ) 
workers=[]

for i,file in enumerate(files ):
    np_tot[i,:]=np.load(directory_path+file)
    workers.append(int(file.split('_')[1].split('.')[0]) )

# %%
# Create a dataframe of timing results
df_timings = pd.DataFrame(np_tot.T,[1, 2, 4, 16, 32, 128, 400], workers)#,, partitions, workers)
# Heatmap
plt.figure(figsize=(10, 6.8))
sn.set(font_scale=1) # for label size
sn.heatmap(data=df_timings, annot=True, fmt=".3f",
               cmap=sn.dark_palette("mediumseagreen", reverse=True, as_cmap=True)
              )
plt.xlabel('workers',fontsize=16)
plt.ylabel('partitions/workers',fontsize=16)
plt.title("Execution time [s]", fontsize=20)
plt.show()
plt.style.use('default')

# %% [markdown]
# # 2. Most Productive Countries and Universities
# In this section we figure out the countries and the universities that are most and less active in the research. <br>
# We start by initializing a **Client** and pointing it to the address of one previously chosen Virtual Machine, that acts as Scheduler.

# %%
client = Client('10.67.22.190:8786')
client
# Out:
# /usr/lib/python3.6/site-packages/distributed/client.py:1134: VersionMismatchWarning: Mismatched versions found
#
# +---------+---------------+---------------+------------------------------------+
# | Package | client        | scheduler     | workers                            |
# +---------+---------------+---------------+------------------------------------+
# | python  | 3.6.8.final.0 | 3.6.8.final.0 | {'3.6.8.final.0', '3.6.5.final.0'} |
# +---------+---------------+---------------+------------------------------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tcp://10.67.22.190:8786' processes=8 threads=32, memory=65.61 GB>

# %% [markdown]
# We read the json as Dask Bag object. This is needed for us to call operations in parallel.

# %%
# Load the data
filename = os.path.join('data', 'json_singleline', '*.json')
lines = db.read_text(filename)  # we read as a bag
js = lines.map(json.loads)

# %% [markdown]
# We extract the list of authors for each document

# %%
# Pluck 'metadata' and then 'authors'
authors = js.pluck('metadata').pluck('authors')
authors.take(1)
# Out:
# ([{'first': 'W',
#    'middle': ['K'],
#    'last': 'Lam',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'C',
#    'middle': ['K'],
#    'last': 'Wong',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'C',
#    'middle': ['W K'],
#    'last': 'Lam',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'A',
#    'middle': ['K L'],
#    'last': 'Wu',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'W',
#    'middle': ['K'],
#    'last': 'Ip',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'N',
#    'middle': ['L S'],
#    'last': 'Lee',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'I',
#    'middle': ['H S'],
#    'last': 'Chan',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'L',
#    'middle': ['C W'],
#    'last': 'Lit',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'D',
#    'middle': ['S C'],
#    'last': 'Hui',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'M',
#    'middle': ['H M'],
#    'last': 'Chan',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'S',
#    'middle': ['S C'],
#    'last': 'Chung',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''},
#   {'first': 'J',
#    'middle': ['J Y'],
#    'last': 'Sung',
#    'suffix': '',
#    'affiliation': {},
#    'email': ''}],)

# %% [markdown]
# This function takes as argument one record and returns a dictionary with informations on the author in the record: *name*, *surname*, *University*, *Laboratory* and *Country*. <br>
# We have to pay attention for the last three fields: for example, we may not have any information about them in the record. In this case, we use a placeholder value, i.e. a string "Unknown". <br>
# Another problem is the presence of more ways to represent one Country in the record. For that, we chose to unify all representations of one Country into one that is the same for everyone, and we chose to do a similar thing also for cases in which we didn't have the original Country's name, e.g. Austria. <br>
# For example, The United Kingdom is found in the record as "UK", "U.K", or "UK A R". In this case, the Country field in the returned dictionary will be "United Kingdom".

# %%
# Flatten information of the authors
def flatten(record):
    
    uni = loc = lab = "Unknown"
    
    affiliation_keys = record['affiliation'].keys()
    
    if 'location' in affiliation_keys: # check location
        loc = record['affiliation']['location'].get("country", "Unknown")
    
    if 'institution' in affiliation_keys: # check institution
        uni = record['affiliation'].get("institution", "Unknown")
    
    if 'laboratory' in affiliation_keys: # check laboratory
        lab = record['affiliation'].get("laboratory", "Unknown") 
        
    if uni == "":
#         print("Warning: empty uni found")
        uni = "Unknown"
    if loc == "":
#         print("Warning: empty loc found")
        loc = "Unknown"
    if lab == "":
#         print("Warning: empty lab found")
        lab = "Unknown"
        
    # Some problems: 
    if loc in {'PR China', 'P.R. China', "People's Republic of China",'P. R. China'}: loc = "China"
            
    elif loc in {"UK","U.K", "UK A R"}: loc = "United Kingdom"
        
    elif loc in {"United States of America", "United States", "U.S.A", "U.S.A."} : loc = "USA"
        
    elif loc == "the Netherlands" : loc = "The Netherlands"
        
    elif loc == "Deutschland" : loc = "Germany"
        
    elif loc == "Republic of Korea" : loc = "Korea"

    elif loc == "10 Austria" : loc = "Austria"
        
    elif loc == "France 15" : loc = "France"
        
    elif loc == "Russian" : loc = "Russia"    
    
    return {
        'name':       record['first'],
        'surname':    record['last'], 
        'University': uni,
        'Laboratory': lab,
        'Country':    loc,
    }

# #check that the flatten function works as wanted 
authors.repartition(100).flatten().map(flatten).filter(lambda record: 
                                            tokenizer.tokenize(record["Country"]) == 
                                            word_tokenize(record["Country"], 
                                                          language = 'english')).take(1)
# Out:
# ({'name': 'W',
#   'surname': 'Lam',
#   'University': 'Unknown',
#   'Laboratory': 'Unknown',
#   'Country': 'Unknown'},)

# %% [markdown]
# We construct a dataframe in which each row contains information about one author. We specify the type of each column to improve the performance.

# %%
# Convert dataset to dataframe
authors_df = (authors.repartition(100)
              .flatten().map(flatten)
              .filter(lambda record: tokenizer.tokenize(record["Country"]) == 
                      word_tokenize(record["Country"], language = 'english'))
              .to_dataframe(meta = {"name": str, "surname": str, "University": str, 
                                    "Laboratory": str, "Country": str}))

authors_df.tail()
# Out:
#         name   surname                               University Laboratory  \
# 82    Hajime     Senjo  Hokkaido University Faculty of medicine    Unknown
# 83    Kasumi  Hayasaka             Hokkaido University Hospital    Unknown
# 84   Satoshi     Konno  Hokkaido University Faculty of medicine    Unknown
# 85   Mutsumi   Nishida             Hokkaido University Hospital    Unknown
# 86  Takanori   Teshima  Hokkaido University Faculty of medicine    Unknown
#
#    Country
# 82   Japan
# 83   Japan
# 84   Japan
# 85   Japan
# 86   Japan

# %% [markdown]
# Some countries present punctuation, due to the fact that the authors are not of the same country. We remove them comparing the output of two tokenizer: one that considers the punctuation and the other that skips them.

# %% [markdown]
# ## Countries <br>
# In the next cell we compute the number of occurrences for each Country, obtaining a Series object that shows which Countries are more/less productive. The persist() function keeps the data in the RAM of the workers, avoiding the overhead caused by sending the data to the workers each time we need to analyze them. In this case, we call it because we will use **countries** multiple times in the following cells. Notice that the persist() command does not do anything until we trigger it: in our case, it will be triggered the first time we call the "plott" function.

# %%
countries = authors_df.Country.value_counts().persist()

# %% [markdown]
# Next function takes as arguments a Series object and eventually some option parameters. According to passed parameters, it prints or plots most/less productive Countries. <br>
# Parameters: <br>
# *small*: boolean to decide if printing/plotting most or least productive Countries <br>
# *small_univ*: boolean to check strange names <br>
# *top_univ*: boolean used to decide if we want to plot universities or countries

# %%
def plott(data, n=10, small=False, small_univ=False, top_univ=False):
    if small == False:
        data = data.nlargest(n+1).compute()
        data = data[data.axes[0] != 'Unknown']  # try to comment to say something about the unknown
    
    elif small_univ==False:
        # here we delete (a posteriori) some strange names
        data = data[data==1].compute()
        data = data[data.axes[0] != 'China-Japan, China']
        data = data[data.axes[0] != 'University']
        low = [c for c in data.axes[0]]
        print("The less productive countries are:\n")
        for c in low: print("-", c)
        return
    
    else:
        data = data[data==1].compute()[:n]
        low = [c for c in data.axes[0]]
        print("{0} of the less productive universities are:\n".format(n))
        for c in low: print("-", c)
        return
    
    height = [data[i] for i in range(0, n)]
    bars = [data.axes[0][i] for i in range(0, n)]
    
    fig, ax = plt.subplots(figsize=(16, int(n)*0.4))
    
    # Plot
    if top_univ==False:
        ax.set_title("The most productive countries", size = 16)
    else:
        ax.set_title("The most productive universities", size = 16)
        
    ax.barh(bars, height[:n], color = "mediumseagreen")
    ax.grid(True, color = "lightsteelblue", linestyle="--")
    ax.set_axisbelow(True)
    ax.tick_params(labelsize=16)
    if max(height) > 200:
        ax.xaxis.set_minor_locator(MultipleLocator(20))
    else:
        ax.xaxis.set_minor_locator(MultipleLocator(1))

# %%
plott(countries, small=True)
# Out:
# The less productive countries are:
#
# - Kenya
# - UAE
# - Bahrain
# - Panama
# - Slovakia
# - Cuba
# - Qatar A R
# - Norway
# - Indonesia
# - Lao PDR
# - Österreich

# %%
plott(countries, 10)

# %% [markdown]
# ## Timing
# Function to time the computation of the 10 most productive countries, given the number of partitions

# %%
def get_time_countries(partitions):
    
    # Make client
    client = Client('10.67.22.190:8786')
    # Register start time
    start = time.time() 
    
    # Load data and repartition
    filename = os.path.join('data', 'json_singleline', '*.json')
    lines = db.read_text(filename)
    

    authors_df = (lines.map(json.loads)
                    .pluck('metadata').pluck('authors').repartition(partitions)
                    .flatten().map(flatten).filter(lambda record: 
                                                   tokenizer.tokenize(record["Country"]) == 
                                                   word_tokenize(record["Country"], 
                                                                 language = 'english'))
                    .to_dataframe())
    
    countries = authors_df.Country.value_counts().nlargest(10).compute()
    
    end = time.time()
    client.close() #close client
    return end - start

# %% [markdown]
# Compute and save the timings

# %%
if False:
    # Number of workers
    workers = [5]
    # Partitions factor
    partitions = [1, 2, 4, 16, 32, 64, 128] 

    times_countries = np.zeros((len(workers),len(partitions))) 

    for w in range(len(workers)):
        for p in range(len(partitions)):
            times_countries[w][p] = get_time_countries(partitions[p]*workers[w])
            print("nw: ", workers[w], " partitions: ", partitions[p]*workers[w], " time [s]: ", times_countries[w][p])

    with open("times_countries/countries_05.npy", "wb") as f:
        np.save(f, times_countries)

# %% [markdown]
# Heatmap of execution times when varying the number of partitions per workers and number of workers.

# %%
directory_path = './times_countries/'

file_type = 'npy'
files=sorted([file for file in os.listdir(directory_path) if file.split('.')[-1]== file_type])

np_tot=np.zeros((len(files), 7) ) 
workers=[]

for i,file in enumerate(files ):
    np_tot[i,:]=np.load(directory_path+file)
    workers.append(int(file.split('_')[1].split('.')[0]) )

#     print(file)

# %%
# Create a dataframe of timing results
df_timings = pd.DataFrame(np_tot.T,[1, 2, 4, 16, 32, 64, 128],workers)#,, partitions, workers)
# Heatmap
plt.figure(figsize=(10, 6.8))
sn.set(font_scale=1) # for label size
sn.heatmap(data=df_timings, annot=True, fmt=".3f",
               cmap=sn.dark_palette("mediumseagreen", reverse=True, as_cmap=True)
              )
plt.xlabel('workers',fontsize=16)
plt.ylabel('partitions/workers',fontsize=16)
plt.title("Execution time [s]", fontsize=20)
plt.show()
plt.style.use('default')

# %% [markdown]
# ## Universities <br>
# In the next cell we compute the number of occurrences for each University, obtaining a Series object that shows which Universities are more/less productive.

# %%
univs = (authors.repartition(100).
         flatten().map(flatten).
         to_dataframe(meta = {"name": str, "surname": str, "University": str, 
                                "Laboratory": str, "Country": str})
         .University.value_counts().persist())

# %%
plott(univs, 20, small=True, small_univ=True)
# Out:
# 20 of the less productive universities are:
#
# - Hackensack University Medical Center
# - Hallym University College of Medicine
# - Hamadan University of Medical Sciences
# - Zhongshan City People's Hospital
# - IT University
# - Hallym University college of Medicine
# - Université Paris Descartes
# - Hamad Medical Corporation (HMC)
# - Alexandria University
# - Hadassah-Hebrew University Medical Center
# - A. Manzoni Hospital
# - ISGlobal, Hospital Clínic-Universitat de Barcelona
# - ISPRA
# - IRCCS Mondino Foundation
# - -Hospital Sírio Libanês
# - Alessandro Manzoni Hospital
# - & College of Pharmacy
# - Acharya Institute of Technology
# - Harold and Muriel Block Institute for Clinical and Translational Research
# - IPS CardioDajud

# %%
plott(univs, 20, top_univ = True)

# %% [markdown]
# ## Timing
# Function to time the computation of the 10 most productive universities, given the number of partitions

# %%
def get_time_univs(partitions):

    client = Client('10.67.22.190:8786')
    
    start = time.time()
    
    filename = os.path.join('data', 'json_singleline', '*.json')
    lines = db.read_text(filename)
    
    authors_df = (lines.map(json.loads)
                    .pluck('metadata').pluck('authors').repartition(partitions)
                    .flatten().map(flatten)
                    .to_dataframe())
    
    univs = authors_df.University.value_counts().nlargest(10).compute()
    
    end = time.time()
    client.close() #close client
    return end-start

# %% [markdown]
# Compute and save the timings

# %%
if False:
    # Number of workers
    workers = [10]
    # Partitions factor
    partitions = [1, 2, 4, 16, 32, 64, 128] 

    times_univ = np.zeros((len(workers),len(partitions))) 

    for w in range(len(workers)):
        for p in range(len(partitions)):
            times_univ[w][p] = get_time_univs(partitions[p]*workers[w])
            print("nw: ", workers[w], " partitions: ", partitions[p]*workers[w], 
                  " time [s]: ", times_univ[w][p])
    with open("times_univs/univs_10.npy", "wb") as f:
        np.save(f, times_univ)

# %% [markdown]
# Heatmap of execution times when varying the number of partitions per workers and number of workers.

# %%
directory_path = './times_univs/'

file_type = 'npy'
files=sorted([file for file in os.listdir(directory_path) if file.split('.')[-1]== file_type])

np_tot=np.zeros((len(files), 7) ) 
workers=[]

for i,file in enumerate(files ):
    np_tot[i,:]=np.load(directory_path+file)
    workers.append(int(file.split('_')[1].split('.')[0]) )

#     print(file)

# %%
# Create a dataframe of timing results
df_timings = pd.DataFrame(np_tot.T,[1, 2, 4, 16, 32, 64, 128],workers)#,, partitions, workers)
# Heatmap
plt.figure(figsize=(10, 6.8))
sn.set(font_scale=1) # for label size
sn.heatmap(data=df_timings, annot=True, fmt=".3f",
               cmap=sn.dark_palette("mediumseagreen", reverse=True, as_cmap=True)
              )
plt.xlabel('workers',fontsize=16)
plt.ylabel('partitions/workers',fontsize=16)
plt.title("Execution time [s]", fontsize=20)
plt.show()
plt.style.use('default')

# %%
client.close()

# %% [markdown]
# ## Comment on the timings
# All the previous heatmaps about the timings show that both the workers and the partitions should not be neither too many nor too few.
#
# As far as the partitions, their size should fit comfortably in memory but also not be too many, since every operation on every partition takes the central scheduler a few hundred microseconds to process. Moreover, having too many partitions means that a lot of chunks of data has to be transmitted through the cluster and this cause a lot of overhead.
#
# As far as the workers, having more than one worker is good to distribute the code, but too many of them can cause overhead too, since the workers have to exchange data between each other and this operation takes a lot of time if the workers are too many. Another consideration that we can do about this aspect, is that it is not sensible to use a number of workers that is higher than the number of cores we have in our cluster, since the workers are supposed to execute tasks in parallel: looking at the heatmaps indeed, we can see that the computation time starts increasing when we set a number of workers greater than 8, that is the number of cores we have in our cluster.

# %% [markdown]
# # 3. Embedding for the title of the papers

# %% [markdown]
# In NLP a common technique to perform analysis over a set of texts is to transform the text to a set of vectors, each one representing a word inside a document.
# We transform the titles of the papers into their embedding version by using the pre-trained model available on FastText page https://fasttext.cc/docs/en/crawl-vectors.html.
# * We load the data plucking only the metadata field of each paper, since it contains the title
# * We load the english fasttext model
# * We create one dictionary per paper, each one with its title and the embedding for it
# * We save each dictionary in a .json file

# %%
if False:
    
    import fasttext

    def embed(text, model):
        
        text_split = text.split()
        text_list = [model[t] for t in text_split]
        text_string = [["%.10f" % n for n in emb] for emb in text_list]
        
        return text_string

    
    def dict_embed(text, model):
        
        return {
            "title": text,
            "emb_title": embed(text, model)
        }


    def embedding():
        # Import data
        filename = os.path.join('data', 'json_singleline', '*.json')
        lines = db.read_text(filename)
        js = lines.map(json.loads)
        titles = js.pluck("metadata").pluck("title").compute()

        # Load the FastText model
        ft = fasttext.load_model('cc.en.300.bin')

        # Get titles and embed them
        titles_emb = [dict_embed(d, ft) for d in titles]

        # Save embedded paper titles
        for i in range(len(titles_emb)):
            fname = "data/new_emb/embeddings"+str(i)+".json"
            with open (fname, 'w') as wf:
                json.dump(titles_emb[i], wf)


    client = Client('10.67.22.190:8786')   

    embedding()

    client.close()

# %%
client  = Client('10.67.22.190:8786')
client
# Out:
# /usr/lib/python3.6/site-packages/distributed/client.py:1134: VersionMismatchWarning: Mismatched versions found
#
# +---------+---------------+---------------+------------------------------------+
# | Package | client        | scheduler     | workers                            |
# +---------+---------------+---------------+------------------------------------+
# | python  | 3.6.8.final.0 | 3.6.8.final.0 | {'3.6.8.final.0', '3.6.5.final.0'} |
# +---------+---------------+---------------+------------------------------------+
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tcp://10.67.22.190:8786' processes=8 threads=32, memory=65.61 GB>

# %% [markdown]
# Now we can load the embedded titles json files

# %%
# Load embedded papers
filename = os.path.join('data', 'embeddings', '*.json')
jfiles = db.read_text(filename).map(json.loads)
jfiles.take(1)
# Out:
# ({'title': 'Plasma inflammatory cytokines and chemokines in severe acute respiratory syndrome',
#   'emb_title': [['0.0179780778',
#     '0.0610310212',
#     '0.0514091067',
#     '0.0119336043',
#     '0.0383133069',
#     '-0.0342295803',
#     '0.0544443913',
#     '-0.0438884012',
#     '-0.0255027022',
#     '-0.1600893885',
#     '-0.0631421208',
#     '-0.0346374400',
#     '-0.0694727302',
#     '-0.0476796925',
#     '0.0126695549',
#     '0.0481020324',
#     '0.1033288166',
#     '-0.0134457452',
#     '-0.0230915360',
#     '0.0095322421',
#     '0.0111391805',
#     '-0.0126392692',
#     '0.0422238111',
#     '-0.0236146357',
#     '0.0950958356',
#     '0.0068730386',
#     '-0.0092170276',
#     '-0.0240158867',
#     '-0.0792038664',
#     '0.0995018706',
#     '0.0013987571',
#     '0.1105756983',
#     '0.0172082502',
#     '0.0815243348',
#     '0.0238117855',
#     '-0.0196268894',
#     '-0.0114727272',
#     '0.0105287535',
#     '0.0734981075',
#     '-0.0900465846',
#     '-0.0880422294',
#     '0.0961950645',
#     '-0.0415551290',
#     '-0.0520615652',
#     '-0.0644700229',
#     '0.0177867357',
#     '-0.0266534835',
#     '-0.0121189812',
#     '0.0581873432',
#     '-0.0776401162',
#     '-0.0007089336',
#     '0.0848425552',
#     '0.1865844280',
#     '0.0266050249',
#     '-0.0261656977',
#     '-0.0005478542',
#     '0.0543464907',
#     '-0.0046749930',
#     '-0.0440217853',
#     '0.0275370963',
#     '-0.0709503591',
#     '-0.0841484591',
#     '0.0825289413',
#     '0.1669105291',
#     '0.1297752708',
#     '-0.0655464381',
#     '-0.1282918006',
#     '-0.0390856490',
#     '0.0369121693',
#     '0.1313807964',
#     '0.0378168933',
#     '-0.0822056085',
#     '-0.0144308778',
#     '0.0591870435',
#     '0.1377823949',
#     '0.0124013368',
#     '0.0398885719',
#     '0.0379361324',
#     '0.0099099753',
#     '-0.0585635416',
#     '0.0154409884',
#     '-0.0011333786',
#     '-0.0120889684',
#     '0.0042568496',
#     '-0.0184128005',
#     '-0.0436585471',
#     '-0.0065470370',
#     '-0.0318428837',
#     '0.0272266399',
#     '-0.0310536269',
#     '-0.1420682222',
#     '0.0957769081',
#     '0.0057505192',
#     '-0.1047087088',
#     '0.0940950364',
#     '0.0234451685',
#     '-0.0046659471',
#     '-0.0491790734',
#     '0.0237160828',
#     '0.1085590720',
#     '-0.0313984752',
#     '-0.0182460826',
#     '-0.0988085046',
#     '0.0348263606',
#     '0.1826699823',
#     '-0.0763748810',
#     '0.0286006965',
#     '-0.0338387378',
#     '0.0661524907',
#     '0.0393705331',
#     '-0.0221661832',
#     '0.0105133215',
#     '0.0333971791',
#     '-0.0377174914',
#     '-0.0572618619',
#     '0.1075376645',
#     '0.1251664013',
#     '-0.1599021852',
#     '-0.0168502983',
#     '-0.0976572335',
#     '-0.0140148094',
#     '-0.0103445100',
#     '-0.0610554293',
#     '-0.0401414894',
#     '0.0185367968',
#     '-0.0078206779',
#     '0.0186200403',
#     '0.0367368348',
#     '0.0384254791',
#     '-0.0040176339',
#     '0.0531575046',
#     '0.0163613986',
#     '-0.0640610456',
#     '-0.0751721114',
#     '-0.0964335427',
#     '-0.0375935510',
#     '0.1161265895',
#     '0.0766513124',
#     '0.0199932512',
#     '-0.0862198621',
#     '-0.0684804842',
#     '-0.1187018305',
#     '-0.0215393025',
#     '-0.0839251429',
#     '0.0263672061',
#     '-0.0030394839',
#     '-0.0941175818',
#     '0.0219571944',
#     '-0.0011163962',
#     '-0.0301247668',
#     '-0.0042389808',
#     '-0.1713099778',
#     '-0.0910871029',
#     '0.0685789809',
#     '-0.0279960278',
#     '-0.0496860035',
#     '-0.0632926449',
#     '-0.0163604151',
#     '-0.0145386485',
#     '0.1075751781',
#     '-0.1981454194',
#     '-0.0013523803',
#     '0.0115990527',
#     '-0.0124529926',
#     '-0.0291412361',
#     '0.0154910684',
#     '-0.0017945318',
#     '-0.0976632833',
#     '0.0471312888',
#     '-0.0380201004',
#     '0.0675910935',
#     '-0.1543070674',
#     '0.0665042773',
#     '0.1451794803',
#     '-0.0628984049',
#     '0.0867627636',
#     '-0.0238457676',
#     '0.0618910678',
#     '-0.0472618937',
#     '0.0055044829',
#     '0.0384459570',
#     '-0.0008921169',
#     '0.0118710464',
#     '0.0346381925',
#     '0.0973875225',
#     '-0.0086540552',
#     '0.0139493346',
#     '0.0119881826',
#     '0.1560552120',
#     '-0.0607657544',
#     '-0.0522252582',
#     '0.0029425777',
#     '-0.0595225170',
#     '-0.0455992892',
#     '0.1752128750',
#     '0.0750852227',
#     '0.0078438772',
#     '-0.0137179587',
#     '0.1486664861',
#     '-0.0364192501',
#     '-0.0322721861',
#     '-0.0235511661',
#     '-0.0539475568',
#     '0.0482306927',
#     '-0.0499965958',
#     '-0.0582406931',
#     '0.0141337290',
#     '-0.0114066368',
#     '-0.1400615871',
#     '-0.0148440627',
#     '0.0228817090',
#     '0.0105996346',
#     '-0.0146525176',
#     '0.0147895431',
#     '-0.0485571660',
#     '-0.0147151370',
#     '-0.0535492599',
#     '0.0391916595',
#     '0.0573588125',
#     '0.0199129116',
#     '0.0604470037',
#     '-0.0360783823',
#     '0.0726937577',
#     '0.0230323412',
#     '0.0718855262',
#     '0.0873054788',
#     '0.0057732263',
#     '0.0215410031',
#     '-0.0268334132',
#     '-0.0034508915',
#     '0.0485009588',
#     '-0.0019806814',
#     '0.0204651766',
#     '-0.0181122422',
#     '-0.0461912975',
#     '-0.0891543552',
#     '-0.0698659718',
#     '-0.0171591695',
#     '0.0631079376',
#     '0.0542181842',
#     '0.0493083112',
#     '-0.0238146912',
#     '0.1489002407',
#     '-0.0238095801',
#     '0.1410761327',
#     '0.0110912081',
#     '0.0287767835',
#     '0.0014988534',
#     '0.1174057275',
#     '0.0193136632',
#     '0.0033459277',
#     '0.0728965327',
#     '0.0133105842',
#     '0.0659924820',
#     '-0.0851328596',
#     '-0.0373405181',
#     '0.0293879509',
#     '0.0106307268',
#     '0.0430905819',
#     '0.0162257459',
#     '0.1420755386',
#     '-0.0863616914',
#     '-0.0063638329',
#     '-0.1038005948',
#     '-0.0352152362',
#     '0.0972662196',
#     '-0.0604721420',
#     '0.0561044589',
#     '0.0235184859',
#     '0.0497089289',
#     '-0.0627267808',
#     '-0.0110204844',
#     '-0.0606819503',
#     '0.0179584082',
#     '0.0495055206',
#     '-0.0660153702',
#     '0.0101643056',
#     '-0.0941421911',
#     '0.0821476802',
#     '-0.0318938419',
#     '0.0785633922',
#     '0.0139290737',
#     '0.0221646782',
#     '-0.0453400724',
#     '0.0551504493',
#     '-0.0399180576',
#     '0.0222778600',
#     '-0.0834696144',
#     '-0.0565986335',
#     '-0.0049410658',
#     '-0.0347958393',
#     '0.0310985334',
#     '0.1809450984',
#     '-0.0446225256',
#     '0.0443716943',
#     '0.0441823192',
#     '-0.1037849337',
#     '0.0801475197',
#     '-0.0833752528',
#     '-0.1715013981'],
#    ['0.0342138708',
#     '-0.0382088535',
#     '0.0254127309',
#     '0.0824857503',
#     '-0.0101040807',
#     '-0.0113908723',
#     '0.0131736062',
#     '-0.0292113330',
#     '-0.0416998900',
#     '0.0230511166',
#     '0.0339953750',
#     '0.0006093620',
#     '-0.0588065945',
#     '-0.0275591314',
#     '-0.0191213340',
#     '-0.0122985737',
#     '0.0276048239',
#     '0.0013595995',
#     '-0.0063982410',
#     '-0.0310707614',
#     '-0.0009906956',
#     '0.0008521152',
#     '0.0095450329',
#     '-0.0233745519',
#     '-0.0043481635',
#     '0.0003423030',
#     '-0.0289845150',
#     '-0.0351893306',
#     '-0.0273046400',
#     '0.0676110238',
#     '0.0118208127',
#     '0.0252142642',
#     '0.0221984144',
#     '0.0296929814',
#     '-0.0223247148',
#     '-0.0209606532',
#     '0.0589899048',
#     '0.0165999718',
#     '-0.0063662450',
#     '-0.0114591150',
#     '0.0284476504',
#     '-0.0315966494',
#     '0.0272564329',
#     '-0.0103756711',
#     '-0.0482619368',
#     '0.0093484195',
#     '-0.0237600654',
#     '-0.0656507090',
#     '0.0393463969',
#     '0.0358271748',
#     '-0.0084321946',
#     '-0.0020556720',
#     '-0.0385152102',
#     '-0.0252412856',
#     '0.0116437227',
#     '0.0340136513',
#     '-0.0108703719',
#     '0.0384838767',
#     '-0.0502090268',
#     '0.0053283595',
#     '-0.0227704085',
#     '-0.0435378850',
#     '-0.0257141925',
#     '-0.0260507148',
#     '0.0100234319',
#     '0.0488201603',
#     '-0.0258518960',
#     '-0.0432682335',
#     '0.0352513343',
#     '-0.0665943027',
#     '0.0129826441',
#     '-0.0130793899',
#     '0.0172066037',
#     '-0.0137565387',
#     '0.0259421505',
#     '-0.0093951672',
#     '0.0403619111',
#     '-0.0463111810',
#     '-0.0273515638',
#     '-0.0014779026',
#     '-0.0096603502',
#     '0.0021718629',
#     '0.0098875705',
#     '-0.0263293087',
#     '-0.0331652649',
#     '-0.0472245887',
#     '0.0824844092',
#     '0.0056015383',
#     '0.0528181978',
#     '0.0203878824',
#     '-0.0026833480',
#     '0.0243113972',
#     '0.0580116101',
#     '-0.0208991636',
#     '0.0133853462',
#     '-0.0145885339',
#     '-0.0212682914',
#     '-0.0228000041',
#     '-0.0524511263',
#     '-0.0111035779',
#     '-0.0356523283',
#     '0.0061775311',
#     '-0.0504353866',
#     '-0.0049408111',
#     '0.0130390842',
#     '-0.0443128049',
#     '-0.0116603998',
#     '-0.0050019245',
#     '0.0300307497',
#     '-0.0064626513',
#     '-0.0100749880',
#     '-0.0070338529',
#     '0.0400502235',
#     '0.0211335942',
#     '-0.0307082050',
#     '-0.0120308632',
#     '-0.0097944429',
#     '-0.0199298058',
#     '0.0025164669',
#     '0.0264899135',
#     '-0.0327548459',
#     '0.0160971321',
#     '0.0237258673',
#     '-0.0190331768',
#     '-0.0673120469',
#     '-0.0537992530',
#     '0.0423805900',
#     '0.0034875993',
#     '0.0122158527',
#     '-0.0446761250',
#     '0.0301532261',
#     '0.0056306599',
#     '-0.0001242781',
#     '0.0291057806',
#     '0.0387494266',
#     '0.0175261740',
#     '0.0632927790',
#     '-0.0138204945',
#     '-0.0125144562',
#     '0.0298614912',
#     '-0.0381099768',
#     '-0.0359694734',
#     '-0.0135356477',
#     '-0.0034270231',
#     '-0.0012404906',
#     '-0.0283590667',
#     '-0.0574985147',
#     '-0.0327640995',
#     '-0.0313187242',
#     '0.0378280506',
#     '-0.0269056484',
#     '0.0023338618',
#     '0.0098666335',
#     '0.0534835532',
#     '-0.0518050864',
#     '0.0349278040',
#     '0.0027217555',
#     '0.0373726971',
#     '0.0210185330',
#     '-0.0269194413',
#     '-0.0262119770',
#     '0.0225230232',
#     '-0.0407033153',
#     '-0.0040421132',
#     '-0.0021471835',
#     '-0.0314272828',
#     '0.0286498964',
#     '0.0173597615',
#     '0.0369332917',
#     '0.0276170652',
#     '-0.0213257018',
#     '0.0389794931',
#     '0.0580863543',
#     '-0.0488585830',
#     '0.0445082486',
#     '0.0213380065',
#     '0.0224887393',
#     '-0.0200323202',
#     '-0.0239730682',
#     '0.0262009017',
#     '-0.0011123713',
#     '-0.0294161178',
#     '-0.0221036170',
#     '-0.0268120673',
#     '0.0220118705',
#     '0.0073779575',
#     '0.0537173711',
#     '0.0223557707',
#     '0.0239076074',
#     '-0.0137620587',
#     '0.0182326753',
#     '0.0207199603',
#     '-0.0683449581',
#     '-0.0545900539',
#     '0.0069124401',
#     '0.0342317969',
#     '0.0892156959',
#     '-0.0105499048',
#     '-0.0333107598',
#     '0.0060956283',
#     '-0.0346594751',
#     '0.0268355217',
#     '-0.0071492046',
#     '0.0038431732',
#     '-0.0125941830',
#     '0.0428923629',
#     '-0.0328884572',
#     '-0.0042786314',
#     '0.0304092914',
#     '-0.0520549752',
#     '-0.0238028150',
#     '-0.0011625304',
#     '0.0563890263',
#     '-0.0426975600',
#     '0.0090199197',
#     '0.0024907140',
#     '-0.0142751951',
#     '0.0160611086',
#     '0.0219227318',
#     '-0.0521996729',
#     '-0.0217525270',
#     '0.0015154092',
#     '0.0397220775',
#     '0.0180473179',
#     '0.0439798646',
#     '0.0208731052',
#     '-0.0181099586',
#     '0.0542981625',
#     '0.0201347768',
#     '0.0021121115',
#     '0.0230705384',
#     '-0.0014640852',
#     '0.0234152190',
#     '0.0215967782',
#     '-0.0000731959',
#     '-0.0240439866',
#     '-0.0158516224',
#     '0.0419078171',
#     '-0.0085844742',
#     '0.0015253823',
#     '-0.0205592420',
#     '-0.0146117648',
#     '0.0025477686',
#     '-0.0316075385',
#     '0.0543682389',
#     '-0.0149237020',
#     '0.0305532310',
#     '0.0290812310',
#     '-0.0012582953',
#     '0.0523521490',
#     '0.0096299425',
#     '-0.0374565646',
#     '-0.0183616877',
#     '0.0454600640',
#     '-0.0240238216',
#     '-0.0094151041',
#     '-0.0055529755',
#     '0.0766992867',
#     '-0.0085248947',
#     '-0.0306679811',
#     '0.0103636952',
#     '-0.0101125157',
#     '-0.0057150628',
#     '-0.0512187295',
#     '0.0364743359',
#     '0.0102208275',
#     '0.0060236421',
#     '-0.0073106848',
#     '-0.0126147317',
#     '0.0165915433',
#     '-0.0191152487',
#     '0.0026040527',
#     '0.0264307652',
#     '-0.0297290739',
#     '-0.0223966632',
#     '0.0609814264',
#     '0.0116897551',
#     '0.0250054207',
#     '0.0101715894',
#     '-0.0563469604',
#     '0.0084602609',
#     '0.0044305795',
#     '-0.0056886435',
#     '-0.0453860313',
#     '-0.0590553097',
#     '0.0009914069',
#     '-0.0122686280',
#     '0.0021566167',
#     '0.0180080980',
#     '-0.0251848381',
#     '-0.0093119834',
#     '0.0040551224',
#     '-0.0444092788',
#     '0.0450269766',
#     '0.0119309500',
#     '-0.0619979464',
#     '-0.0708265901',
#     '0.0575036928',
#     '-0.0044215070',
#     '0.0291664172'],
#    ['0.0571616814',
#     '0.0119980536',
#     '0.0351123735',
#     '0.0149233248',
#     '0.0083013372',
#     '0.0343423001',
#     '0.0458510742',
#     '-0.0266155899',
#     '-0.0725836232',
#     '0.0124345701',
#     '0.0698489025',
#     '-0.0228880085',
#     '-0.0380751193',
#     '-0.0327032283',
#     '-0.0699138716',
#     '-0.0912565738',
#     '0.0406569391',
#     '-0.0373206101',
#     '-0.0574845336',
#     '-0.0142088346',
#     '0.0253180377',
#     '-0.0593890473',
#     '0.0135039305',
#     '-0.0127033480',
#     '-0.0234133359',
#     '0.0077156052',
#     '-0.0461204574',
#     '-0.0407119393',
#     '-0.0216965955',
#     '0.1983208358',
#     '-0.0062709698',
#     '0.0213900264',
#     '0.0255005471',
#     '0.0184975117',
#     '-0.0164362378',
#     '-0.0590315498',
#     '-0.0084770378',
#     '0.0175166354',
#     '0.0288173575',
#     '-0.0591155738',
#     '0.0462724864',
#     '-0.0395645462',
#     '0.0670349449',
#     '0.0300596803',
#     '-0.0138700958',
#     '-0.0293342378',
#     '-0.0132046016',
#     '-0.0941496640',
#     '-0.0019994834',
#     '0.0231688749',
#     '-0.0126613900',
#     '-0.0206600521',
#     '-0.0174422618',
#     '-0.0711020231',
#     '0.0348353647',
#     '-0.0247710962',
#     '0.0741489604',
#     '0.0174850821',
#     '-0.0660764277',
#     '0.0215100199',
#     '-0.0237036776',
#     '-0.0252656657',
#     '-0.0317255482',
#     '-0.0066437311',
#     '0.0120111620',
#     '0.0556367151',
#     '-0.0145490710',
#     '-0.0093834242',
#     '0.0248455945',
#     '-0.0547974706',
#     '-0.0538745672',
#     '0.0097428169',
#     '-0.0094366623',
#     '0.0467647389',
#     '0.0558410697',
#     '-0.0447788276',
#     '-0.0227589458',
#     '-0.0309620872',
#     '0.0083935102',
#     '-0.0012959428',
#     '-0.0010633066',
#     '0.0309000909',
#     '0.0114317089',
#     '0.0059961705',
#     '-0.0410578735',
#     '-0.0353177898',
#     '-0.0209623761',
#     '-0.0193173625',
#     '0.0797581971',
#     '-0.0181327276',
#     '-0.0552661046',
#     '0.0235181842',
#     '-0.0143788122',
#     '-0.0182844978',
#     '0.0815791041',
#     '-0.0323745236',
#     '0.0184597615',
#     '-0.0610586330',
#     '-0.0405390710',
#     '-0.0570189618',
#     '-0.0148303891',
#     '-0.0966342315',
#     '-0.0923893526',
#     '-0.0131135536',
#     '0.0507279970',
#     '-0.0421922617',
#     '-0.0343689695',
#     '0.0041673072',
#     '0.0293146204',
#     '-0.0478838272',
#     '-0.0789191946',
#     '-0.0041755913',
#     '0.0511022396',
#     '0.0379586145',
#     '-0.0326521806',
#     '-0.0002574605',
#     '0.1186499298',
#     '-0.0063714720',
#     '-0.0474968068',
#     '-0.0101862401',
#     '0.0313320421',
#     '-0.0442437194',
#     '0.0280433614',
#     '-0.0682169646',
#     '-0.0606221892',
#     '-0.0858401731',
#     '0.0888527036',
#     '0.0280294679',
#     '0.0500691682',
#     '-0.0491562150',
#     '-0.0018024861',
#     '0.0394465439',
#     '-0.0310102850',
#     '-0.0064188987',
#     '0.0661638081',
#     '0.0560764931',
#     '0.0093426425',
#     '0.0239187106',
#     '-0.0172676444',
#     '0.0825031325',
#     '0.0015425065',
#     '-0.0455205329',
#     '-0.0400091447',
#     '-0.0729188696',
#     '0.0193573534',
#     '-0.0194962230',
#     '-0.1013156697',
#     '0.0311509129',
#     '0.0052591274',
#     '0.0726259649',
#     '0.0062261447',
#     '0.0231829677',
#     '-0.0064923018',
#     '0.1067223623',
#     '-0.0551740266',
#     '-0.0300768334',
#     '0.0550037585',
#     '0.0248294100',
#     '0.0563619211',
#     '-0.0362660028',
#     '-0.0759376138',
#     '0.0115186628',
#     '-0.0167415813',
#     '0.0824734941',
#     '0.0084680459',
#     '-0.0933740288',
#     '-0.0080229789',
#     '-0.0508121587',
#     '0.0411165059',
#     '-0.0184967835',
#     '-0.0787545294',
#     '-0.0109647941',
#     '0.0700761378',
#     '-0.0715313628',
#     '0.0239678584',
#     '0.0059921071',
#     '0.0151002053',
#     '0.0060510482',
#     '-0.0151915802',
#     '0.0302584618',
#     '-0.0098146787',
#     '-0.0252179038',
#     '-0.0640941039',
#     '-0.0114623532',
#     '0.1040136963',
#     '-0.0084111970',
#     '0.0541199222',
#     '-0.0229258817',
#     '-0.0318638831',
#     '-0.0241613723',
#     '0.0011004808',
#     '0.0190559532',
#     '-0.0965720266',
#     '-0.0572338551',
#     '0.0247792732',
#     '0.0185659137',
#     '0.0879732817',
#     '-0.0261967909',
#     '0.0826147571',
#     '0.0114585767',
#     '0.0514229536',
#     '0.0117448373',
#     '-0.0072383797',
#     '0.0284797363',
#     '-0.0296143480',
#     '0.0223989896',
#     '-0.0154633019',
#     '-0.0363214538',
#     '-0.0102964835',
#     '0.0042166319',
#     '-0.0186283998',
#     '0.0772126168',
#     '0.0254555810',
#     '-0.0211311467',
#     '-0.0086441999',
#     '0.0227348823',
#     '-0.0145066343',
#     '0.0700061843',
#     '0.0511470176',
#     '0.0177461952',
#     '-0.0992579162',
#     '0.0374445356',
#     '0.0437429063',
#     '0.0259465389',
#     '-0.0270322710',
#     '0.0772094652',
#     '0.0254332665',
#     '0.0162354279',
#     '-0.0274100248',
#     '-0.0623435341',
#     '0.0916812047',
#     '0.0069360179',
#     '0.0404996648',
#     '0.0292873066',
#     '-0.0126714204',
#     '-0.0243643355',
#     '-0.0434536263',
#     '-0.0044969665',
#     '0.0400175527',
#     '-0.0160458237',
#     '0.0045413049',
#     '0.0441676974',
#     '-0.0065080952',
#     '-0.0455523655',
#     '0.0667696893',
#     '-0.0069564329',
#     '0.0661402643',
#     '-0.0284090098',
#     '0.0755579919',
#     '0.0661532804',
#     '0.0202503596',
#     '0.0256034546',
#     '-0.0118633993',
#     '0.0185062736',
#     '-0.0619472191',
#     '0.0063502514',
#     '-0.0551336333',
#     '0.0939245075',
#     '-0.0518795103',
#     '-0.0387788229',
#     '0.0549692474',
#     '-0.0143003110',
#     '0.0006621983',
#     '-0.0511171855',
#     '-0.0276644044',
#     '-0.0171259008',
#     '0.0352714919',
#     '-0.0170618687',
#     '0.0200869776',
#     '-0.0119517185',
#     '-0.0683468133',
#     '-0.0165680908',
#     '-0.0264147110',
#     '0.0220403988',
#     '0.0071571507',
#     '0.0529615805',
#     '0.0411484316',
#     '0.0372173078',
#     '-0.0281764995',
#     '-0.0190761033',
#     '-0.0329135992',
#     '-0.0015182784',
#     '-0.0459846072',
#     '-0.0932520106',
#     '-0.0234625638',
#     '0.0087321978',
#     '-0.0060871211',
#     '-0.0084579168',
#     '0.0296220947',
#     '-0.0552819446',
#     '-0.0473720059',
#     '0.0439186804',
#     '-0.0111124339',
#     '0.0191876851',
#     '0.0418791585',
#     '-0.0086262347',
#     '-0.0972989798',
#     '0.0466689169',
#     '0.0071521495',
#     '-0.0094735753'],
#    ['0.0082391109',
#     '-0.0899027660',
#     '0.0265252870',
#     '-0.0085538775',
#     '-0.0609397441',
#     '0.0067593013',
#     '0.0652322620',
#     '0.0106213633',
#     '-0.0475259237',
#     '-0.0076114833',
#     '-0.0022587562',
#     '0.0009084080',
#     '-0.0066886954',
#     '-0.0225828700',
#     '-0.0066159326',
#     '-0.0724807084',
#     '0.0203068964',
#     '0.0214499757',
#     '-0.0507426150',
#     '0.0391916037',
#     '0.0533207357',
#     '-0.0045275465',
#     '-0.0018690201',
#     '0.0557158291',
#     '0.0146500766',
#     '-0.0570575595',
#     '0.0004939493',
#     '-0.0070915874',
#     '0.0148559324',
#     '-0.0528307818',
#     '0.0284850523',
#     '-0.0496256426',
#     '0.0222029127',
#     '0.0586468279',
#     '0.0213257503',
#     '0.0079136863',
#     '0.0187332481',
#     '0.0918916687',
#     '-0.0277845450',
#     '0.0239473525',
#     '0.0425748378',
#     '-0.0099417148',
#     '-0.0223485958',
#     '0.0855861679',
#     '-0.0447648503',
#     '-0.0141877644',
#     '-0.0001268871',
#     '-0.1002391279',
#     '-0.0124342320',
#     '0.0595488772',
#     '0.0235982426',
#     '0.0156282559',
#     '0.0194263570',
#     '0.0085824458',
#     '0.0151532954',
#     '0.0416088402',
#     '0.0198060516',
#     '-0.0074611306',
#     '-0.0307702627',
#     '-0.0210531931',
#     '0.0274334885',
#     '-0.0417157374',
#     '-0.0356185883',
#     '-0.0217031352',
#     '0.0137879029',
#     '0.0272319801',
#     '0.0291177686',
#     '0.0162381288',
#     '0.0223314390',
#     '0.0312007107',
#     '-0.0075290566',
#     '0.0102584790',
#     '0.0294368342',
#     '0.0125950836',
#     '0.0728831515',
#     '-0.0124444338',
#     '-0.0443593860',
#     '0.0330700912',
#     '-0.0975801498',
#     '-0.0258863755',
#     '0.0053457040',
#     '0.0175542943',
#     '-0.0194995441',
#     '0.0300365388',
#     '-0.0318978280',
#     '0.0281078480',
#     '0.0548056886',
#     '-0.0152527466',
#     '-0.0436926112',
#     '-0.0541102588',
#     '0.0112257171',
#     '0.0216098651',
#     '-0.0360471047',
#     '-0.0144853946',
#     '-0.0036204532',
#     '0.0195710585',
#     '0.0121764317',
#     '-0.0570974648',
#     '-0.0270106252',
#     '0.0638146177',
#     '0.0428568050',
#     '-0.0607165471',
#     '-0.0319392532',
#     '0.0031941645',
#     '-0.0124735981',
#     '-0.0713155493',
#     '-0.0303832013',
#     '-0.0121982563',
#     '0.0211810097',
#     '-0.0269490033',
#     '0.0081738271',
#     '-0.1155548692',
#     '0.0007626042',
#     '0.0895902887',
#     '-0.0165034328',
#     '-0.0127696330',
#     '-0.0411331467',
#     '-0.0134926224',
#     '0.0154139949',
#     '-0.0280922018',
#     '0.0618206672',
#     '-0.0036704866',
#     '-0.0811334252',
#     '0.0207473226',
#     '0.0202467032',
#     '0.0587196238',
#     '-0.0165337455',
#     '0.1276094019',
#     '-0.0316866301',
#     '-0.0039312467',
#     '-0.0439455174',
#     '0.0146993287',
#     '-0.0586559139',
#     '-0.0186296999',
#     '0.0126128625',
#     '-0.0054122214',
#     '-0.0426090881',
#     '0.0605685711',
#     '-0.0427909158',
#     '-0.0296267532',
#     '-0.0102523398',
#     '-0.0180237554',
#     '0.0102565736',
#     '0.0300097764',
#     '0.0205962062',
#     '0.0246783439',
#     '-0.3689808846',
#     '-0.0038506095',
#     '0.0272371080',
#     '-0.0251431949',
#     '-0.0401115716',
#     '0.0253724586',
#     '-0.0439509079',
#     '-0.0038051943',
#     '-0.0001575425',
#     '0.0138481390',
#     '0.0608402230',
#     '0.0325895734',
#     '-0.0869639590',
#     '-0.0047342749',
#     '-0.0584197268',
#     '-0.0243068412',
#     '-0.0934191346',
#     '-0.0029022703',
#     '-0.0028586963',
#     '0.0198261254',
#     '0.0149173150',
#     '-0.0408625118',
#     '0.0180987455',
#     '-0.0209783278',
#     '-0.0221290570',
#     '0.0168420840',
#     '0.0310796499',
#     '0.0333685130',
#     '-0.0504413135',
#     '0.0163729712',
#     '-0.0312635042',
#     '0.1001017243',
#     '0.0282859225',
#     '-0.0844198242',
#     '0.0168396402',
#     '0.0222058222',
#     '-0.0624679327',
#     '-0.0626606345',
#     '0.0307596754',
#     '0.0266086198',
#     '-0.0626772717',
#     '-0.0390372090',
#     '0.0234264489',
#     '-0.0504080988',
#     '-0.0444788560',
#     '0.0474284291',
#     '-0.0452308729',
#     '0.0411198586',
#     '0.0174042508',
#     '-0.0617337301',
#     '0.0637754649',
#     '-0.0659050569',
#     '-0.0148986205',
#     '0.0685354099',
#     '-0.0729488060',
#     '-0.0176609159',
#     '0.0045581739',
#     '-0.0137576871',
#     '-0.0160885155',
#     '-0.0184375253',
#     '-0.0989368558',
#     '0.0069545973',
#     '0.0543078929',
#     '0.1277211905',
#     '0.0355936289',
#     '-0.0026823264',
#     '0.0858246982',
#     '0.0111327469',
#     '-0.0019593230',
#     '0.0273223221',
#     '0.0501469374',
#     '-0.0386893563',
#     '0.0323250070',
#     '0.0417337604',
#     '0.0523539893',
#     '0.0277093053',
#     '-0.0144251995',
#     '0.0432834141',
#     '0.0427054539',
#     '-0.0107224286',
#     '0.0395365059',
#     '-0.0518234596',
#     '-0.0333377495',
#     '-0.0117142852',
#     '-0.0287252963',
#     '-0.0241805799',
#     '0.0369910486',
#     '0.0449758433',
#     '0.0315677449',
#     '-0.0527046509',
#     '0.0119324103',
#     '0.0500314534',
#     '0.0141884973',
#     '0.0322734229',
#     '0.0256861262',
#     '-0.0019931756',
#     '0.0563756302',
#     '-0.2396043241',
#     '0.6197361350',
#     '0.0086132046',
#     '0.0366283394',
#     '-0.0421728641',
#     '0.0743011087',
#     '0.0188162178',
#     '-0.0432008430',
#     '-0.0123270685',
#     '-0.0217413902',
#     '-0.0456854552',
#     '0.0126606524',
#     '-0.0475486219',
#     '-0.1059409603',
#     '0.0109916627',
#     '-0.0014046021',
#     '-0.0092897108',
#     '0.0386689752',
#     '0.0941321328',
#     '-0.0441618860',
#     '0.0169493593',
#     '-0.0712717623',
#     '0.0748523623',
#     '0.0028674705',
#     '0.0932347551',
#     '-0.1162463054',
#     '0.0106363427',
#     '-0.0150462352',
#     '0.0557788797',
#     '-0.0585105419',
#     '-0.0191076845',
#     '0.0228385851',
#     '0.0304185450',
#     '0.0189196952',
#     '-0.0318782479',
#     '-0.0563929938',
#     '0.0580628291',
#     '0.0059848079',
#     '0.0722073093',
#     '-0.1536723673',
#     '0.0284299590',
#     '0.0111958720',
#     '0.0417528562',
#     '0.0354119763',
#     '-0.0961888283',
#     '-0.0008415980',
#     '0.0196748879',
#     '0.0607221983',
#     '-0.0355068520',
#     '-0.0238197073',
#     '-0.0277546421',
#     '-0.0260229278',
#     '-0.0380507559',
#     '-0.0211028941',
#     '-0.0115913749',
#     '-0.0411286354',
#     '0.0362522230'],
#    ['0.0838248730',
#     '0.0040165028',
#     '0.0329453796',
#     '0.0003815128',
#     '0.0100558307',
#     '0.0252803378',
#     '0.0185337439',
#     '-0.0362672657',
#     '-0.1069153696',
#     '0.0028337564',
#     '0.0432538129',
#     '-0.0711632445',
#     '-0.0260639284',
#     '-0.0327203609',
#     '-0.0586592145',
#     '-0.0937510803',
#     '0.0500133969',
#     '0.0071625845',
#     '0.0013668665',
#     '0.0211644862',
#     '0.0175877400',
#     '0.0189456530',
#     '0.0064258394',
#     '-0.0414548330',
#     '0.0314997584',
#     '-0.0284853522',
#     '-0.0445765555',
#     '0.0083394479',
#     '-0.0284040812',
#     '0.2186753303',
#     '0.0137184393',
#     '0.0006215867',
#     '0.0496537015',
#     '0.0148081901',
#     '-0.0986373052',
#     '-0.0610437132',
#     '-0.0017763310',
#     '-0.0184293650',
#     '0.0640102625',
#     '-0.0208455399',
#     '0.0532640517',
#     '-0.0514697917',
#     '0.0678525493',
#     '0.0008960813',
#     '-0.0195161700',
#     '-0.0314899348',
#     '-0.0595662519',
#     '-0.0677702799',
#     '-0.0413356833',
#     '0.0092983991',
#     '-0.0602331646',
#     '-0.0610301830',
#     '-0.0061698654',
#     '-0.0707915127',
#     '0.0099236555',
#     '-0.0268674437',
#     '0.0266593602',
#     '0.0454425104',
#     '-0.0508296713',
#     '0.0091561005',
#     '-0.0460350029',
#     '0.0013187387',
#     '-0.0709917098',
#     '0.0008045675',
#     '0.0011430128',
#     '0.0207640175',
#     '0.0057548885',
#     '-0.0650860667',
#     '0.0318650454',
#     '-0.0127975410',
#     '-0.0379903428',
#     '-0.0160878766',
#     '0.0217278171',
#     '0.0066787247',
#     '0.0595078729',
#     '0.0260925610',
#     '-0.0134177776',
#     '-0.0180475917',
#     '-0.0002444051',
#     '0.0062103057',
#     '-0.0242563952',
#     '0.0482191369',
#     '0.0865794867',
#     '0.0087312888',
#     '-0.0259376708',
#     '-0.0141776269',
#     '-0.0081318477',
#     '-0.0204470698',
#     '0.0407189503',
#     '-0.0378310084',
#     '-0.0219997726',
#     '-0.0039702482',
#     '-0.0096690925',
#     '0.0224970225',
#     '0.0749889463',
#     '-0.0417821929',
#     '0.0418894924',
#     '-0.0640637130',
#     '-0.0435682982',
#     '-0.0804029331',
#     '-0.0426041968',
#     '-0.0347152390',
#     '-0.0500530228',
#     '0.0011077342',
#     '0.0228046309',
#     '-0.0203825328',
#     '-0.0178621858',
#     '-0.0006806859',
#     '0.0533895753',
#     '-0.0172776543',
#     '-0.0598322302',
#     '-0.0423026346',
#     '0.0569496751',
#     '0.0208208729',
#     '-0.0488334335',
#     '-0.0012830481',
#     '0.0879320800',
#     '-0.0111219529',
#     '-0.0711489394',
#     '-0.0284607373',
#     '0.0234581772',
#     '-0.0220289007',
#     '0.0141931279',
#     '-0.0751447454',
#     '-0.0489985757',
#     '-0.0985345766',
#     '0.0670912787',
#     '0.0194416996',
#     '0.0206155423',
#     '-0.0029130909',
#     '0.0343696102',
#     '0.0300309323',
#     '-0.0238815602',
#     '0.0037209077',
#     '0.0461209305',
#     '0.0566345006',
#     '0.0130543299',
#     '0.0447215028',
#     '0.0016291059',
#     '0.0591512397',
#     '0.0088319844',
#     '-0.0163079482',
#     '-0.0069692456',
#     '-0.1334950924',
#     '0.0117129553',
#     '0.0340682790',
#     '-0.0775905550',
#     '0.0347449780',
#     '-0.0366332717',
#     '0.0963333771',
#     '-0.0067967558',
#     '0.0254016034',
#     '-0.0262419023',
#     '0.0560408384',
#     '-0.0377065986',
#     '-0.0336557217',
#     '0.0597392507',
#     '0.0686539859',
#     '0.0644726828',
#     '-0.0777135491',
#     '-0.0432766192',
#     '-0.0124559086',
#     '-0.0173746012',
#     '0.0226401463',
#     '0.0554355867',
#     '-0.0084061082',
#     '0.0215507392',
#     '-0.0845077038',
#     '0.0024150827',
#     '-0.0406133160',
#     '-0.0760758147',
#     '-0.0153024169',
#     '0.0754262730',
#     '-0.0841959417',
#     '0.0177111868',
#     '0.0349739082',
#     '-0.0105380453',
#     '-0.0058498061',
#     '-0.0373373292',
#     '0.0501051024',
#     '0.0142501676',
#     '-0.0299420562',
#     '-0.0678995475',
#     '-0.0134474635',
#     '0.1137256473',
#     '-0.0039949683',
#     '0.0358270481',
#     '-0.0645244196',
#     '-0.0338856764',
#     '0.0214423351',
#     '-0.0128950719',
#     '-0.0021750834',
#     '-0.0695464909',
#     '-0.0315582752',
#     '0.0144599201',
#     '-0.0462621748',
#     '0.0916634053',
#     '-0.0443168171',
#     '0.1177797839',
#     '-0.0103047974',
#     '0.0682477430',
#     '0.0189395286',
#     '0.0230934843',
#     '0.0502143204',
#     '-0.0340245031',
#     '0.0394972488',
#     '-0.0287716519',
#     '0.0391842797',
#     '0.0030559807',
#     '0.0183002520',
#     '-0.0085723884',
#     '0.1067420468',
#     '0.0263284929',
#     '-0.0093379747',
#     '0.0353298411',
#     '-0.0066472432',
#     '-0.0278312806',
#     '0.0564378761',
#     '0.0571269281',
#     '0.0029247359',
#     '-0.0361949205',
#     '0.0490549318',
#     '0.0162046496',
#     '0.0014585491',
#     '-0.0306810830',
#     '0.0648157299',
#     '-0.0112608802',
#     '0.0635858476',
#     '-0.0076985243',
#     '-0.0685970560',
#     '0.0719113424',
#     '0.0440296829',
#     '0.0487807393',
#     '0.0131478608',
#     '-0.0459374972',
#     '-0.0079309009',
#     '-0.0372134596',
#     '-0.0212744251',
#     '0.0506740361',
#     '0.0068840864',
#     '-0.0140993576',
#     '0.0240990333',
#     '-0.0489959307',
#     '-0.0510437936',
#     '0.0445063077',
#     '0.0374155417',
#     '0.0273038875',
#     '-0.0333690830',
#     '0.0587979890',
#     '0.0243105255',
#     '0.0368481427',
#     '0.0481692702',
#     '0.0313818865',
#     '0.0089948922',
#     '-0.0824901536',
#     '0.0151968133',
#     '-0.0683393478',
#     '0.0883733481',
#     '-0.0063669775',
#     '-0.0241868589',
#     '0.0579335093',
#     '-0.0039730766',
#     '0.0125698196',
#     '-0.0498039648',
#     '-0.0152584333',
#     '-0.0061843265',
#     '0.0840640962',
#     '-0.0428467281',
#     '0.0128206359',
#     '-0.0075512729',
#     '-0.0148777431',
#     '0.0479150899',
#     '-0.0466224328',
#     '-0.0054230159',
#     '-0.0447902046',
#     '0.0654970109',
#     '0.0153681012',
#     '0.0089899814',
#     '-0.0389129110',
#     '-0.0200183038',
#     '-0.0429180972',
#     '-0.0637030602',
#     '-0.0436190851',
#     '-0.0395466127',
#     '-0.0161659699',
#     '-0.0029647583',
#     '-0.0048271772',
#     '0.0143542839',
#     '0.0208658855',
#     '-0.0802001655',
#     '-0.0561008267',
#     '0.0121541135',
#     '0.0359859876',
#     '0.0373513512',
#     '0.0072912285',
#     '-0.0161610376',
#     '-0.0757821128',
#     '0.0416983776',
#     '0.0068071103',
#     '-0.0008577866'],
#    ['-0.0140470369',
#     '-0.2521746159',
#     '0.0715019330',
#     '-0.0245555844',
#     '-0.0637230650',
#     '-0.0363792926',
#     '0.1618654430',
#     '0.0267617349',
#     '-0.0475057885',
#     '0.0191809293',
#     '0.0102130733',
#     '0.0243246090',
#     '0.0691005439',
#     '-0.0130875874',
#     '0.0100059593',
#     '0.0384060591',
#     '0.0048987651',
#     '-0.0645632744',
#     '0.0061554275',
#     '-0.2643951178',
#     '-0.0436217710',
#     '0.0481976159',
#     '0.0964776799',
#     '0.0303503629',
#     '-0.0419443026',
#     '-0.0725289732',
#     '-0.0309239905',
#     '0.0357893668',
#     '0.0183183476',
#     '0.1034464762',
#     '0.1145463809',
#     '-0.0687584728',
#     '-0.0052948981',
#     '-0.2819453180',
#     '-0.2296230793',
#     '-0.0919692442',
#     '0.0032450440',
#     '0.7827215791',
#     '0.0971800312',
#     '-0.0344188288',
#     '-0.0813292637',
#     '0.1041836515',
#     '-0.0096769687',
#     '-0.0404449850',
#     '-0.1460328847',
#     '-0.0858742446',
#     '-0.0571354330',
#     '0.1671402007',
#     '-0.0320789590',
#     '-0.0203845315',
#     '-0.0316091292',
#     '0.0623241551',
#     '-0.1638111174',
#     '-0.0375008695',
#     '-0.0511924438',
#     '-0.2756403685',
#     '-0.2067030817',
#     '-0.2015297264',
#     '0.0877581164',
#     '-0.0350258127',
#     '-0.0384856761',
#     '-0.0003907204',
#     '0.0473652594',
#     '-0.1299982518',
#     '0.0051986678',
#     '-0.0483641401',
#     '0.0840214714',
#     '-0.1381398588',
#     '-0.0641841441',
#     '0.0140481852',
#     '-0.1044005752',
#     '-0.0455967747',
#     '0.0876867175',
#     '-0.0228637476',
#     '-0.0419424064',
#     '-0.1082736626',
#     '0.0767570436',
#     '-0.0058189910',
#     '0.0683184937',
#     '-0.3819470406',
#     '-0.0488641858',
#     '-0.0136823561',
#     '0.0042041922',
#     '0.0273898374',
#     '0.0017619773',
#     '-0.0764040500',
#     '0.0187839419',
#     '-0.0126136495',
#     '-0.0265979599',
#     '-0.0022307348',
#     '-0.0397253782',
#     '-0.0325681865',
#     '0.1004184932',
#     '0.0007887303',
#     '-0.3709552288',
#     '0.0142918192',
#     '-0.5056773424',
#     '-0.0563236475',
#     '-0.0323655270',
#     '-0.0150438268',
#     '0.0679076537',
#     '-0.0074618012',
#     '-0.0515629165',
#     '-0.1919198334',
#     '0.0230865348',
#     '0.0041166693',
#     '-0.0302731097',
#     '0.0056967721',
#     '0.0731676891',
#     '0.0721943900',
#     '0.0288530942',
#     '-0.1765866578',
#     '0.0102383653',
#     '0.5299022794',
#     '0.0130323526',
#     '0.0332197212',
#     '-0.0444980226',
#     '0.0497086830',
#     '0.0220255498',
#     '-0.0794000253',
#     '-0.0548917986',
#     '-0.0054580080',
#     '0.0151784001',
#     '-0.0195136853',
#     '-0.1830837727',
#     '-0.0861255750',
#     '0.0326891504',
#     '-0.1275683045',
#     '-0.0175937898',
#     '0.2193050832',
#     '-0.0151507454',
#     '0.0203543510',
#     '0.0680701882',
#     '-0.0003273289',
#     '-0.3027332723',
#     '-0.0579354614',
#     '-0.1059812233',
#     '0.1507357657',
#     '0.0009064961',
#     '0.2191822380',
#     '-0.0802065209',
#     '-0.0025828646',
#     '-0.0304704830',
#     '-0.0336230174',
#     '0.2452725023',
#     '0.0414466113',
#     '-0.8212800026',
#     '0.0119885541',
#     '-0.0472736880',
#     '0.0538554937',
#     '-0.4324164987',
#     '0.0061702598',
#     '0.2391372919',
#     '-0.0052665570',
#     '0.0046395897',
#     '0.0013087994',
#     '0.5302045345',
#     '-0.2481153160',
#     '0.0565272570',
#     '0.0617825985',
#     '0.0533116646',
#     '-0.0439541265',
#     '-0.2048905194',
#     '0.0076964260',
#     '0.0326398313',
#     '-0.0322006643',
#     '-0.0085423905',
#     '-0.1772449613',
#     '-0.0105685387',
#     '-0.1252601892',
#     '-0.0130995438',
#     '0.0266819540',
#     '0.0493296869',
#     '-0.0790763870',
#     '0.0805997699',
#     '0.0444043092',
#     '-0.0211875811',
#     '0.3405150473',
#     '0.0053735669',
#     '-0.0861864462',
#     '0.1063978076',
#     '0.1316533834',
#     '-0.0494623259',
#     '0.2878910899',
#     '-0.0545127019',
#     '0.2326889932',
#     '-0.0770395249',
#     '-0.0906221122',
#     '0.1124629751',
#     '0.1008397713',
#     '-0.1094483808',
#     '0.0340698026',
#     '-0.1274731308',
#     '0.0053732581',
#     '0.0216368455',
#     '-0.0083320243',
#     '-0.0621114112',
#     '0.0767328814',
#     '-0.1277791858',
#     '-0.0720385313',
#     '0.0082930839',
#     '0.6660360098',
#     '-0.0167873651',
#     '0.0465054959',
#     '0.0063235131',
#     '-0.0074500842',
#     '-0.0267454516',
#     '-0.0079835793',
#     '0.0482218526',
#     '-0.2655583918',
#     '0.1731809676',
#     '0.1059661880',
#     '0.0241693538',
#     '0.1088437811',
#     '-0.0682982281',
#     '-0.0113943545',
#     '0.1227510795',
#     '-0.0705569983',
#     '-0.1164379641',
#     '0.1824643761',
#     '-0.0260998681',
#     '0.1075505093',
#     '0.0819567740',
#     '-0.0716168210',
#     '-0.2241235971',
#     '0.0683481619',
#     '0.0585455671',
#     '0.0378724746',
#     '0.2510809302',
#     '-0.0656151548',
#     '0.0366687551',
#     '0.0143859591',
#     '-0.1206870750',
#     '0.0538402535',
#     '0.0329679698',
#     '0.1529629380',
#     '0.0070779803',
#     '-0.1196243316',
#     '0.0066617308',
#     '-0.0451752581',
#     '-0.0267202538',
#     '0.6864678264',
#     '0.0393932126',
#     '-0.0609485209',
#     '1.3706725836',
#     '-0.0411161594',
#     '0.0020104556',
#     '0.1064185277',
#     '0.1182666048',
#     '-0.4045625329',
#     '0.0442258827',
#     '0.1037338600',
#     '0.0726695657',
#     '-0.0822361931',
#     '0.0171763841',
#     '-0.0794767588',
#     '-0.0800647363',
#     '-0.0282604937',
#     '-0.1013556570',
#     '0.1520577520',
#     '0.0363528840',
#     '-0.1821440458',
#     '-0.1327088922',
#     '-0.1122761518',
#     '-0.0203313958',
#     '-0.0533409826',
#     '-0.0602380447',
#     '0.0791010782',
#     '0.3132679462',
#     '0.3043559790',
#     '-0.0950713828',
#     '-0.1197223589',
#     '0.1717844456',
#     '0.2628834248',
#     '-0.1347875893',
#     '-0.3195926547',
#     '0.1979920715',
#     '-0.4671708941',
#     '0.1230326369',
#     '-0.5155766010',
#     '0.0470938310',
#     '-0.2120081037',
#     '-0.1742130965',
#     '-0.1204480752',
#     '0.0024168149',
#     '-0.0434145816',
#     '-0.0343659334',
#     '-0.0141093116',
#     '-0.0519006923',
#     '0.0879419744',
#     '0.1051574349',
#     '0.0813961923',
#     '-0.0323029421',
#     '0.0973433256',
#     '-0.0104865525',
#     '0.0093293209',
#     '-0.0196084771',
#     '0.1370442212',
#     '0.0045107394',
#     '0.0329234600'],
#    ['-0.0346625410',
#     '-0.0651641488',
#     '-0.0408765562',
#     '0.1219506487',
#     '-0.0232617855',
#     '-0.0376455970',
#     '0.2018600702',
#     '0.0092212763',
#     '0.1127445251',
#     '0.0291080009',
#     '0.0452539586',
#     '-0.0202839524',
#     '0.0734757259',
#     '0.0239273664',
#     '-0.0369532444',
#     '-0.0156952050',
#     '-0.0044415910',
#     '0.0241668541',
#     '-0.0503467917',
#     '-0.0235735532',
#     '0.0463157147',
#     '-0.0034704388',
#     '0.0291366410',
#     '0.0021512031',
#     '-0.0778777227',
#     '0.0266703423',
#     '-0.0024491728',
#     '-0.0408767872',
#     '-0.0039235628',
#     '0.0311503764',
#     '0.1653513759',
#     '0.0106966598',
#     '0.0437256955',
#     '0.0677728578',
#     '-0.0659952983',
#     '0.0303008258',
#     '0.1428831667',
#     '0.0208755787',
#     '0.0283525120',
#     '-0.0445936508',
#     '-0.0469394475',
#     '-0.0758544579',
#     '-0.0174254645',
#     '0.0113202166',
#     '-0.0083053028',
#     '0.0824482739',
#     '0.0362987630',
#     '0.0022947907',
#     '-0.0002342941',
#     '0.0112020150',
#     '-0.0163624752',
#     '-0.0291802343',
#     '0.0106028942',
#     '-0.0054687141',
#     '0.0181946736',
#     '-0.0007314749',
#     '0.0079374937',
#     '0.0990238339',
#     '-0.1066265330',
#     '0.0095662978',
#     '-0.0075342269',
#     '0.0146654686',
#     '0.0304109603',
#     '-0.0934050381',
#     '0.0282037258',
#     '-0.0323361829',
#     '-0.0099136038',
#     '-0.0726153031',
#     '-0.0429105237',
#     '-0.0492161326',
#     '0.0040691700',
#     '-0.0299162660',
#     '0.0574828871',
#     '-0.0516968630',
#     '0.0528368056',
#     '0.0023242205',
#     '-0.0389323495',
#     '-0.0643827692',
#     '0.0383756943',
#     '0.0070122788',
#     '-0.0315236263',
#     '-0.0025109078',
#     '-0.0078551052',
#     '-0.0418584198',
#     '0.0119743748',
#     '0.0695486590',
#     '0.0359967537',
#     '-0.0968908370',
#     '0.0857091919',
#     '0.0539243706',
#     '-0.0201696306',
#     '-0.0459763967',
#     '0.0104646264',
#     '0.0116116209',
#     '0.0410880111',
#     '-0.0118083684',
#     '0.0100599620',
#     '-0.0029381828',
#     '0.0213852394',
#     '-0.0291953385',
#     '-0.0385238342',
#     '-0.0465626344',
#     '-0.0746225864',
#     '-0.0385614745',
#     '0.0581657365',
#     '-0.0107763400',
#     '0.0347390957',
#     '0.0448206104',
#     '-0.0247672684',
#     '-0.0250197630',
#     '-0.0339056663',
#     '0.0345520787',
#     '0.0281290766',
#     '0.0136902928',
#     '0.0416502766',
#     '-0.0448757894',
#     '0.0251234062',
#     '0.0131742051',
#     '-0.0876013711',
#     '0.0312160049',
#     '-0.0090422435',
#     '-0.0693942234',
#     '-0.0235007983',
#     '-0.0469566099',
#     '0.0226390939',
#     '-0.0211523473',
#     '0.0101235509',
#     '-0.0214517675',
#     '-0.0300648045',
#     '-0.1234059110',
#     '0.0113846110',
#     '0.0365941189',
#     '-0.0205312651',
#     '0.0610707998',
#     '-0.0361469500',
#     '-0.0268019438',
#     '0.0426561199',
#     '-0.0427242778',
#     '0.0403721631',
#     '0.0534878261',
#     '-0.0461139344',
#     '0.0410227254',
#     '0.0453787185',
#     '0.0454312675',
#     '-0.0302040279',
#     '0.0055105882',
#     '-0.1119462252',
#     '0.0244855229',
#     '-0.0251590144',
#     '-0.0642503873',
#     '-0.0735870525',
#     '0.0063855485',
#     '-0.0936386138',
#     '-0.0417222343',
#     '-0.0047910810',
#     '0.0701461807',
#     '0.0074127913',
#     '0.0051965923',
#     '0.0310334656',
#     '-0.0542756580',
#     '0.0281926692',
#     '-0.0217702854',
#     '-0.0927718505',
#     '-0.0239148494',
#     '-0.0950577781',
#     '-0.0518071316',
#     '-0.0349328034',
#     '0.1070801020',
#     '-0.0287677776',
#     '-0.0391571783',
#     '0.0593241416',
#     '-0.0150985811',
#     '0.0593030453',
#     '-0.0042163916',
#     '0.0273221619',
#     '-0.0197342131',
#     '-0.0275651161',
#     '0.0984371826',
#     '0.0221091975',
#     '-0.0572628938',
#     '0.0728184357',
#     '-0.0368092470',
#     '0.0092009073',
#     '-0.0389616750',
#     '-0.0372314565',
#     '0.0351536535',
#     '-0.0008930147',
#     '0.0930660293',
#     '-0.0029708862',
#     '-0.0363673978',
#     '-0.0382690765',
#     '0.0435281694',
#     '-0.0030977873',
#     '-0.0554362349',
#     '0.0312306322',
#     '0.0305411965',
#     '0.0450026952',
#     '0.0376694985',
#     '-0.0491582304',
#     '-0.0065255761',
#     '-0.0053855511',
#     '0.1432574093',
#     '-0.0271062702',
#     '-0.0190941561',
#     '-0.0223664735',
#     '0.1044121310',
#     '-0.0285317283',
#     '-0.0239834320',
#     '-0.0902028680',
#     '-0.1072615907',
#     '-0.0173782017',
#     '-0.0209986754',
#     '0.0015663430',
#     '0.0359029174',
#     '0.0270054694',
#     '0.0045486852',
#     '-0.0376547985',
#     '0.0886896849',
#     '0.0656464547',
#     '-0.0514155291',
#     '0.1070585847',
#     '-0.0065612453',
#     '0.0500360392',
#     '0.0799184516',
#     '0.0553543679',
#     '0.0586231947',
#     '0.0064312401',
#     '0.0768070966',
#     '0.1070393696',
#     '-0.0619918518',
#     '-0.0381561555',
#     '-0.0629393309',
#     '0.0995378420',
#     '0.0080050807',
#     '0.0458273478',
#     '-0.0115713505',
#     '0.0462256446',
#     '-0.0254797395',
#     '0.0795811638',
#     '-0.0634839609',
#     '-0.0506757013',
#     '0.0028760822',
#     '-0.1211852804',
#     '-0.0870946571',
#     '0.1310647428',
#     '0.0429485701',
#     '0.0437950455',
#     '0.0831807032',
#     '0.0097412067',
#     '0.0224099644',
#     '0.0428843051',
#     '-0.0100079365',
#     '0.0148477620',
#     '0.0377336554',
#     '0.0026295246',
#     '0.0067134663',
#     '-0.0453421250',
#     '0.0049641295',
#     '-0.0496629290',
#     '0.0277156364',
#     '-0.0185407605',
#     '0.0063641430',
#     '-0.0354613103',
#     '-0.0028282695',
#     '0.1158779487',
#     '-0.0085255969',
#     '-0.0346291550',
#     '0.0673579797',
#     '0.0146481842',
#     '0.0029691726',
#     '-0.1054074764',
#     '0.0000672162',
#     '-0.0454903618',
#     '-0.0752331838',
#     '-0.1065382138',
#     '0.0393109173',
#     '-0.0267425366',
#     '0.0090955598',
#     '-0.0247858707',
#     '0.0544622540',
#     '-0.0272891466',
#     '0.0590526462',
#     '-0.0035608120',
#     '0.0985456631',
#     '-0.0812678710',
#     '0.0237767808',
#     '0.0612093583',
#     '-0.0158715751',
#     '-0.0648394600',
#     '-0.0126000186',
#     '0.0260250960',
#     '0.1145104915',
#     '0.0254588071',
#     '0.0001308411',
#     '0.0418315642',
#     '0.0619346164',
#     '-0.0167872757',
#     '0.0654610023',
#     '0.0465950631',
#     '0.0171428807'],
#    ['-0.0279658474',
#     '-0.1094825268',
#     '-0.0105827888',
#     '0.1695864201',
#     '0.0130763836',
#     '-0.0409209616',
#     '0.0937784165',
#     '-0.0604486465',
#     '0.0704840869',
#     '0.0574368872',
#     '-0.0249384772',
#     '-0.0465568602',
#     '0.0252979696',
#     '-0.0453713015',
#     '0.0426439270',
#     '-0.0450261161',
#     '0.0149488486',
#     '0.0925647244',
#     '0.0411352627',
#     '-0.0091355667',
#     '0.0870438069',
#     '0.0171838459',
#     '-0.0209530778',
#     '0.0316948928',
#     '-0.0712861121',
#     '0.0403105691',
#     '-0.0180080589',
#     '-0.0522492975',
#     '-0.0105079478',
#     '0.1104827747',
#     '0.0504413359',
#     '0.0181826539',
#     '-0.0338679925',
#     '0.1063155830',
#     '0.0554201566',
#     '-0.0242996253',
#     '0.1718820930',
#     '0.0369733572',
#     '0.0414526016',
#     '-0.0187745597',
#     '0.0120636644',
#     '-0.1689168662',
#     '0.0131049138',
#     '-0.0164604709',
#     '-0.0887415335',
#     '0.0239251573',
#     '-0.0799569562',
#     '-0.0957214758',
#     '-0.0111935865',
#     '0.0142286746',
#     '0.0063704560',
#     '-0.0279534459',
#     '0.0323661305',
#     '-0.1216354892',
#     '0.0160783809',
#     '0.0909582525',
#     '0.0225369092',
#     '0.1225969195',
#     '-0.1041415408',
#     '0.0710083842',
#     '0.0248765107',
#     '-0.0361480825',
#     '0.1120279953',
#     '-0.0778374970',
#     '0.0580705851',
#     '-0.1220141798',
#     '-0.0526306890',
#     '-0.0912412703',
#     '-0.0971325561',
#     '-0.0447113514',
#     '0.0006744834',
#     '-0.0031970106',
#     '0.0921708122',
#     '-0.0147383045',
#     '0.1513650864',
#     '-0.0097112134',
#     '0.0740607381',
#     '-0.1605669260',
#     '0.0082215685',
#     '0.0897115692',
#     '-0.0817084238',
#     '0.0551984794',
#     '0.0897353441',
#     '-0.1084323302',
#     '0.0042977161',
#     '0.0051735966',
#     '0.0665979981',
#     '-0.1765689999',
#     '0.1785876304',
#     '0.0843533278',
#     '-0.0702707767',
#     '-0.0089915898',
#     '0.0118773906',
#     '-0.1092495918',
#     '0.0254500955',
#     '-0.0204127338',
#     '0.0689232424',
#     '-0.1707618088',
#     '-0.0335930996',
#     '-0.1173209026',
#     '-0.0856724232',
#     '-0.0675538182',
#     '-0.1537254602',
#     '-0.0576867610',
#     '0.0227208622',
#     '-0.0016838596',
#     '0.0110172080',
#     '0.0320402533',
#     '-0.0223629940',
#     '-0.0904425606',
#     '-0.0105522340',
#     '-0.0523577034',
#     '0.1050955504',
#     '0.0866272599',
#     '0.0930622667',
#     '0.0466498248',
#     '0.0172614362',
#     '0.0214240346',
#     '-0.0257213656',
#     '-0.0725105479',
#     '-0.0504120216',
#     '0.0473456345',
#     '-0.0487893671',
#     '-0.0499125384',
#     '-0.0609936975',
#     '-0.0716221333',
#     '-0.0538899824',
#     '-0.0535423383',
#     '0.0223985426',
#     '-0.1272553355',
#     '0.0229777209',
#     '0.1327143610',
#     '0.0958185196',
#     '0.1433782279',
#     '0.0032164762',
#     '0.0168912597',
#     '0.1204649210',
#     '-0.0676044077',
#     '0.1415490508',
#     '0.0874603540',
#     '-0.0692602322',
#     '-0.0361850560',
#     '0.0288779158',
#     '0.0347618461',
#     '-0.0214584824',
#     '-0.1384284198',
#     '-0.1448790431',
#     '-0.0011347942',
#     '0.1457548887',
#     '0.1297732592',
#     '-0.0703792945',
#     '0.0368772149',
#     '0.0564113818',
#     '-0.0519936271',
#     '-0.0379431956',
#     '-0.0467417501',
#     '-0.0163483303',
#     '0.0078750281',
#     '0.0449492671',
#     '-0.1486822218',
#     '0.0376332514',
#     '-0.0383607112',
#     '-0.0841135755',
#     '-0.0681206882',
#     '0.0213095155',
#     '-0.1086680591',
#     '0.0338155851',
#     '0.1000258178',
#     '-0.0110411532',
#     '0.0199296698',
#     '-0.0756264031',
#     '-0.0600736439',
#     '0.0504628159',
#     '-0.0127724316',
#     '0.0362423435',
#     '0.0565396734',
#     '0.0226311684',
#     '0.0961222723',
#     '-0.1271358132',
#     '-0.0516716689',
#     '0.0782150924',
#     '-0.0240800641',
#     '-0.0254050400',
#     '-0.0296274498',
#     '0.0321464166',
#     '-0.0003231056',
#     '0.0434012152',
#     '-0.0708712786',
#     '-0.0153132062',
#     '0.0247237179',
#     '-0.0453401953',
#     '-0.0503070131',
#     '0.0150146196',
#     '0.0239372086',
#     '0.0528185628',
#     '0.1007761583',
#     '-0.0440192744',
#     '0.0918982252',
#     '0.1088932976',
#     '0.0171688590',
#     '0.0129037835',
#     '0.1464858055',
#     '-0.0108051337',
#     '-0.0383470878',
#     '-0.0239930227',
#     '0.0605528839',
#     '0.0142861363',
#     '0.0118297730',
#     '-0.0545629822',
#     '-0.0546418056',
#     '0.0189092867',
#     '-0.0317902975',
#     '0.0268559363',
#     '0.0341683179',
#     '0.0011317180',
#     '0.0645402223',
#     '-0.0908356234',
#     '-0.0036098943',
#     '0.0628018007',
#     '-0.0321380645',
#     '0.0961540565',
#     '0.0168079734',
#     '0.0050109741',
#     '0.0085732043',
#     '0.0078724697',
#     '-0.1136527434',
#     '0.0430316143',
#     '-0.0523271337',
#     '0.1643794477',
#     '-0.0714154020',
#     '-0.0204553045',
#     '-0.0044631893',
#     '0.0636019856',
#     '0.0569538176',
#     '0.0050304723',
#     '0.1011702642',
#     '-0.0516310893',
#     '0.0471788757',
#     '0.1335348040',
#     '-0.0714331046',
#     '-0.0811329111',
#     '0.0213503689',
#     '-0.0915687755',
#     '-0.0814538300',
#     '0.1507964432',
#     '0.0306357294',
#     '0.0620485619',
#     '-0.0311462004',
#     '0.0166573711',
#     '0.0040262826',
#     '0.0450086482',
#     '-0.0876924694',
#     '0.0103916544',
#     '0.0014312267',
#     '0.0096192556',
#     '-0.0790359899',
#     '0.0213983022',
#     '0.0945142284',
#     '-0.0397791490',
#     '-0.0303159207',
#     '-0.0003005995',
#     '0.0012638809',
#     '-0.0081484243',
#     '-0.0959885120',
#     '0.0695269629',
#     '0.0684362203',
#     '0.0161885042',
#     '0.1266072690',
#     '0.1029616520',
#     '0.0434271321',
#     '-0.0293153599',
#     '-0.0467417091',
#     '-0.0683826357',
#     '-0.0409378111',
#     '-0.1721588522',
#     '0.0443340950',
#     '-0.0739714280',
#     '-0.0240233596',
#     '-0.0410308316',
#     '-0.0214939155',
#     '0.0573254190',
#     '0.1226867661',
#     '0.0191065781',
#     '0.0711516291',
#     '-0.0979546532',
#     '0.0882339105',
#     '0.0143727763',
#     '0.0742068291',
#     '-0.0665645599',
#     '-0.0734093189',
#     '-0.0052220188',
#     '0.0472516008',
#     '-0.0184007436',
#     '-0.0137256663',
#     '-0.0854653940',
#     '0.0121816630',
#     '-0.0033432757',
#     '0.1123864874',
#     '0.0193697605',
#     '-0.0434106663'],
#    ['0.0237968452',
#     '-0.0083763599',
#     '0.0341439955',
#     '0.0705902502',
#     '0.0157009251',
#     '-0.0229128823',
#     '0.0237176828',
#     '0.0202882700',
#     '0.0286641996',
#     '0.0750714242',
#     '-0.0084128110',
#     '-0.0437456332',
#     '0.0389940292',
#     '-0.0099715367',
#     '-0.0092549380',
#     '-0.0201148130',
#     '-0.0312138982',
#     '0.0257898066',
#     '-0.0318484716',
#     '-0.0141933355',
#     '-0.0046508056',
#     '0.0143802790',
#     '-0.0133513724',
#     '0.0285391454',
#     '-0.0186435170',
#     '0.0913833901',
#     '-0.0428452082',
#     '-0.0486394130',
#     '-0.0045743664',
#     '0.0791370794',
#     '0.0328833833',
#     '-0.0156464707',
#     '0.0276475288',
#     '-0.0031780617',
#     '0.0214590337',
#     '0.0189361777',
#     '0.0425318927',
#     '0.0366497748',
#     '-0.0054348051',
#     '-0.0258541703',
#     '0.0398739576',
#     '-0.0189821292',
#     '-0.0002710503',
#     '-0.0206417739',
#     '-0.0700880438',
#     '0.0096088741',
#     '0.0278737694',
#     '-0.0239165463',
#     '-0.0493981205',
#     '-0.0045132618',
#     '0.0169623327',
#     '-0.0210625026',
#     '0.0240471046',
#     '-0.0355100967',
#     '-0.0157362614',
#     '-0.0228454117',
#     '-0.0062221973',
#     '0.0558375679',
#     '-0.0477416329',
#     '0.0303902663',
#     '0.0043403148',
#     '-0.0536502860',
#     '0.0488557182',
#     '0.0176979061',
#     '-0.0381026417',
#     '0.0182817169',
#     '0.0166712794',
#     '-0.0227710083',
#     '-0.0664114282',
#     '0.0294927601',
#     '0.0145040108',
#     '0.0261865407',
#     '-0.0372034647',
#     '0.0339510925',
#     '-0.0091098957',
#     '-0.0121224588',
#     '-0.0072645000',
#     '-0.0128185218',
#     '-0.0367941745',
#     '0.0183305647',
#     '-0.0013614300',
#     '-0.0073914006',
#     '0.0077066692',
#     '-0.0504753590',
#     '0.0011733681',
#     '-0.0353034735',
#     '0.0441414602',
#     '-0.0253310204',
#     '0.0717583522',
#     '-0.0146223605',
#     '0.0103839273',
#     '-0.0351268910',
#     '-0.0150560662',
#     '-0.0068828687',
#     '-0.0088132201',
#     '0.0042637885',
#     '0.0143034402',
#     '-0.0710209459',
#     '-0.0022180916',
#     '-0.0357842520',
#     '-0.0758469403',
#     '-0.0913542658',
#     '-0.0864809006',
#     '-0.0626261458',
#     '-0.0359113850',
#     '0.0235544052',
#     '0.0046736831',
#     '0.0274498295',
#     '0.0640072674',
#     '-0.0054927766',
#     '-0.0040787025',
#     '0.0146199381',
#     '0.0122536262',
#     '0.0462091938',
#     '-0.0186075177',
#     '0.0119528463',
#     '0.0337446779',
#     '0.0162493363',
#     '0.0249571744',
#     '0.0001018822',
#     '0.0336071737',
#     '0.0128752468',
#     '-0.0003774354',
#     '-0.0182877872',
#     '-0.1009258851',
#     '-0.0252962690',
#     '0.0320546590',
#     '0.0446792953',
#     '0.0251564961',
#     '-0.0132119507',
#     '-0.0227499846',
#     '0.0991003662',
#     '-0.0233107433',
#     '0.0465392731',
#     '0.0698775575',
#     '0.0011760101',
#     '0.0905654952',
#     '-0.0231634919',
#     '-0.0217400137',
#     '-0.0537541993',
#     '0.0087775774',
#     '-0.0120824156',
#     '-0.0091501987',
#     '0.0186870173',
#     '0.0016294256',
#     '-0.0347876027',
#     '-0.0506619103',
#     '0.0085231429',
#     '-0.0109618232',
#     '0.0114345299',
#     '-0.0120557128',
#     '-0.0219517611',
#     '0.0046681138',
#     '-0.0211658832',
#     '-0.0102962693',
#     '0.0299643874',
#     '-0.0320810787',
#     '0.0001849763',
#     '0.0150418850',
#     '-0.0269987416',
#     '-0.0487467274',
#     '0.0093561979',
#     '0.0107115759',
#     '0.0179820210',
#     '0.0398318395',
#     '-0.0180021953',
#     '0.0087232115',
#     '0.0331232212',
#     '0.0257899463',
#     '-0.0159882177',
#     '0.0041526700',
#     '-0.0127704591',
#     '0.0347903594',
#     '-0.0088391611',
#     '-0.0163865983',
#     '0.0339223817',
#     '0.0307565164',
#     '0.0292800851',
#     '-0.0236609597',
#     '-0.0384203903',
#     '0.0570662916',
#     '-0.0232327208',
#     '-0.0045558549',
#     '-0.0502117053',
#     '0.0315926634',
#     '0.0085622724',
#     '0.0147731770',
#     '-0.0431256965',
#     '-0.0086370818',
#     '-0.0520691089',
#     '0.0055522430',
#     '-0.0267903153',
#     '-0.0501754843',
#     '-0.0271035340',
#     '0.0215219501',
#     '0.0400892086',
#     '0.0709500313',
#     '0.0509496406',
#     '-0.0054214695',
#     '-0.0168641340',
#     '0.0296781547',
#     '0.0089808935',
#     '-0.0119059673',
#     '0.0287097488',
#     '-0.0118777212',
#     '0.0359420367',
#     '-0.0139088901',
#     '0.0031095736',
#     '0.0157008506',
#     '0.0399728976',
#     '-0.0093346760',
#     '-0.0153782284',
#     '-0.0281765759',
#     '-0.0369549356',
#     '0.0521999672',
#     '-0.0391283706',
#     '-0.0308526102',
#     '-0.0486320704',
#     '0.0323626250',
#     '0.0011819296',
#     '0.0202212911',
#     '-0.0224786680',
#     '-0.0380465910',
#     '-0.0052986704',
#     '0.0105128242',
#     '-0.0310890526',
#     '-0.0187185947',
#     '0.0041946769',
#     '0.0525623560',
#     '-0.0478462093',
#     '-0.0056254244',
#     '0.0045088679',
#     '0.0215094872',
#     '0.0074932808',
#     '-0.0156107666',
#     '0.0055001946',
#     '0.0097873239',
#     '0.0262870584',
#     '0.0168993231',
#     '-0.0114873648',
#     '-0.0439429171',
#     '0.0118870456',
#     '-0.0175982863',
#     '-0.0267588031',
#     '0.0681974664',
#     '0.0262746401',
#     '-0.0003724754',
#     '-0.0278050788',
#     '-0.0370247327',
#     '0.0192452800',
#     '0.0343647264',
#     '0.0110118259',
#     '0.0009151321',
#     '-0.0797272325',
#     '0.0233381074',
#     '0.0480592065',
#     '0.0142015908',
#     '0.0307147708',
#     '0.0016646441',
#     '-0.0435843542',
#     '0.0361126103',
#     '-0.0232037958',
#     '-0.0216243677',
#     '0.0355365239',
#     '0.0610963181',
#     '0.0193585344',
#     '-0.0707954094',
#     '-0.0061802547',
#     '-0.0186443757',
#     '0.0724837407',
#     '-0.1015703827',
#     '-0.0245721545',
#     '0.0286797229',
#     '0.0234210175',
#     '-0.0542732254',
#     '0.0202523023',
#     '-0.0583506338',
#     '0.0363036506',
#     '0.0320714340',
#     '0.0116063049',
#     '-0.0449998826',
#     '0.0277362894',
#     '-0.0119929528',
#     '-0.0379290171',
#     '-0.0412241668',
#     '0.0344476663',
#     '0.0164164510',
#     '0.0042195930',
#     '-0.0008867953',
#     '-0.0727678090',
#     '-0.0081769712',
#     '0.1005823165',
#     '0.0180215593',
#     '0.0460463688',
#     '-0.0337889902',
#     '0.0025824900',
#     '0.0066585750',
#     '0.0796716213',
#     '0.0671158731',
#     '-0.0243276805'],
#    ['0.0475865491',
#     '-0.0260394532',
#     '-0.0574971959',
#     '-0.0330236852',
#     '-0.0072625689',
#     '-0.1196589097',
#     '0.0963159725',
#     '-0.0222008470',
#     '0.0020501965',
#     '0.0476900786',
#     '-0.0095434319',
#     '0.0038259479',
#     '0.0021893641',
#     '0.0093038622',
#     '-0.0714942068',
#     '0.0850827843',
#     '-0.0160388555',
#     '-0.0138859432',
#     '-0.0350103639',
#     '-0.0366970114',
#     '-0.0540128648',
#     '-0.0484827869',
#     '-0.0092709232',
#     '0.0136545422',
#     '0.0379806422',
#     '-0.0107420171',
#     '-0.0704417452',
#     '0.0013220351',
#     '0.0195235498',
#     '0.0611253493',
#     '-0.0011393809',
#     '0.0421083234',
#     '-0.0136323106',
#     '-0.0539047308',
#     '-0.0617476031',
#     '0.0561222136',
#     '0.0494493023',
#     '0.0744739622',
#     '-0.0244765170',
#     '-0.0052101081',
#     '0.0494701639',
#     '-0.0683569461',
#     '-0.0456050858',
#     '0.0403928086',
#     '-0.0672069937',
#     '0.0528862663',
#     '-0.0207341686',
#     '-0.0026143140',
#     '-0.0111485813',
#     '-0.0280634705',
#     '0.0219697542',
#     '-0.0129792551',
#     '-0.0005121790',
#     '0.0232831333',
#     '0.0272872895',
#     '0.0140320435',
#     '0.0770429671',
#     '0.0051106382',
#     '0.0155739067',
#     '0.0111471619',
#     '0.0098758340',
#     '-0.0341413468',
#     '-0.0414336883',
#     '0.0655886233',
#     '0.0100724567',
#     '0.0341693237',
#     '0.0250575133',
#     '-0.1040411070',
#     '0.0067123529',
#     '-0.0397860780',
#     '0.0432952568',
#     '-0.1028010547',
#     '-0.0290003642',
#     '-0.0049545262',
#     '0.0182302725',
#     '0.0126683358',
#     '0.0620190278',
#     '-0.0000168208',
#     '-0.0653814822',
#     '0.0191418901',
#     '-0.0213699024',
#     '0.0079832003',
#     '-0.0423093885',
#     '-0.0146700535',
#     '-0.0225606766',
#     '0.0234138090',
#     '0.0273356289',
#     '-0.0297903009',
#     '0.0760786161',
#     '0.0148902861',
#     '0.0124374386',
#     '0.0250289161',
#     '0.0058102268',
#     '-0.0705543905',
#     '0.1033366472',
#     '0.0524526276',
#     '0.0004241653',
#     '-0.0501266085',
#     '0.0064240205',
#     '-0.0711165518',
#     '-0.0269471332',
#     '-0.0783371776',
#     '-0.0605452731',
#     '-0.0224868078',
#     '0.0607300103',
#     '0.0185508654',
#     '0.0024766934',
#     '0.0418665558',
#     '-0.0706559420',
#     '-0.0380460247',
#     '-0.0410917625',
#     '-0.0158700682',
#     '0.0272822343',
#     '0.0413314626',
#     '0.0378917232',
#     '-0.0298457295',
#     '0.0269023627',
#     '0.0713721514',
#     '-0.0723876879',
#     '0.0659717321',
#     '0.0402274840',
#     '0.0025632207',
#     '0.0098534739',
#     '-0.0053566862',
#     '-0.0041059623',
#     '-0.0072301468',
#     '-0.0233768933',
#     '0.0515646972',
#     '0.0479758047',
#     '-0.0479967929',
#     '-0.0354788825',
#     '0.0687350109',
#     '0.0134222554',
#     '-0.0451518670',
#     '-0.0221651979',
#     '-0.0368525907',
#     '-0.0060232165',
#     '-0.0010318727',
#     '0.0135709541',
#     '-0.0914115757',
#     '0.0036234874',
#     '0.0077693257',
#     '-0.0213835258',
#     '0.0434183963',
#     '-0.0695089549',
#     '-0.0208868161',
#     '-0.0984965116',
#     '-0.0387514085',
#     '0.0228500981',
#     '0.0505943820',
#     '-0.0111434190',
#     '0.0143489465',
#     '-0.0323276035',
#     '-0.0018659988',
#     '-0.0821524486',
#     '-0.0099452734',
#     '0.0609730668',
#     '-0.0221892856',
#     '0.0320805274',
#     '-0.0134701896',
#     '0.0515290424',
#     '-0.0993456990',
#     '0.0160876364',
#     '-0.0452076048',
#     '-0.0588555038',
#     '-0.0806624070',
#     '0.0339344256',
#     '0.0250616297',
#     '-0.0125335781',
#     '0.0389591157',
#     '-0.0515778214',
#     '-0.0240521859',
#     '0.0840637833',
#     '-0.0688439608',
#     '0.0533884354',
#     '0.0278774574',
#     '0.0250331070',
#     '0.0267307721',
#     '-0.0019000120',
#     '0.0765797943',
#     '-0.0029339560',
#     '-0.0229103751',
#     '0.0309062619',
#     '-0.0925292149',
#     '0.0151283387',
#     '0.0012471315',
#     '0.0182066113',
#     '0.0088524930',
#     '-0.0378369056',
#     '0.0056692190',
#     '0.0060135056',
#     '0.0504893698',
#     '0.0509827323',
#     '-0.0525627024',
#     '0.0312380455',
#     '0.0275675543',
#     '0.0376268886',
#     '0.0638258532',
#     '-0.0254617538',
#     '0.0468028337',
#     '0.0151961623',
#     '-0.0796120688',
#     '-0.0556066334',
#     '-0.0214868225',
#     '0.0198815987',
#     '0.0237187203',
#     '-0.0589769185',
#     '-0.0274611823',
#     '-0.0360052176',
#     '0.0177783594',
#     '-0.1517941207',
#     '-0.0145806102',
#     '-0.0611996204',
#     '-0.0552123822',
#     '-0.0502330847',
#     '-0.0423878059',
#     '-0.0283772144',
#     '-0.0146702044',
#     '0.0870081410',
#     '-0.1050859839',
#     '0.1065903455',
#     '0.0573600829',
#     '0.0062000039',
#     '0.0290890895',
#     '-0.0378708765',
#     '0.0100770127',
#     '-0.0054728263',
#     '0.0186780673',
#     '0.0814318433',
#     '-0.0040523498',
#     '0.0128162829',
#     '-0.0177964643',
#     '0.0382970460',
#     '0.0101049710',
#     '-0.0368654057',
#     '-0.0299014114',
#     '0.0251258053',
#     '0.0042895870',
#     '-0.0727547631',
#     '-0.0555194393',
#     '-0.0901056603',
#     '0.0235147439',
#     '-0.0430650935',
#     '-0.0403238051',
#     '0.1166239530',
#     '0.0441655442',
#     '-0.0549957529',
#     '0.0421668440',
#     '0.0216385797',
#     '0.0500910729',
#     '-0.0473982804',
#     '0.0216331128',
#     '0.0052340566',
#     '0.0351010561',
#     '-0.0706470311',
#     '0.0847001746',
#     '0.0214043949',
#     '0.0221956857',
#     '-0.0603253581',
#     '-0.0482625104',
#     '0.0287557561',
#     '0.0709345937',
#     '-0.0589295216',
#     '-0.0078287395',
#     '0.0261926763',
#     '0.0035349862',
#     '-0.0240166727',
#     '0.0187345538',
#     '-0.0038303244',
#     '0.0368694142',
#     '-0.0398769043',
#     '-0.0229233764',
#     '0.0148104243',
#     '-0.0634711012',
#     '-0.0812120065',
#     '0.0065602981',
#     '-0.0547275245',
#     '-0.0486813150',
#     '-0.0573506802',
#     '-0.0533273630',
#     '0.0578188077',
#     '-0.0001465348',
#     '0.0238528010',
#     '0.0027292108',
#     '-0.0314679258',
#     '0.0064970423',
#     '0.0230687819',
#     '0.0164240897',
#     '-0.0416606590',
#     '-0.0723336339',
#     '-0.0778441131',
#     '0.0049797343',
#     '0.0117659969',
#     '0.0767480060',
#     '-0.0307816211',
#     '0.0221427605',
#     '0.0317285471',
#     '0.0374958515',
#     '-0.0258205626',
#     '0.0905739293']]},)

# %% [markdown]
# # 4. Cosine Similarities (Bonus Point)

# %% [markdown]
# In this section we compute the cosine similarity between the titles of the papers using the embeddings generated in the previous part of the notebook.
#
# In order to compute the cosine similarity, we need to convert back the embeddings from string to array. To this end, we define two functions and we map them to the dask bag that contains the embedddings for the titles of the papers.

# %%
def string_to_float(title):
    return np.array([[float(w) for w in word] for word in title])


def float_db(record):
    return {
        "title": record['title'],
        "embedding": string_to_float(record['emb_title'])
    }

titles_emb = db.from_sequence(jfiles.map(float_db)).compute() # list of dictionaries
titles_emb[1] # dictionary with the paper_id and the embedding for the title
# Out:
# {'title': 'Porcine epidemic diarrhea virus N protein prolongs S-phase cell cycle, induces endoplasmic reticulum stress, and up-regulates interleukin-8 expression',
#  'embedding': array([[ 0.11259791, -0.08943596,  0.06739864, ...,  0.07181671,
#           0.03540783,  0.03851681],
#         [ 0.01789738, -0.00506568,  0.04937705, ...,  0.06316409,
#           0.12435553,  0.04923374],
#         [ 0.00742944, -0.01183865,  0.06509748, ...,  0.07222264,
#           0.02185644, -0.00609187],
#         ...,
#         [ 0.03701144,  0.01375189, -0.00625162, ...,  0.00516427,
#           0.01857092,  0.00152456],
#         [ 0.06229753,  0.02009709, -0.00328165, ...,  0.04872797,
#           0.01969829, -0.0386173 ],
#         [ 0.0667282 ,  0.02106262,  0.01536188, ...,  0.03783946,
#           0.01066694,  0.07477056]])}

# %% [markdown]
# Each embedding is a list of vectors, with one vector for each word of the title. As a consequence, the embeddings are not all of the same length, so we have to cut some of them in order to be able to compute the cosine similarity: to this end, we compute the minimum length between the two titles we are analyzing and cut the larger one. For example, if two titles have 10 and 16 words respectively, we compute the cosine of the first 10 words.

# %%
import math
# Function to compute the cosine similarity
def cos_sim(x,y):
    # we flatten the list of vectors first
    x = x.flatten()
    y = y.flatten()
    # we compute where to cut the longer vector
    m   = min(len(x), len(y))
    # cosine similarity
    xx  = np.sqrt(np.dot(x,x))
    yy  = np.sqrt(np.dot(y,y))
    cosine = np.dot(x[:m],y[:m])/(xx*yy)
    
    if math.isnan(cosine):  # check for nan
        return 0.
    else:
        return cosine

# Function for computing the cosine similarity with dask.bag
def cos_sim_bag(db):
    
    s = cos_sim(db[0]['embedding'], db[1]['embedding'])
    
    return {
        "Paper_1": db[0]['title'],
        "Paper_2": db[1]['title'],
        "Cosine_Similarity": s
    }

# %% [markdown]
# Before starting the computation, let us checking whether or not it is worth to use dask in this case

# %%
# %%timeit
# default = 45 partitions (the unique pairs of the first ten papers)
# with this restricted dataset, we can use 1 partition only:
# in this way, we prevent the scheduler to organize the computation among them ––> faster code 
dask = (db.from_sequence([(titles_emb[i], titles_emb[j]) for i in range(10) for j in range(i+1, 10)])
                .repartition(1).map(cos_sim_bag).compute())
# Out:
# 121 ms ± 2.97 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# This approach scales badly with the number of papers (even if we increase the number of partitions), making impossible to apply the previous code to the full dataset. The serial approach is much faster instead, as we show with the following cells: it takes about 1 ms, making the distributed approach pointless.

# %%
# Function for computing the cosine similarity with arrays
def cos_sim_array(record1, record2):
    
    s = cos_sim(record1['embedding'], record2['embedding'])

    return {
        "Paper_1": record1['title'],
        "Paper_2": record2['title'],
        "Cosine_Similarity": s
    }

# %%
# %%timeit
sim_ser = [cos_sim_array(titles_emb[i], titles_emb[j]) for i in range(10) for j in range(i+1, 10)]
# Out:
# 1.12 ms ± 24 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# As a consequence, in the following cell we **serially** compute all the similarities between the papers.

# %%
L = len(titles_emb)

simil = [cos_sim_array(titles_emb[i], titles_emb[j]) for i in range(L) for j in range(i+1, L)]
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   if sys.path[0] == '':

# %%
simil_df = pd.DataFrame(simil)

print("Number of perfect similarities:", len(simil_df[simil_df['Cosine_Similarity'] >  0.999]))
simil_df.head()
# Out:
# Number of perfect similarities: 5
#                                              Paper_1  \
# 0  Plasma inflammatory cytokines and chemokines i...
# 1  Plasma inflammatory cytokines and chemokines i...
# 2  Plasma inflammatory cytokines and chemokines i...
# 3  Plasma inflammatory cytokines and chemokines i...
# 4  Plasma inflammatory cytokines and chemokines i...
#
#                                              Paper_2  Cosine_Similarity
# 0  Porcine epidemic diarrhea virus N protein prol...           0.068285
# 1  Journal Pre-proof Trombosis de la vena mesenté...           0.042059
# 2  QT prolongation in a diverse, urban population...           0.112272
# 3  How digital health solutions align with the ro...           0.053854
# 4  Deep phenotyping detects a pathological CD4 + ...           0.093806

# %% [markdown]
# Here we compute the 10 papers with the highest cosine similarity and then we print them.

# %%
simil_df_largest = simil_df.nlargest(10, ['Cosine_Similarity'])

for i in range(10):
    print(i+1, "-----------------------------------------------------------------------------------------------")
    print("  Title 1:             ", simil_df_largest.iloc[i]['Paper_1'])
    print("  Title 2:             ", simil_df_largest.iloc[i]['Paper_2'])
    print("  Cosine Similarity:   ", simil_df_largest.iloc[i][2])
# Out:
# 1 -----------------------------------------------------------------------------------------------
#   Title 1:              Journal Pre-proof
#   Title 2:              Journal Pre-proof
#   Cosine Similarity:    1.0
# 2 -----------------------------------------------------------------------------------------------
#   Title 1:              Journal Pre-proof
#   Title 2:              Journal Pre-proof
#   Cosine Similarity:    1.0
# 3 -----------------------------------------------------------------------------------------------
#   Title 1:              Journal Pre-proof
#   Title 2:              Journal Pre-proof
#   Cosine Similarity:    1.0
# 4 -----------------------------------------------------------------------------------------------
#   Title 1:              0123456789) 1 3 Clinical Research in Cardiology
#   Title 2:              0123456789) 1 3 Clinical Research in Cardiology
#   Cosine Similarity:    1.0
# 5 -----------------------------------------------------------------------------------------------
#   Title 1:              Morbidity and Mortality Weekly Report
#   Title 2:              Morbidity and Mortality Weekly Report
#   Cosine Similarity:    0.9999999999999998
# 6 -----------------------------------------------------------------------------------------------
#   Title 1:              National age and co-residence patterns shape covid-19 vulnerability
#   Title 2:              National age and coresidence patterns shape COVID-19 vulnerability
#   Cosine Similarity:    0.9637530808060492
# 7 -----------------------------------------------------------------------------------------------
#   Title 1:              Advances in the treatment of virus-induced asthma
#   Title 2:              Challenges in the time of COVID-19
#   Cosine Similarity:    0.9198208737333303
# 8 -----------------------------------------------------------------------------------------------
#   Title 1:              -NC-ND license (http:// creativecommons.org/licenses/by-nc-nd/4.0/)
#   Title 2:              -NC-ND license (http://creativecommons.org/licenses/by-nc-nd/4.0/)
#   Cosine Similarity:    0.9191508926605849
# 9 -----------------------------------------------------------------------------------------------
#   Title 1:              ADOLESCENT MEDICINE !RON STATUS OF ADOLESCENT FEMALE ATHLETES: Robert
#   Title 2:              CHEMICAL AND BIOLOGICAL ASPECTS OF NARCISSUS ALKALOIDS
#   Cosine Similarity:    0.8978080360329973
# 10 -----------------------------------------------------------------------------------------------
#   Title 1:              Graphene-based nanomaterials in biosystems
#   Title 2:              Protein S-palmitoylation in immunity
#   Cosine Similarity:    0.8826100473360634

# %%
client.close()
